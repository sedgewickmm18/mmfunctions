# %% [markdown]
# ### Preparation steps
#
# Install iotfunctions with
#
# `pip install git+https://github.com/ibm-watson-iot/functions@development`
#
# This projects contains the code for the Analytics Service pipeline as well as the anomaly functions and should pull in most of this notebook's dependencies.
#
# The plotting library matplotlib is the exception, so you need to run
# `pip install matplotlib`
#
#
# #### Unpacking the data
#
# Data is stored in `ArmstarkPumps_3408_36B1_096.tar.bz2`
#
# Please run `tar xfj ArmstarkPumps_3408_36B1_096.tar.bz2` to unpack it prior to running this notebook. You should find
#
# ```
# -rw-rw-r-- 1 markus markus 72361832 Dez 22 17:10 04714B603408.csv
# -rw-rw-r-- 1 markus markus 71782702 Dez 22 16:43 04714B6036B1.csv
# -rw-rw-r-- 1 markus markus 50373659 Dez 22 16:43 IOT_PUMP_DE_GEN5_202012141519.csv
# ```

# %%
# Real life data

import logging
import threading
import itertools
import math
import datetime
import pandas as pd  
import numpy as np  
import scipy as sp
import json
import ibm_db

import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d
import seaborn as seabornInstance
from sqlalchemy import Column, Integer, String, Float, DateTime, Boolean, func
from iotfunctions import base
from iotfunctions import bif
from iotfunctions import entity
from iotfunctions import metadata
from iotfunctions.metadata import EntityType
from iotfunctions.db import Database
from iotfunctions.dbtables import FileModelStore, DBModelStore
from iotfunctions.enginelog import EngineLogging
from iotfunctions import estimator
from iotfunctions.bif import PythonExpression
from iotfunctions.ui import (UISingle, UIMultiItem, UIFunctionOutSingle,
                 UISingleItem, UIFunctionOutMulti, UIMulti, UIExpression,
                 UIText, UIStatusFlag, UIParameters)
from iotfunctions.anomaly import (SaliencybasedGeneralizedAnomalyScore, SpectralAnomalyScore,
                 FFTbasedGeneralizedAnomalyScore, KMeansAnomalyScore,
                 SaliencybasedGeneralizedAnomalyScoreV2, FFTbasedGeneralizedAnomalyScoreV2, 
                 KMeansAnomalyScoreV2, BayesRidgeRegressor,)
from mmfunctions.anomaly import (FeatureBuilder, GBMForecaster, KDEAnomalyScore, VIAnomalyScore)
#from poc.functions import State_Timer
import datetime as dt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics
from pandas.plotting import register_matplotlib_converters
import seaborn as sns
register_matplotlib_converters()

EngineLogging.configure_console_logging(logging.INFO)

# %%
# set up a db object with a FileModelStore to support scaling
with open('credentials_as_beta3.json', encoding='utf-8') as F:
    credentials = json.loads(F.read())
db_schema=None
#fm = FileModelStore()
#db = Database(credentials=credentials, model_store=fm)
# 11390 is the entity type id of shadow_pump_de_gen5
db=Database(credentials=credentials, entity_type_id=11930)


# 11390 is the entity type id of shadow_pump_de_gen5
if db.model_store is None:
     db.model_store = DBModelStore('beta-3', 11390, 'bluadmin', db.native_connection, db.db_type)

print (db)
# Out:
# <iotfunctions.db.Database object at 0x7fbe2c91b910>

# %%
db.native_connection

# %%
def load_data(filename):
    # load data
    df_input = pd.read_csv(filename, parse_dates=['RCV_TIMESTAMP_UTC'], comment='#')
    #df_input = df_input.asfreq('H')
    df_input = df_input.sort_values(by='RCV_TIMESTAMP_UTC').\
                    rename(columns={'RCV_TIMESTAMP_UTC':'timestamp', 'DEVICEID': 'entity'}).\
                    drop(columns=['DEVICETYPE','ID','FORMAT','UPDATED_UTC','LOGICALINTERFACE_ID','PUMP_MODE',\
                                  'DEVICE_ID','FIRMWARE_VER','PTS_COUNT','SERIAL_NUMBER', 'HARDWARE_VER',\
                                  'TAG_NUMBER','PWR','HW_VER','DQ','FW_VER','PTS','PERF_OPTION']).\
                    drop(columns=['VIBRATION_N_XAXIS','VIBRATION_N_YAXIS','VIBRATION_N_ZAXIS','REATED_POWER',\
                                  'RATED_SPEED','RATED_CURRENT','RMSN_X','RMSN_Y','RMSN_Z','RUN_QTY',\
                                  'DESIGN_HEAD','DESIGN_FLOW','RMS_X_AVG'])

    df_input = df_input[df_input['VERSION'] != 0].drop(columns=['VERSION'])
    
    
    return df_input


    
def prep_data(df_input):
    entity = df_input['entity'].values[0]
    
    list_ac_vx = []
    cnt = 0
    for idx,row in df_input[['timestamp','VIBRATIONS_XAXIS','VIBRATIONS_YAXIS','VIBRATIONS_ZAXIS',
                             'ACCEL_POWER','ACCEL_SPEED']].iterrows():
        if isinstance(row['timestamp'], str):
            ts = datetime.datetime.strptime(row['timestamp'], '%Y-%m-%d-%H.%M.%S.%f')
        else:
            ts = row['timestamp']
            
        rvibxs = row['VIBRATIONS_XAXIS']
        rvibys = row['VIBRATIONS_YAXIS']
        rvibzs = row['VIBRATIONS_ZAXIS']
        racc = row['ACCEL_POWER']
        rspd = row['ACCEL_SPEED']

        if isinstance(racc, str):
            racc = eval(racc)
        if isinstance(rspd, str):
            rspd = eval(rspd)
            
        if isinstance(rvibxs, str):
            list_ac = []
           
            for ac in racc:
                #print(ac)
                list_ac.append(eval(ac))
                list_ac.append(eval(ac))
                list_ac.append(eval(ac))
                #print (list_ac)
            
            list_as = []
            for as_ in rspd:
                list_as.append(eval(as_))
                list_as.append(eval(as_))
                list_as.append(eval(as_))
            
            list_vx = []
            for vx in eval(rvibxs):
                list_vx.append(vx)
                #print (list_vx)
            
            list_vy = []
            for vy in eval(rvibys):
                list_vy.append(vy)
            
            list_vz = []
            for vz in eval(rvibzs):
                list_vz.append(vz)

            #print(list_ac, list_vx)
            cnt2 = 0
            for p in zip(list_ac, list_as, list_vx, list_vy, list_vz):
                #print(ts + datetime.timedelta(seconds = cnt2 * 10), p[0],p[1])
                list_ac_vx.append([ts + datetime.timedelta(seconds = cnt2 * 10), p[0],p[1],p[2],p[3],p[4]])
                cnt2 += 1
        cnt += 1

    df_clean = pd.DataFrame(list_ac_vx, columns=['timestamp','power','speed','rms_x', 'rms_y', 'rms_z'])
    df_clean['entity'] = entity
    
    return df_clean.set_index(['entity','timestamp'])

# %%
#df_clean = prep_data(load_data('./IOT_PUMP_DE_GEN5_202012141519.csv'))

#df_clean.head(2)

# %%
filename = "./IOT_SHADOW_PUMP_DE_GEN5_202102231533.csv"
dff = pd.read_csv(filename, parse_dates=['EVT_TIMESTAMP'], comment='#')
dff.columns = dff.columns.str.lower() 
df_clean = dff.drop(columns=['devicetype','logicalinterface_id','eventtype','format',
                             'rcv_timestamp_utc','updated_utc']).set_index(['deviceid','evt_timestamp'])

# %%
df_clean.to_csv('PumpTestData.csv')

# %%
df_clean.index.levels[0]
# Out:
# Index(['04714B601096', '04714B603408', '04714B6036B1', '04714B6037F8',
#        '04714B60382B', '04714B604101', '04714B60553A', '04714B605699',
#        '04714B606390'],
#       dtype='object', name='deviceid')

# %%
#plt.figure(figsize=(20, 6))

df_display = df_clean[df_clean['speed'] > 1000]

sns.set_style('ticks')
#fig, ax = plt.subplots(1,1,figsize=(20,8))
gx = sns.displot(df_display[['speed','rms_x']], x='speed', y='rms_x', kind="kde", 
                 rug=False, height=6, aspect=2)
    
gx.set_titles('KDE for' + df_clean.index.levels[0].values[0])
# Out:
# 2021-04-22T15:29:49.834 INFO numexpr.utils._init_num_threads Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-04-22T15:29:49.835 INFO numexpr.utils._init_num_threads NumExpr defaulting to 8 threads.

# %%
#plt.figure(figsize=(16, 6))
sns.set_style('ticks')
#fig, ax = plt.subplots(1,1,figsize=(20,8))
gy = sns.displot(df_display[['speed','rms_y']], x='speed', y='rms_y', kind="kde", 
                 rug=False, height=6, aspect=2)
gy.set_titles('KDE for' + df_clean.index.levels[0].values[0])

# %%
# prepare
delete_model = True
df_i = df_clean.dropna()
#df_i['speed'] /= 10
df_i.to_csv('PumpTestData.csv')

# %%
# %%time
print('Train and evaluate model for ' + df_i.index.levels[0].values)
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsi = VIAnomalyScore(['speed'], ['rms_x'])
#spsi.epochs = 1  # only for testing model storage
spsi.epochs = 300

spsi.auto_train = True
spsi.delete_model = delete_model
et = spsi._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
et.name = 'IOT_SHADOW_PUMP_DE_GEN5'



spsi._entity_type = et
df_i = spsi.execute(df=df_i)

EngineLogging.configure_console_logging(logging.INFO)
df_i.describe()
# Out:
# ['Train and evaluate model for 04714B601096'
#  'Train and evaluate model for 04714B603408'
#  'Train and evaluate model for 04714B6036B1'
#  'Train and evaluate model for 04714B6037F8'
#  'Train and evaluate model for 04714B60382B'
#  'Train and evaluate model for 04714B604101'
#  'Train and evaluate model for 04714B60553A'
#  'Train and evaluate model for 04714B605699'
#  'Train and evaluate model for 04714B606390']
# 2021-04-22T19:48:56.406 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2021-04-22T19:48:56.408 DEBUG root.__init__ __init__VIAnomalyScore
# 2021-04-22T19:48:56.409 DEBUG root.__init__ __init__ done with parameters: speed.rms_x
# 2021-04-22T19:48:56.411 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.3.1
# 2021-04-22T19:48:56.412 DEBUG iotfunctions.util.__init__ Starting trace
# 2021-04-22T19:48:56.413 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20210422174856
# 2021-04-22T19:48:56.413 DEBUG iotfunctions.util.__init__ auto_save None
# 2021-04-22T19:48:56.414 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2021-04-22T19:48:56.415 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2021-04-22T19:48:56.415 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# 2021-04-22T19:48:56.441 DEBUG mmfunctions.anomaly.execute Execute VIAnomalyScore
# 2021-04-22T19:48:56.442 DEBUG mmfunctions.anomaly.execute Execute VIAnomalyScore enter per entity execution
# 2021-04-22T19:48:56.609 DEBUG mmfunctions.anomaly._calc VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'> for entity 04714B601096
# 2021-04-22T19:48:56.610 DEBUG mmfunctions.anomaly._calc ['speed']
# 2021-04-22T19:48:56.611 ERROR mmfunctions.anomaly.load_model Model retrieval failed with name 'db' is not defined
# 2021-04-22T19:48:56.616 INFO mmfunctions.anomaly._calc Adjusting target mean with 0.2014988813574559
# 2021-04-22T19:48:56.674 DEBUG mmfunctions.anomaly._calc Training VI model 1 for entity: 04714B601096Prior mean: 0.0, sigma: 0.10127890314963868
# 2021-04-22T19:48:56.756 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([177980, 1]) Sigma: torch.Size([177980, 1]) loglikelihood: torch.Size([177980, 1]) KL value: tensor(-3.7834, grad_fn=<MeanBackward0>)
# 2021-04-22T19:48:56.757 DEBUG mmfunctions.anomaly._calc Epoch: 0, neg ELBO: 4.759181976318359
# 2021-04-22T19:48:58.181 DEBUG mmfunctions.anomaly._calc Epoch: 10, neg ELBO: 2.022649049758911
# 2021-04-22T19:48:59.545 DEBUG mmfunctions.anomaly._calc Epoch: 20, neg ELBO: 0.5788609385490417
# 2021-04-22T19:49:00.868 DEBUG mmfunctions.anomaly._calc Epoch: 30, neg ELBO: -0.16033312678337097
# 2021-04-22T19:49:02.295 DEBUG mmfunctions.anomaly._calc Epoch: 40, neg ELBO: -0.4311883747577667
# 2021-04-22T19:49:03.583 DEBUG mmfunctions.anomaly._calc Epoch: 50, neg ELBO: -0.4432709813117981
# 2021-04-22T19:49:04.860 DEBUG mmfunctions.anomaly._calc Epoch: 60, neg ELBO: -0.45885229110717773
# 2021-04-22T19:49:06.179 DEBUG mmfunctions.anomaly._calc Epoch: 70, neg ELBO: -0.46065664291381836
# 2021-04-22T19:49:07.487 DEBUG mmfunctions.anomaly._calc Epoch: 80, neg ELBO: -0.4651552736759186
# 2021-04-22T19:49:08.769 DEBUG mmfunctions.anomaly._calc Epoch: 90, neg ELBO: -0.466545045375824
# 2021-04-22T19:49:10.084 DEBUG mmfunctions.anomaly._calc Epoch: 100, neg ELBO: -0.46640151739120483
# 2021-04-22T19:49:11.395 DEBUG mmfunctions.anomaly._calc Epoch: 110, neg ELBO: -0.46932706236839294
# 2021-04-22T19:49:12.746 DEBUG mmfunctions.anomaly._calc Epoch: 120, neg ELBO: -0.47255587577819824
# 2021-04-22T19:49:14.095 DEBUG mmfunctions.anomaly._calc Epoch: 130, neg ELBO: -0.4691467583179474
# 2021-04-22T19:49:15.396 DEBUG mmfunctions.anomaly._calc Epoch: 140, neg ELBO: -0.4704263508319855
# 2021-04-22T19:49:16.709 DEBUG mmfunctions.anomaly._calc Epoch: 150, neg ELBO: -0.4688505232334137
# 2021-04-22T19:49:18.022 DEBUG mmfunctions.anomaly._calc Epoch: 160, neg ELBO: -0.4708265960216522
# 2021-04-22T19:49:19.326 DEBUG mmfunctions.anomaly._calc Epoch: 170, neg ELBO: -0.4708259105682373
# 2021-04-22T19:49:20.646 DEBUG mmfunctions.anomaly._calc Epoch: 180, neg ELBO: -0.4727709889411926
# 2021-04-22T19:49:22.001 DEBUG mmfunctions.anomaly._calc Epoch: 190, neg ELBO: -0.47286322712898254
# 2021-04-22T19:49:23.353 DEBUG mmfunctions.anomaly._calc Epoch: 200, neg ELBO: -0.4732581079006195
# 2021-04-22T19:49:24.758 DEBUG mmfunctions.anomaly._calc Epoch: 210, neg ELBO: -0.47428038716316223
# 2021-04-22T19:49:26.097 DEBUG mmfunctions.anomaly._calc Epoch: 220, neg ELBO: -0.47517186403274536
# 2021-04-22T19:49:27.618 DEBUG mmfunctions.anomaly._calc Epoch: 230, neg ELBO: -0.47390085458755493
# 2021-04-22T19:49:28.966 DEBUG mmfunctions.anomaly._calc Epoch: 240, neg ELBO: -0.4724351167678833
# 2021-04-22T19:49:30.363 DEBUG mmfunctions.anomaly._calc Epoch: 250, neg ELBO: -0.4741164445877075
# 2021-04-22T19:49:31.814 DEBUG mmfunctions.anomaly._calc Epoch: 260, neg ELBO: -0.47604620456695557
# 2021-04-22T19:49:33.169 DEBUG mmfunctions.anomaly._calc Epoch: 270, neg ELBO: -0.4728131890296936
# 2021-04-22T19:49:34.531 DEBUG mmfunctions.anomaly._calc Epoch: 280, neg ELBO: -0.475280225276947
# 2021-04-22T19:49:35.944 DEBUG mmfunctions.anomaly._calc Epoch: 290, neg ELBO: -0.4746377766132355
# 2021-04-22T19:49:37.380 DEBUG mmfunctions.anomaly._calc Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-04-22T19:49:38.205 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# 2021-04-22T19:49:38.292 DEBUG mmfunctions.anomaly._calc VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'> for entity 04714B601096
# 2021-04-22T19:49:38.293 DEBUG mmfunctions.anomaly._calc ['speed']
# 2021-04-22T19:49:38.295 ERROR mmfunctions.anomaly.load_model Model retrieval failed with name 'db' is not defined
# 2021-04-22T19:49:38.300 INFO mmfunctions.anomaly._calc Adjusting target mean with 0.015608653210748304
# 2021-04-22T19:49:38.328 DEBUG mmfunctions.anomaly._calc Training VI model 1 for entity: 04714B601096Prior mean: 0.0, sigma: 0.014463010314334925
# 2021-04-22T19:49:38.367 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([105505, 1]) Sigma: torch.Size([105505, 1]) loglikelihood: torch.Size([105505, 1]) KL value: tensor(-20.7502, grad_fn=<MeanBackward0>)
# 2021-04-22T19:49:38.369 DEBUG mmfunctions.anomaly._calc Epoch: 0, neg ELBO: 21.470867156982422
# 2021-04-22T19:49:39.167 DEBUG mmfunctions.anomaly._calc Epoch: 10, neg ELBO: 3.486595392227173
# 2021-04-22T19:49:39.938 DEBUG mmfunctions.anomaly._calc Epoch: 20, neg ELBO: -1.3078597784042358
# 2021-04-22T19:49:40.705 DEBUG mmfunctions.anomaly._calc Epoch: 30, neg ELBO: -1.6024247407913208
# 2021-04-22T19:49:41.528 DEBUG mmfunctions.anomaly._calc Epoch: 40, neg ELBO: -1.587221384048462
# 2021-04-22T19:49:42.305 DEBUG mmfunctions.anomaly._calc Epoch: 50, neg ELBO: -1.6019647121429443
# 2021-04-22T19:49:43.075 DEBUG mmfunctions.anomaly._calc Epoch: 60, neg ELBO: -1.631020426750183
# 2021-04-22T19:49:43.842 DEBUG mmfunctions.anomaly._calc Epoch: 70, neg ELBO: -1.6335546970367432
# 2021-04-22T19:49:44.608 DEBUG mmfunctions.anomaly._calc Epoch: 80, neg ELBO: -1.6352548599243164
# 2021-04-22T19:49:45.372 DEBUG mmfunctions.anomaly._calc Epoch: 90, neg ELBO: -1.6349188089370728
# 2021-04-22T19:49:46.156 DEBUG mmfunctions.anomaly._calc Epoch: 100, neg ELBO: -1.633570671081543
# 2021-04-22T19:49:46.940 DEBUG mmfunctions.anomaly._calc Epoch: 110, neg ELBO: -1.6366909742355347
# 2021-04-22T19:49:47.701 DEBUG mmfunctions.anomaly._calc Epoch: 120, neg ELBO: -1.634118676185608
# 2021-04-22T19:49:48.487 DEBUG mmfunctions.anomaly._calc Epoch: 130, neg ELBO: -1.6356098651885986
# 2021-04-22T19:49:49.289 DEBUG mmfunctions.anomaly._calc Epoch: 140, neg ELBO: -1.6369277238845825
# 2021-04-22T19:49:50.067 DEBUG mmfunctions.anomaly._calc Epoch: 150, neg ELBO: -1.6355299949645996
# 2021-04-22T19:49:50.877 DEBUG mmfunctions.anomaly._calc Epoch: 160, neg ELBO: -1.6347800493240356
# 2021-04-22T19:49:51.653 DEBUG mmfunctions.anomaly._calc Epoch: 170, neg ELBO: -1.6357678174972534
# 2021-04-22T19:49:52.416 DEBUG mmfunctions.anomaly._calc Epoch: 180, neg ELBO: -1.6363036632537842
# 2021-04-22T19:49:53.157 DEBUG mmfunctions.anomaly._calc Epoch: 190, neg ELBO: -1.6326446533203125
# 2021-04-22T19:49:53.942 DEBUG mmfunctions.anomaly._calc Epoch: 200, neg ELBO: -1.634736180305481
# 2021-04-22T19:49:54.731 DEBUG mmfunctions.anomaly._calc Epoch: 210, neg ELBO: -1.6366462707519531
# 2021-04-22T19:49:55.520 DEBUG mmfunctions.anomaly._calc Epoch: 220, neg ELBO: -1.6360846757888794
# 2021-04-22T19:49:56.273 DEBUG mmfunctions.anomaly._calc Epoch: 230, neg ELBO: -1.6374549865722656
# 2021-04-22T19:49:57.039 DEBUG mmfunctions.anomaly._calc Epoch: 240, neg ELBO: -1.6350401639938354
# 2021-04-22T19:49:57.828 DEBUG mmfunctions.anomaly._calc Epoch: 250, neg ELBO: -1.6392173767089844
# 2021-04-22T19:49:58.633 DEBUG mmfunctions.anomaly._calc Epoch: 260, neg ELBO: -1.638512134552002
# 2021-04-22T19:49:59.406 DEBUG mmfunctions.anomaly._calc Epoch: 270, neg ELBO: -1.6335479021072388
# 2021-04-22T19:50:00.227 DEBUG mmfunctions.anomaly._calc Epoch: 280, neg ELBO: -1.6378117799758911
# 2021-04-22T19:50:01.022 DEBUG mmfunctions.anomaly._calc Epoch: 290, neg ELBO: -1.6337666511535645
# 2021-04-22T19:50:01.800 DEBUG mmfunctions.anomaly._calc Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-04-22T19:50:02.533 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# 2021-04-22T19:50:02.593 DEBUG mmfunctions.anomaly._calc VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'> for entity 04714B601096
# 2021-04-22T19:50:02.593 DEBUG mmfunctions.anomaly._calc ['speed']
# 2021-04-22T19:50:02.594 ERROR mmfunctions.anomaly.load_model Model retrieval failed with name 'db' is not defined
# 2021-04-22T19:50:02.598 INFO mmfunctions.anomaly._calc Adjusting target mean with 0.03493562271520667
# 2021-04-22T19:50:02.622 DEBUG mmfunctions.anomaly._calc Training VI model 1 for entity: 04714B601096Prior mean: 0.0, sigma: 0.018506651655864313
# 2021-04-22T19:50:02.661 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([105480, 1]) Sigma: torch.Size([105480, 1]) loglikelihood: torch.Size([105480, 1]) KL value: tensor(-27.4641, grad_fn=<MeanBackward0>)
# 2021-04-22T19:50:02.662 DEBUG mmfunctions.anomaly._calc Epoch: 0, neg ELBO: 28.438554763793945
# 2021-04-22T19:50:03.431 DEBUG mmfunctions.anomaly._calc Epoch: 10, neg ELBO: 9.971869468688965
# 2021-04-22T19:50:04.220 DEBUG mmfunctions.anomaly._calc Epoch: 20, neg ELBO: -0.2338498830795288
# 2021-04-22T19:50:05.017 DEBUG mmfunctions.anomaly._calc Epoch: 30, neg ELBO: -1.4210954904556274
# 2021-04-22T19:50:05.793 DEBUG mmfunctions.anomaly._calc Epoch: 40, neg ELBO: -1.482487678527832
# 2021-04-22T19:50:06.586 DEBUG mmfunctions.anomaly._calc Epoch: 50, neg ELBO: -1.4983595609664917
# 2021-04-22T19:50:07.366 DEBUG mmfunctions.anomaly._calc Epoch: 60, neg ELBO: -1.5148409605026245
# 2021-04-22T19:50:08.178 DEBUG mmfunctions.anomaly._calc Epoch: 70, neg ELBO: -1.5237135887145996
# 2021-04-22T19:50:08.963 DEBUG mmfunctions.anomaly._calc Epoch: 80, neg ELBO: -1.5269055366516113
# 2021-04-22T19:50:09.748 DEBUG mmfunctions.anomaly._calc Epoch: 90, neg ELBO: -1.527173638343811
# 2021-04-22T19:50:10.550 DEBUG mmfunctions.anomaly._calc Epoch: 100, neg ELBO: -1.5269535779953003
# 2021-04-22T19:50:11.343 DEBUG mmfunctions.anomaly._calc Epoch: 110, neg ELBO: -1.52457857131958
# 2021-04-22T19:50:12.139 DEBUG mmfunctions.anomaly._calc Epoch: 120, neg ELBO: -1.5224796533584595
# 2021-04-22T19:50:12.948 DEBUG mmfunctions.anomaly._calc Epoch: 130, neg ELBO: -1.5256855487823486
# 2021-04-22T19:50:13.747 DEBUG mmfunctions.anomaly._calc Epoch: 140, neg ELBO: -1.530903697013855
# 2021-04-22T19:50:14.566 DEBUG mmfunctions.anomaly._calc Epoch: 150, neg ELBO: -1.5281479358673096
# 2021-04-22T19:50:15.386 DEBUG mmfunctions.anomaly._calc Epoch: 160, neg ELBO: -1.5291235446929932
# 2021-04-22T19:50:16.238 DEBUG mmfunctions.anomaly._calc Epoch: 170, neg ELBO: -1.5241949558258057
# 2021-04-22T19:50:17.103 DEBUG mmfunctions.anomaly._calc Epoch: 180, neg ELBO: -1.5274447202682495
# 2021-04-22T19:50:17.954 DEBUG mmfunctions.anomaly._calc Epoch: 190, neg ELBO: -1.5226701498031616
# 2021-04-22T19:50:18.800 DEBUG mmfunctions.anomaly._calc Epoch: 200, neg ELBO: -1.524231195449829
# 2021-04-22T19:50:19.629 DEBUG mmfunctions.anomaly._calc Epoch: 210, neg ELBO: -1.5285195112228394
# 2021-04-22T19:50:20.450 DEBUG mmfunctions.anomaly._calc Epoch: 220, neg ELBO: -1.5269371271133423
# 2021-04-22T19:50:21.301 DEBUG mmfunctions.anomaly._calc Epoch: 230, neg ELBO: -1.5310944318771362
# 2021-04-22T19:50:22.299 DEBUG mmfunctions.anomaly._calc Epoch: 240, neg ELBO: -1.5252269506454468
# 2021-04-22T19:50:23.139 DEBUG mmfunctions.anomaly._calc Epoch: 250, neg ELBO: -1.5280098915100098
# 2021-04-22T19:50:23.948 DEBUG mmfunctions.anomaly._calc Epoch: 260, neg ELBO: -1.5264116525650024
# 2021-04-22T19:50:24.729 DEBUG mmfunctions.anomaly._calc Epoch: 270, neg ELBO: -1.526443362236023
# 2021-04-22T19:50:25.543 DEBUG mmfunctions.anomaly._calc Epoch: 280, neg ELBO: -1.5273194313049316
# 2021-04-22T19:50:26.343 DEBUG mmfunctions.anomaly._calc Epoch: 290, neg ELBO: -1.5277886390686035
# 2021-04-22T19:50:27.089 DEBUG mmfunctions.anomaly._calc Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-04-22T19:50:27.846 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16640 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# 2021-04-22T19:50:27.910 DEBUG mmfunctions.anomaly._calc VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'> for entity 04714B601096
# 2021-04-22T19:50:27.911 DEBUG mmfunctions.anomaly._calc ['speed']
# 2021-04-22T19:50:27.913 ERROR mmfunctions.anomaly.load_model Model retrieval failed with name 'db' is not defined
# 2021-04-22T19:50:27.918 INFO mmfunctions.anomaly._calc Adjusting target mean with 0.07878814401944209
# 2021-04-22T19:50:28.000 DEBUG mmfunctions.anomaly._calc Training VI model 1 for entity: 04714B601096Prior mean: 0.0, sigma: 0.008665731551314558
# 2021-04-22T19:50:28.072 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([236600, 1]) Sigma: torch.Size([236600, 1]) loglikelihood: torch.Size([236600, 1]) KL value: tensor(-56.6467, grad_fn=<MeanBackward0>)
# 2021-04-22T19:50:28.074 DEBUG mmfunctions.anomaly._calc Epoch: 0, neg ELBO: 57.58334732055664
# 2021-04-22T19:50:29.939 DEBUG mmfunctions.anomaly._calc Epoch: 10, neg ELBO: 32.59372329711914
# 2021-04-22T19:50:31.914 DEBUG mmfunctions.anomaly._calc Epoch: 20, neg ELBO: 8.950203895568848
# 2021-04-22T19:50:33.850 DEBUG mmfunctions.anomaly._calc Epoch: 30, neg ELBO: -0.6671410202980042
# 2021-04-22T19:50:35.732 DEBUG mmfunctions.anomaly._calc Epoch: 40, neg ELBO: -1.7390165328979492
# 2021-04-22T19:50:37.599 DEBUG mmfunctions.anomaly._calc Epoch: 50, neg ELBO: -1.8196176290512085
# 2021-04-22T19:50:39.416 DEBUG mmfunctions.anomaly._calc Epoch: 60, neg ELBO: -1.8204057216644287
# 2021-04-22T19:50:41.300 DEBUG mmfunctions.anomaly._calc Epoch: 70, neg ELBO: -1.84403657913208
# 2021-04-22T19:50:43.146 DEBUG mmfunctions.anomaly._calc Epoch: 80, neg ELBO: -1.8582407236099243
# 2021-04-22T19:50:45.027 DEBUG mmfunctions.anomaly._calc Epoch: 90, neg ELBO: -1.865736961364746
# 2021-04-22T19:50:46.884 DEBUG mmfunctions.anomaly._calc Epoch: 100, neg ELBO: -1.8702012300491333
# 2021-04-22T19:50:48.748 DEBUG mmfunctions.anomaly._calc Epoch: 110, neg ELBO: -1.872461199760437
# 2021-04-22T19:50:50.619 DEBUG mmfunctions.anomaly._calc Epoch: 120, neg ELBO: -1.874882459640503
# 2021-04-22T19:50:52.638 DEBUG mmfunctions.anomaly._calc Epoch: 130, neg ELBO: -1.8765085935592651
# 2021-04-22T19:50:54.519 DEBUG mmfunctions.anomaly._calc Epoch: 140, neg ELBO: -1.8785502910614014
# 2021-04-22T19:50:56.410 DEBUG mmfunctions.anomaly._calc Epoch: 150, neg ELBO: -1.8788437843322754
# 2021-04-22T19:50:58.229 DEBUG mmfunctions.anomaly._calc Epoch: 160, neg ELBO: -1.8784369230270386
# 2021-04-22T19:51:00.104 DEBUG mmfunctions.anomaly._calc Epoch: 170, neg ELBO: -1.879885196685791
# 2021-04-22T19:51:02.056 DEBUG mmfunctions.anomaly._calc Epoch: 180, neg ELBO: -1.8836027383804321
# 2021-04-22T19:51:04.022 DEBUG mmfunctions.anomaly._calc Epoch: 190, neg ELBO: -1.8826793432235718
# 2021-04-22T19:51:06.030 DEBUG mmfunctions.anomaly._calc Epoch: 200, neg ELBO: -1.8817614316940308
# 2021-04-22T19:51:07.965 DEBUG mmfunctions.anomaly._calc Epoch: 210, neg ELBO: -1.8821029663085938
# 2021-04-22T19:51:09.954 DEBUG mmfunctions.anomaly._calc Epoch: 220, neg ELBO: -1.8845428228378296
# 2021-04-22T19:51:11.851 DEBUG mmfunctions.anomaly._calc Epoch: 230, neg ELBO: -1.8835524320602417
# 2021-04-22T19:51:13.731 DEBUG mmfunctions.anomaly._calc Epoch: 240, neg ELBO: -1.88588547706604
# 2021-04-22T19:51:15.710 DEBUG mmfunctions.anomaly._calc Epoch: 250, neg ELBO: -1.885646939277649
# 2021-04-22T19:51:17.652 DEBUG mmfunctions.anomaly._calc Epoch: 260, neg ELBO: -1.8844804763793945
# 2021-04-22T19:51:19.587 DEBUG mmfunctions.anomaly._calc Epoch: 270, neg ELBO: -1.8851053714752197
# 2021-04-22T19:51:21.522 DEBUG mmfunctions.anomaly._calc Epoch: 280, neg ELBO: -1.887305498123169
# 2021-04-22T19:51:23.420 DEBUG mmfunctions.anomaly._calc Epoch: 290, neg ELBO: -1.8873672485351562
# 2021-04-22T19:51:25.230 DEBUG mmfunctions.anomaly._calc Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-04-22T19:51:26.073 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# 2021-04-22T19:51:26.197 DEBUG mmfunctions.anomaly._calc VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'> for entity 04714B601096
# 2021-04-22T19:51:26.198 DEBUG mmfunctions.anomaly._calc ['speed']
# 2021-04-22T19:51:26.199 ERROR mmfunctions.anomaly.load_model Model retrieval failed with name 'db' is not defined
# 2021-04-22T19:51:26.201 INFO mmfunctions.anomaly._calc Adjusting target mean with 0.04123785988983475
# 2021-04-22T19:51:26.204 DEBUG mmfunctions.anomaly._calc Training VI model 1 for entity: 04714B601096Prior mean: 0.0, sigma: 0.015313554065731597
# 2021-04-22T19:51:26.208 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([9985, 1]) Sigma: torch.Size([9985, 1]) loglikelihood: torch.Size([9985, 1]) KL value: tensor(-37.1749, grad_fn=<MeanBackward0>)
# 2021-04-22T19:51:26.209 DEBUG mmfunctions.anomaly._calc Epoch: 0, neg ELBO: 38.19293975830078
# 2021-04-22T19:51:26.309 DEBUG mmfunctions.anomaly._calc Epoch: 10, neg ELBO: 31.740219116210938
# 2021-04-22T19:51:26.402 DEBUG mmfunctions.anomaly._calc Epoch: 20, neg ELBO: 27.10441017150879
# 2021-04-22T19:51:26.480 DEBUG mmfunctions.anomaly._calc Epoch: 30, neg ELBO: 15.581926345825195
# 2021-04-22T19:51:26.560 DEBUG mmfunctions.anomaly._calc Epoch: 40, neg ELBO: 2.3090291023254395
# 2021-04-22T19:51:26.644 DEBUG mmfunctions.anomaly._calc Epoch: 50, neg ELBO: -1.2606209516525269
# 2021-04-22T19:51:26.730 DEBUG mmfunctions.anomaly._calc Epoch: 60, neg ELBO: -1.5253219604492188
# 2021-04-22T19:51:26.819 DEBUG mmfunctions.anomaly._calc Epoch: 70, neg ELBO: -1.5642045736312866
# 2021-04-22T19:51:26.910 DEBUG mmfunctions.anomaly._calc Epoch: 80, neg ELBO: -1.6263624429702759
# 2021-04-22T19:51:27.003 DEBUG mmfunctions.anomaly._calc Epoch: 90, neg ELBO: -1.6169193983078003
# 2021-04-22T19:51:27.097 DEBUG mmfunctions.anomaly._calc Epoch: 100, neg ELBO: -1.6227710247039795
# 2021-04-22T19:51:27.189 DEBUG mmfunctions.anomaly._calc Epoch: 110, neg ELBO: -1.6140042543411255
# 2021-04-22T19:51:27.280 DEBUG mmfunctions.anomaly._calc Epoch: 120, neg ELBO: -1.606263518333435
# 2021-04-22T19:51:27.387 DEBUG mmfunctions.anomaly._calc Epoch: 130, neg ELBO: -1.6155980825424194
# 2021-04-22T19:51:27.482 DEBUG mmfunctions.anomaly._calc Epoch: 140, neg ELBO: -1.6129907369613647
# 2021-04-22T19:51:27.578 DEBUG mmfunctions.anomaly._calc Epoch: 150, neg ELBO: -1.6115411520004272
# 2021-04-22T19:51:27.674 DEBUG mmfunctions.anomaly._calc Epoch: 160, neg ELBO: -1.6162221431732178
# 2021-04-22T19:51:27.772 DEBUG mmfunctions.anomaly._calc Epoch: 170, neg ELBO: -1.6148101091384888
# 2021-04-22T19:51:27.870 DEBUG mmfunctions.anomaly._calc Epoch: 180, neg ELBO: -1.6123123168945312
# 2021-04-22T19:51:27.966 DEBUG mmfunctions.anomaly._calc Epoch: 190, neg ELBO: -1.619535207748413
# 2021-04-22T19:51:28.073 DEBUG mmfunctions.anomaly._calc Epoch: 200, neg ELBO: -1.62136971950531
# 2021-04-22T19:51:28.178 DEBUG mmfunctions.anomaly._calc Epoch: 210, neg ELBO: -1.6053783893585205
# 2021-04-22T19:51:28.283 DEBUG mmfunctions.anomaly._calc Epoch: 220, neg ELBO: -1.6110811233520508
# 2021-04-22T19:51:28.389 DEBUG mmfunctions.anomaly._calc Epoch: 230, neg ELBO: -1.608687400817871
# 2021-04-22T19:51:28.497 DEBUG mmfunctions.anomaly._calc Epoch: 240, neg ELBO: -1.613528847694397
# 2021-04-22T19:51:28.604 DEBUG mmfunctions.anomaly._calc Epoch: 250, neg ELBO: -1.6069989204406738
# 2021-04-22T19:51:28.709 DEBUG mmfunctions.anomaly._calc Epoch: 260, neg ELBO: -1.620410442352295
# 2021-04-22T19:51:28.814 DEBUG mmfunctions.anomaly._calc Epoch: 270, neg ELBO: -1.60794198513031
# 2021-04-22T19:51:28.916 DEBUG mmfunctions.anomaly._calc Epoch: 280, neg ELBO: -1.614815592765808
# 2021-04-22T19:51:29.018 DEBUG mmfunctions.anomaly._calc Epoch: 290, neg ELBO: -1.6169720888137817
# 2021-04-22T19:51:29.118 DEBUG mmfunctions.anomaly._calc Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-04-22T19:51:30.075 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16640 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# 2021-04-22T19:51:30.100 DEBUG mmfunctions.anomaly._calc VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'> for entity 04714B601096
# 2021-04-22T19:51:30.101 DEBUG mmfunctions.anomaly._calc ['speed']
# 2021-04-22T19:51:30.105 ERROR mmfunctions.anomaly.load_model Model retrieval failed with name 'db' is not defined
# 2021-04-22T19:51:30.112 INFO mmfunctions.anomaly._calc Adjusting target mean with 0.019981020391469474
# 2021-04-22T19:51:30.147 DEBUG mmfunctions.anomaly._calc Training VI model 1 for entity: 04714B601096Prior mean: 0.0, sigma: 0.01242396090770211
# 2021-04-22T19:51:30.195 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([119805, 1]) Sigma: torch.Size([119805, 1]) loglikelihood: torch.Size([119805, 1]) KL value: tensor(-32.2884, grad_fn=<MeanBackward0>)
# 2021-04-22T19:51:30.196 DEBUG mmfunctions.anomaly._calc Epoch: 0, neg ELBO: 33.13491439819336
# 2021-04-22T19:51:31.081 DEBUG mmfunctions.anomaly._calc Epoch: 10, neg ELBO: 9.974770545959473
# 2021-04-22T19:51:31.990 DEBUG mmfunctions.anomaly._calc Epoch: 20, neg ELBO: -0.7033662796020508
# 2021-04-22T19:51:32.908 DEBUG mmfunctions.anomaly._calc Epoch: 30, neg ELBO: -1.59295654296875
# 2021-04-22T19:51:33.982 DEBUG mmfunctions.anomaly._calc Epoch: 40, neg ELBO: -1.6158400774002075
# 2021-04-22T19:51:35.007 DEBUG mmfunctions.anomaly._calc Epoch: 50, neg ELBO: -1.7111698389053345
# 2021-04-22T19:51:36.188 DEBUG mmfunctions.anomaly._calc Epoch: 60, neg ELBO: -1.7315987348556519
# 2021-04-22T19:51:37.939 DEBUG mmfunctions.anomaly._calc Epoch: 70, neg ELBO: -1.737725853919983
# 2021-04-22T19:51:39.531 DEBUG mmfunctions.anomaly._calc Epoch: 80, neg ELBO: -1.7417417764663696
# 2021-04-22T19:51:41.169 DEBUG mmfunctions.anomaly._calc Epoch: 90, neg ELBO: -1.674452781677246
# 2021-04-22T19:51:42.815 DEBUG mmfunctions.anomaly._calc Epoch: 100, neg ELBO: -1.7386093139648438
# 2021-04-22T19:51:44.328 DEBUG mmfunctions.anomaly._calc Epoch: 110, neg ELBO: -1.73824942111969
# 2021-04-22T19:51:45.908 DEBUG mmfunctions.anomaly._calc Epoch: 120, neg ELBO: -1.742488145828247
# 2021-04-22T19:51:47.500 DEBUG mmfunctions.anomaly._calc Epoch: 130, neg ELBO: -1.742430567741394
# 2021-04-22T19:51:49.029 DEBUG mmfunctions.anomaly._calc Epoch: 140, neg ELBO: -1.74126136302948
# 2021-04-22T19:51:50.433 DEBUG mmfunctions.anomaly._calc Epoch: 150, neg ELBO: -1.7402870655059814
# 2021-04-22T19:51:52.088 DEBUG mmfunctions.anomaly._calc Epoch: 160, neg ELBO: -1.744912028312683
# 2021-04-22T19:51:53.571 DEBUG mmfunctions.anomaly._calc Epoch: 170, neg ELBO: -1.7424510717391968
# 2021-04-22T19:51:55.136 DEBUG mmfunctions.anomaly._calc Epoch: 180, neg ELBO: -1.744185209274292
# 2021-04-22T19:51:56.526 DEBUG mmfunctions.anomaly._calc Epoch: 190, neg ELBO: -1.7438526153564453
# 2021-04-22T19:51:58.000 DEBUG mmfunctions.anomaly._calc Epoch: 200, neg ELBO: -1.744192361831665
# 2021-04-22T19:51:59.544 DEBUG mmfunctions.anomaly._calc Epoch: 210, neg ELBO: -1.7444186210632324
# 2021-04-22T19:52:00.948 DEBUG mmfunctions.anomaly._calc Epoch: 220, neg ELBO: -1.6541037559509277
# 2021-04-22T19:52:02.497 DEBUG mmfunctions.anomaly._calc Epoch: 230, neg ELBO: -1.7276631593704224
# 2021-04-22T19:52:04.035 DEBUG mmfunctions.anomaly._calc Epoch: 240, neg ELBO: -1.7342681884765625
# 2021-04-22T19:52:05.628 DEBUG mmfunctions.anomaly._calc Epoch: 250, neg ELBO: -1.7416199445724487
# 2021-04-22T19:52:07.038 DEBUG mmfunctions.anomaly._calc Epoch: 260, neg ELBO: -1.7419488430023193
# 2021-04-22T19:52:08.426 DEBUG mmfunctions.anomaly._calc Epoch: 270, neg ELBO: -1.7449829578399658
# 2021-04-22T19:52:09.817 DEBUG mmfunctions.anomaly._calc Epoch: 280, neg ELBO: -1.7434515953063965
# 2021-04-22T19:52:11.256 DEBUG mmfunctions.anomaly._calc Epoch: 290, neg ELBO: -1.7459408044815063
# 2021-04-22T19:52:12.661 DEBUG mmfunctions.anomaly._calc Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-04-22T19:52:13.414 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# 2021-04-22T19:52:13.498 DEBUG mmfunctions.anomaly._calc VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'> for entity 04714B601096
# 2021-04-22T19:52:13.499 DEBUG mmfunctions.anomaly._calc ['speed']
# 2021-04-22T19:52:13.501 ERROR mmfunctions.anomaly.load_model Model retrieval failed with name 'db' is not defined
# 2021-04-22T19:52:13.506 INFO mmfunctions.anomaly._calc Adjusting target mean with 0.1884576555496548
# 2021-04-22T19:52:13.512 DEBUG mmfunctions.anomaly._calc Training VI model 1 for entity: 04714B601096Prior mean: 0.0, sigma: 0.21192706287219493
# 2021-04-22T19:52:13.518 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([9415, 1]) Sigma: torch.Size([9415, 1]) loglikelihood: torch.Size([9415, 1]) KL value: tensor(-0.9028, grad_fn=<MeanBackward0>)
# 2021-04-22T19:52:13.520 DEBUG mmfunctions.anomaly._calc Epoch: 0, neg ELBO: 1.8089207410812378
# 2021-04-22T19:52:13.649 DEBUG mmfunctions.anomaly._calc Epoch: 10, neg ELBO: 0.6641601920127869
# 2021-04-22T19:52:13.775 DEBUG mmfunctions.anomaly._calc Epoch: 20, neg ELBO: -0.105905681848526
# 2021-04-22T19:52:13.911 DEBUG mmfunctions.anomaly._calc Epoch: 30, neg ELBO: -0.17004498839378357
# 2021-04-22T19:52:14.083 DEBUG mmfunctions.anomaly._calc Epoch: 40, neg ELBO: -0.2044263333082199
# 2021-04-22T19:52:14.275 DEBUG mmfunctions.anomaly._calc Epoch: 50, neg ELBO: -0.19918373227119446
# 2021-04-22T19:52:14.485 DEBUG mmfunctions.anomaly._calc Epoch: 60, neg ELBO: -0.21438361704349518
# 2021-04-22T19:52:14.700 DEBUG mmfunctions.anomaly._calc Epoch: 70, neg ELBO: -0.21807099878787994
# 2021-04-22T19:52:14.888 DEBUG mmfunctions.anomaly._calc Epoch: 80, neg ELBO: -0.22220920026302338
# 2021-04-22T19:52:15.069 DEBUG mmfunctions.anomaly._calc Epoch: 90, neg ELBO: -0.2200239896774292
# 2021-04-22T19:52:15.255 DEBUG mmfunctions.anomaly._calc Epoch: 100, neg ELBO: -0.213107168674469
# 2021-04-22T19:52:15.453 DEBUG mmfunctions.anomaly._calc Epoch: 110, neg ELBO: -0.20441195368766785
# 2021-04-22T19:52:15.659 DEBUG mmfunctions.anomaly._calc Epoch: 120, neg ELBO: -0.21888287365436554
# 2021-04-22T19:52:15.866 DEBUG mmfunctions.anomaly._calc Epoch: 130, neg ELBO: -0.2133471965789795
# 2021-04-22T19:52:16.069 DEBUG mmfunctions.anomaly._calc Epoch: 140, neg ELBO: -0.2135758101940155
# 2021-04-22T19:52:16.277 DEBUG mmfunctions.anomaly._calc Epoch: 150, neg ELBO: -0.21161212027072906
# 2021-04-22T19:52:16.473 DEBUG mmfunctions.anomaly._calc Epoch: 160, neg ELBO: -0.21515725553035736
# 2021-04-22T19:52:16.674 DEBUG mmfunctions.anomaly._calc Epoch: 170, neg ELBO: -0.21356989443302155
# 2021-04-22T19:52:16.867 DEBUG mmfunctions.anomaly._calc Epoch: 180, neg ELBO: -0.19879944622516632
# 2021-04-22T19:52:17.073 DEBUG mmfunctions.anomaly._calc Epoch: 190, neg ELBO: -0.21181267499923706
# 2021-04-22T19:52:17.268 DEBUG mmfunctions.anomaly._calc Epoch: 200, neg ELBO: -0.2103336900472641
# 2021-04-22T19:52:17.467 DEBUG mmfunctions.anomaly._calc Epoch: 210, neg ELBO: -0.2112797498703003
# 2021-04-22T19:52:17.660 DEBUG mmfunctions.anomaly._calc Epoch: 220, neg ELBO: -0.1884455382823944
# 2021-04-22T19:52:17.851 DEBUG mmfunctions.anomaly._calc Epoch: 230, neg ELBO: -0.22184525430202484
# 2021-04-22T19:52:18.049 DEBUG mmfunctions.anomaly._calc Epoch: 240, neg ELBO: -0.2203766256570816
# 2021-04-22T19:52:18.244 DEBUG mmfunctions.anomaly._calc Epoch: 250, neg ELBO: -0.20849324762821198
# 2021-04-22T19:52:18.440 DEBUG mmfunctions.anomaly._calc Epoch: 260, neg ELBO: -0.20875126123428345
# 2021-04-22T19:52:18.634 DEBUG mmfunctions.anomaly._calc Epoch: 270, neg ELBO: -0.21688058972358704
# 2021-04-22T19:52:18.831 DEBUG mmfunctions.anomaly._calc Epoch: 280, neg ELBO: -0.2146449089050293
# 2021-04-22T19:52:19.033 DEBUG mmfunctions.anomaly._calc Epoch: 290, neg ELBO: -0.21065044403076172
# 2021-04-22T19:52:19.237 DEBUG mmfunctions.anomaly._calc Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-04-22T19:52:20.134 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16640 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# 2021-04-22T19:52:20.159 DEBUG mmfunctions.anomaly._calc VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'> for entity 04714B601096
# 2021-04-22T19:52:20.161 DEBUG mmfunctions.anomaly._calc ['speed']
# 2021-04-22T19:52:20.165 ERROR mmfunctions.anomaly.load_model Model retrieval failed with name 'db' is not defined
# 2021-04-22T19:52:20.171 INFO mmfunctions.anomaly._calc Adjusting target mean with 0.053920236118059024
# 2021-04-22T19:52:20.177 DEBUG mmfunctions.anomaly._calc Training VI model 1 for entity: 04714B601096Prior mean: 0.0, sigma: 0.06744427763350297
# 2021-04-22T19:52:20.183 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([9995, 1]) Sigma: torch.Size([9995, 1]) loglikelihood: torch.Size([9995, 1]) KL value: tensor(-6.9960, grad_fn=<MeanBackward0>)
# 2021-04-22T19:52:20.185 DEBUG mmfunctions.anomaly._calc Epoch: 0, neg ELBO: 8.01889419555664
# 2021-04-22T19:52:20.307 DEBUG mmfunctions.anomaly._calc Epoch: 10, neg ELBO: 4.062219619750977
# 2021-04-22T19:52:20.437 DEBUG mmfunctions.anomaly._calc Epoch: 20, neg ELBO: -0.1540919989347458
# 2021-04-22T19:52:20.560 DEBUG mmfunctions.anomaly._calc Epoch: 30, neg ELBO: -0.6049654483795166
# 2021-04-22T19:52:20.689 DEBUG mmfunctions.anomaly._calc Epoch: 40, neg ELBO: -0.8196073770523071
# 2021-04-22T19:52:20.836 DEBUG mmfunctions.anomaly._calc Epoch: 50, neg ELBO: -0.8332322239875793
# 2021-04-22T19:52:20.985 DEBUG mmfunctions.anomaly._calc Epoch: 60, neg ELBO: -0.8304246664047241
# 2021-04-22T19:52:21.132 DEBUG mmfunctions.anomaly._calc Epoch: 70, neg ELBO: -0.8302499651908875
# 2021-04-22T19:52:21.280 DEBUG mmfunctions.anomaly._calc Epoch: 80, neg ELBO: -0.828011155128479
# 2021-04-22T19:52:21.427 DEBUG mmfunctions.anomaly._calc Epoch: 90, neg ELBO: -0.8277048468589783
# 2021-04-22T19:52:21.576 DEBUG mmfunctions.anomaly._calc Epoch: 100, neg ELBO: -0.832368016242981
# 2021-04-22T19:52:21.728 DEBUG mmfunctions.anomaly._calc Epoch: 110, neg ELBO: -0.8376538157463074
# 2021-04-22T19:52:21.893 DEBUG mmfunctions.anomaly._calc Epoch: 120, neg ELBO: -0.8485639095306396
# 2021-04-22T19:52:22.054 DEBUG mmfunctions.anomaly._calc Epoch: 130, neg ELBO: -0.8417963981628418
# 2021-04-22T19:52:22.208 DEBUG mmfunctions.anomaly._calc Epoch: 140, neg ELBO: -0.8366979360580444
# 2021-04-22T19:52:22.379 DEBUG mmfunctions.anomaly._calc Epoch: 150, neg ELBO: -0.8490670919418335
# 2021-04-22T19:52:22.577 DEBUG mmfunctions.anomaly._calc Epoch: 160, neg ELBO: -0.8372915983200073
# 2021-04-22T19:52:22.794 DEBUG mmfunctions.anomaly._calc Epoch: 170, neg ELBO: -0.8417097330093384
# 2021-04-22T19:52:23.021 DEBUG mmfunctions.anomaly._calc Epoch: 180, neg ELBO: -0.8313440680503845
# 2021-04-22T19:52:23.250 DEBUG mmfunctions.anomaly._calc Epoch: 190, neg ELBO: -0.8356417417526245
# 2021-04-22T19:52:23.478 DEBUG mmfunctions.anomaly._calc Epoch: 200, neg ELBO: -0.8354628682136536
# 2021-04-22T19:52:23.689 DEBUG mmfunctions.anomaly._calc Epoch: 210, neg ELBO: -0.8402969837188721
# 2021-04-22T19:52:23.899 DEBUG mmfunctions.anomaly._calc Epoch: 220, neg ELBO: -0.8460313081741333
# 2021-04-22T19:52:24.111 DEBUG mmfunctions.anomaly._calc Epoch: 230, neg ELBO: -0.8442137241363525
# 2021-04-22T19:52:24.344 DEBUG mmfunctions.anomaly._calc Epoch: 240, neg ELBO: -0.8341280221939087
# 2021-04-22T19:52:24.553 DEBUG mmfunctions.anomaly._calc Epoch: 250, neg ELBO: -0.8302322030067444
# 2021-04-22T19:52:24.742 DEBUG mmfunctions.anomaly._calc Epoch: 260, neg ELBO: -0.8438490629196167
# 2021-04-22T19:52:24.962 DEBUG mmfunctions.anomaly._calc Epoch: 270, neg ELBO: -0.8480609655380249
# 2021-04-22T19:52:25.188 DEBUG mmfunctions.anomaly._calc Epoch: 280, neg ELBO: -0.846378743648529
# 2021-04-22T19:52:25.355 DEBUG mmfunctions.anomaly._calc Epoch: 290, neg ELBO: -0.8375763893127441
# 2021-04-22T19:52:25.526 DEBUG mmfunctions.anomaly._calc Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-04-22T19:52:26.379 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# 2021-04-22T19:52:26.403 DEBUG mmfunctions.anomaly._calc VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'> for entity 04714B601096
# 2021-04-22T19:52:26.405 DEBUG mmfunctions.anomaly._calc ['speed']
# 2021-04-22T19:52:26.408 ERROR mmfunctions.anomaly.load_model Model retrieval failed with name 'db' is not defined
# 2021-04-22T19:52:26.415 INFO mmfunctions.anomaly._calc Adjusting target mean with 0.015249440208333333
# 2021-04-22T19:52:26.446 DEBUG mmfunctions.anomaly._calc Training VI model 1 for entity: 04714B601096Prior mean: 0.0, sigma: 0.006453133325510831
# 2021-04-22T19:52:26.477 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([86400, 1]) Sigma: torch.Size([86400, 1]) loglikelihood: torch.Size([86400, 1]) KL value: tensor(-56.1180, grad_fn=<MeanBackward0>)
# 2021-04-22T19:52:26.478 DEBUG mmfunctions.anomaly._calc Epoch: 0, neg ELBO: 56.899658203125
# 2021-04-22T19:52:27.228 DEBUG mmfunctions.anomaly._calc Epoch: 10, neg ELBO: 19.418380737304688
# 2021-04-22T19:52:28.247 DEBUG mmfunctions.anomaly._calc Epoch: 20, neg ELBO: -0.4565531015396118
# 2021-04-22T19:52:29.402 DEBUG mmfunctions.anomaly._calc Epoch: 30, neg ELBO: -1.9444787502288818
# 2021-04-22T19:52:30.406 DEBUG mmfunctions.anomaly._calc Epoch: 40, neg ELBO: -1.9349522590637207
# 2021-04-22T19:52:31.400 DEBUG mmfunctions.anomaly._calc Epoch: 50, neg ELBO: -2.023587226867676
# 2021-04-22T19:52:32.571 DEBUG mmfunctions.anomaly._calc Epoch: 60, neg ELBO: -2.0430614948272705
# 2021-04-22T19:52:33.760 DEBUG mmfunctions.anomaly._calc Epoch: 70, neg ELBO: -2.0441553592681885
# 2021-04-22T19:52:34.859 DEBUG mmfunctions.anomaly._calc Epoch: 80, neg ELBO: -2.0427112579345703
# 2021-04-22T19:52:36.119 DEBUG mmfunctions.anomaly._calc Epoch: 90, neg ELBO: -2.045569658279419
# 2021-04-22T19:52:37.273 DEBUG mmfunctions.anomaly._calc Epoch: 100, neg ELBO: -2.0442333221435547
# 2021-04-22T19:52:38.404 DEBUG mmfunctions.anomaly._calc Epoch: 110, neg ELBO: -2.048516273498535
# 2021-04-22T19:52:39.582 DEBUG mmfunctions.anomaly._calc Epoch: 120, neg ELBO: -2.048414468765259
# 2021-04-22T19:52:40.607 DEBUG mmfunctions.anomaly._calc Epoch: 130, neg ELBO: -2.043560743331909
# 2021-04-22T19:52:41.656 DEBUG mmfunctions.anomaly._calc Epoch: 140, neg ELBO: -2.0477452278137207
# 2021-04-22T19:52:42.805 DEBUG mmfunctions.anomaly._calc Epoch: 150, neg ELBO: -2.046213388442993
# 2021-04-22T19:52:43.949 DEBUG mmfunctions.anomaly._calc Epoch: 160, neg ELBO: -2.0460610389709473
# 2021-04-22T19:52:45.007 DEBUG mmfunctions.anomaly._calc Epoch: 170, neg ELBO: -2.0445637702941895
# 2021-04-22T19:52:46.073 DEBUG mmfunctions.anomaly._calc Epoch: 180, neg ELBO: -2.0457346439361572
# 2021-04-22T19:52:47.249 DEBUG mmfunctions.anomaly._calc Epoch: 190, neg ELBO: -2.0469374656677246
# 2021-04-22T19:52:48.265 DEBUG mmfunctions.anomaly._calc Epoch: 200, neg ELBO: -2.0441668033599854
# 2021-04-22T19:52:49.236 DEBUG mmfunctions.anomaly._calc Epoch: 210, neg ELBO: -2.042543649673462
# 2021-04-22T19:52:50.212 DEBUG mmfunctions.anomaly._calc Epoch: 220, neg ELBO: -2.0482521057128906
# 2021-04-22T19:52:51.320 DEBUG mmfunctions.anomaly._calc Epoch: 230, neg ELBO: -2.0487923622131348
# 2021-04-22T19:52:52.763 DEBUG mmfunctions.anomaly._calc Epoch: 240, neg ELBO: -2.0480918884277344
# 2021-04-22T19:52:53.891 DEBUG mmfunctions.anomaly._calc Epoch: 250, neg ELBO: -2.0445315837860107
# 2021-04-22T19:52:54.926 DEBUG mmfunctions.anomaly._calc Epoch: 260, neg ELBO: -2.0458247661590576
# 2021-04-22T19:52:55.929 DEBUG mmfunctions.anomaly._calc Epoch: 270, neg ELBO: -2.0463616847991943
# 2021-04-22T19:52:57.055 DEBUG mmfunctions.anomaly._calc Epoch: 280, neg ELBO: -2.0460379123687744
# 2021-04-22T19:52:58.097 DEBUG mmfunctions.anomaly._calc Epoch: 290, neg ELBO: -2.0491459369659424
# 2021-04-22T19:52:59.045 DEBUG mmfunctions.anomaly._calc Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-04-22T19:52:59.882 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16640 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# 2021-04-22T19:53:04.337 DEBUG mmfunctions.anomaly.execute Scoring done
# CPU times: user 22min 48s, sys: 36.4 s, total: 23min 24s
# Wall time: 4min 8s
#                rms_x          rms_z          rms_y          power  \
# count  861165.000000  861165.000000  861165.000000  861165.000000
# mean        0.076957       0.293800       0.783084       5.998290
# std         0.087492       0.388257       0.427317       8.171752
# min         0.004989       0.010101       0.007598       0.000000
# 25%         0.015818       0.043151       0.956483       0.000000
# 50%         0.045733       0.097804       1.042373       1.742200
# 75%         0.084654       0.165243       1.044580      18.661800
# max         0.580223       1.044346       1.078255      43.012794
#
#                speed  predicted_rms_x  pred_dev_rms_x
# count  861165.000000    861165.000000   861165.000000
# mean      634.447573         0.076377        0.082959
# std       579.508187         0.076161        0.101136
# min         0.000000         0.006038       -0.021779
# 25%         0.000000         0.014132        0.037553
# 50%      1059.000000         0.048518        0.039054
# 75%      1147.000000         0.081355        0.052721
# max      3600.000000         0.470344        0.517661

# %%
# %%time
print('Train and evaluate model for ' + df_i.index.levels[0].values)
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsiy = VIAnomalyScore(['speed'], ['rms_y'])
#spsiy.epochs = 1  # only for testing model storage
spsiy.epochs = 300

spsiy.auto_train = True
spsiy.delete_model = delete_model
ety = spsiy._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
ety.name = 'IOT_SHADOW_PUMP_DE_GEN5'

spsiy._entity_type = ety
df_i = spsiy.execute(df=df_i)

EngineLogging.configure_console_logging(logging.INFO)
df_i.describe()
# Out:
# ['Train and evaluate model for 04714B601096'
#  'Train and evaluate model for 04714B603408'
#  'Train and evaluate model for 04714B6036B1'
#  'Train and evaluate model for 04714B6037F8'
#  'Train and evaluate model for 04714B60382B'
#  'Train and evaluate model for 04714B604101'
#  'Train and evaluate model for 04714B60553A'
#  'Train and evaluate model for 04714B605699'
#  'Train and evaluate model for 04714B606390']
# 2021-02-23T15:51:59.338 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2021-02-23T15:51:59.339 DEBUG root.__init__ __init__VIAnomalyScore
# 2021-02-23T15:51:59.339 DEBUG root.__init__ __init__ done with parameters: speed.rms_y
# 2021-02-23T15:51:59.340 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 0.0.1
# 2021-02-23T15:51:59.340 DEBUG iotfunctions.util.__init__ Starting trace
# 2021-02-23T15:51:59.341 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20210223145159
# 2021-02-23T15:51:59.341 DEBUG iotfunctions.util.__init__ auto_save None
# 2021-02-23T15:51:59.342 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2021-02-23T15:51:59.342 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2021-02-23T15:51:59.343 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# 2021-02-23T15:51:59.364 DEBUG mmfunctions.anomaly.execute VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'>
# 2021-02-23T15:51:59.365 DEBUG mmfunctions.anomaly.execute ['04714B601096' '04714B603408' '04714B6036B1' '04714B6037F8'
#  '04714B60382B' '04714B604101' '04714B60553A' '04714B605699'
#  '04714B606390']
# ['speed']
# 2021-02-23T15:52:00.507 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B601096 of size 16634 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:00.510 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:00.562 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.9648271186706371
# ['speed']
# 2021-02-23T15:52:01.543 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B603408 of size 16638 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:01.552 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:01.610 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0517420700729927
# ['speed']
# 2021-02-23T15:52:02.703 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B6036B1 of size 16642 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:02.705 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:02.743 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0439549532907022
# ['speed']
# 2021-02-23T15:52:03.783 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B6037F8 of size 16642 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:03.790 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:03.852 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0441421700323505
# ['speed']
# 2021-02-23T15:52:04.892 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B60382B does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:04.894 INFO mmfunctions.anomaly.execute load model None
# 2021-02-23T15:52:04.950 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0073426544817226
# 2021-02-23T15:52:04.953 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B60382BPrior mean: 0.0, sigma: 0.0010110001999518326
# 2021-02-23T15:52:04.957 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([9985, 1]) Sigma: torch.Size([9985, 1]) loglikelihood: torch.Size([9985, 1]) KL value: tensor(-598.3000, grad_fn=<MeanBackward0>)
# 2021-02-23T15:52:04.958 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([9985, 1]) Sigma: torch.Size([9985, 1]) loglikelihood: torch.Size([9985, 1]) KL: torch.Size([]) KL value: tensor(223.0067, grad_fn=<MulBackward0>)
# 2021-02-23T15:52:04.959 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 599.3150024414062 neg ELBO G: 224.51026916503906
# 2021-02-23T15:52:05.051 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 291.0631408691406 neg ELBO G: 734.4010009765625
# 2021-02-23T15:52:05.144 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 31.18524742126465 neg ELBO G: 9281.76953125
# 2021-02-23T15:52:05.232 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.1010756492614746 neg ELBO G: 24518.724609375
# 2021-02-23T15:52:05.317 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -2.723978042602539 neg ELBO G: 34707.4921875
# 2021-02-23T15:52:05.405 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -2.8175880908966064 neg ELBO G: 39106.6875
# 2021-02-23T15:52:05.493 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -2.900254249572754 neg ELBO G: 40858.38671875
# 2021-02-23T15:52:05.571 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -2.946669340133667 neg ELBO G: 41547.625
# 2021-02-23T15:52:05.663 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -2.974048137664795 neg ELBO G: 41858.7734375
# 2021-02-23T15:52:05.751 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -2.9697682857513428 neg ELBO G: 42047.3125
# 2021-02-23T15:52:05.835 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -2.9732165336608887 neg ELBO G: 42201.95703125
# 2021-02-23T15:52:05.913 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -2.967862844467163 neg ELBO G: 42352.1484375
# 2021-02-23T15:52:05.992 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -2.985954999923706 neg ELBO G: 42506.9296875
# 2021-02-23T15:52:06.075 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -2.9852986335754395 neg ELBO G: 42668.6171875
# 2021-02-23T15:52:06.154 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -2.9713213443756104 neg ELBO G: 42837.18359375
# 2021-02-23T15:52:06.232 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -2.973757028579712 neg ELBO G: 43009.9375
# 2021-02-23T15:52:06.316 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -2.9759531021118164 neg ELBO G: 43186.703125
# 2021-02-23T15:52:06.394 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -2.984333038330078 neg ELBO G: 43366.4375
# 2021-02-23T15:52:06.473 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -2.9856314659118652 neg ELBO G: 43548.95703125
# 2021-02-23T15:52:06.554 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -2.975799560546875 neg ELBO G: 43731.9296875
# 2021-02-23T15:52:06.634 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -2.9884822368621826 neg ELBO G: 43913.80859375
# 2021-02-23T15:52:06.717 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -2.9871513843536377 neg ELBO G: 44097.3984375
# 2021-02-23T15:52:06.796 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -2.961221933364868 neg ELBO G: 44278.59765625
# 2021-02-23T15:52:06.878 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -2.796212911605835 neg ELBO G: 43438.2578125
# 2021-02-23T15:52:06.960 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -2.9714016914367676 neg ELBO G: 42511.1875
# 2021-02-23T15:52:07.048 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -2.978126287460327 neg ELBO G: 42183.36328125
# 2021-02-23T15:52:07.125 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -2.983856678009033 neg ELBO G: 42204.3828125
# 2021-02-23T15:52:07.213 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -2.9777486324310303 neg ELBO G: 42394.3125
# 2021-02-23T15:52:07.306 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -2.9952456951141357 neg ELBO G: 42655.5390625
# 2021-02-23T15:52:07.386 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -2.9935808181762695 neg ELBO G: 42943.8359375
# 2021-02-23T15:52:07.473 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:08.905 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B60382B of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-23T15:52:09.825 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B604101 of size 16642 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:09.828 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:09.866 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.025699096582703612
# ['speed']
# 2021-02-23T15:52:10.750 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B60553A does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:10.753 INFO mmfunctions.anomaly.execute load model None
# 2021-02-23T15:52:10.815 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0192036036112586
# 2021-02-23T15:52:10.818 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B60553APrior mean: 0.0, sigma: 0.0193266264041326
# 2021-02-23T15:52:10.821 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([9415, 1]) Sigma: torch.Size([9415, 1]) loglikelihood: torch.Size([9415, 1]) KL value: tensor(-26.7316, grad_fn=<MeanBackward0>)
# 2021-02-23T15:52:10.823 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([9415, 1]) Sigma: torch.Size([9415, 1]) loglikelihood: torch.Size([9415, 1]) KL: torch.Size([]) KL value: tensor(26.6759, grad_fn=<MulBackward0>)
# 2021-02-23T15:52:10.824 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 27.70065689086914 neg ELBO G: 28.156341552734375
# 2021-02-23T15:52:10.902 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 18.441143035888672 neg ELBO G: 154.08213806152344
# 2021-02-23T15:52:10.985 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 6.512997150421143 neg ELBO G: 2235.54638671875
# 2021-02-23T15:52:11.062 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -0.6498714685440063 neg ELBO G: 11296.9140625
# 2021-02-23T15:52:11.133 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.4570250511169434 neg ELBO G: 22726.64453125
# 2021-02-23T15:52:11.214 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.5045653581619263 neg ELBO G: 29670.0
# 2021-02-23T15:52:11.290 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.5089499950408936 neg ELBO G: 32708.658203125
# 2021-02-23T15:52:11.366 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.5311312675476074 neg ELBO G: 33588.05859375
# 2021-02-23T15:52:11.446 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.5180861949920654 neg ELBO G: 33590.484375
# 2021-02-23T15:52:11.560 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.5332746505737305 neg ELBO G: 33354.36328125
# 2021-02-23T15:52:11.650 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.5151795148849487 neg ELBO G: 33123.15625
# 2021-02-23T15:52:11.734 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.5165181159973145 neg ELBO G: 32963.33203125
# 2021-02-23T15:52:11.816 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.517351508140564 neg ELBO G: 32880.8046875
# 2021-02-23T15:52:11.905 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.5324358940124512 neg ELBO G: 32861.328125
# 2021-02-23T15:52:11.984 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.5245957374572754 neg ELBO G: 32883.05078125
# 2021-02-23T15:52:12.057 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.5255811214447021 neg ELBO G: 32930.4375
# 2021-02-23T15:52:12.131 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.5219002962112427 neg ELBO G: 32997.515625
# 2021-02-23T15:52:12.202 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.5251543521881104 neg ELBO G: 33004.98046875
# 2021-02-23T15:52:12.282 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.5285273790359497 neg ELBO G: 32974.51171875
# 2021-02-23T15:52:12.355 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.535152554512024 neg ELBO G: 33002.53125
# 2021-02-23T15:52:12.437 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.5254456996917725 neg ELBO G: 33075.984375
# 2021-02-23T15:52:12.520 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.5188215970993042 neg ELBO G: 33169.5703125
# 2021-02-23T15:52:12.599 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.5251327753067017 neg ELBO G: 33266.6328125
# 2021-02-23T15:52:12.670 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.525550127029419 neg ELBO G: 33359.61328125
# 2021-02-23T15:52:12.740 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.5221997499465942 neg ELBO G: 33444.55859375
# 2021-02-23T15:52:12.810 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.522523045539856 neg ELBO G: 33511.9296875
# 2021-02-23T15:52:12.887 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.516192078590393 neg ELBO G: 33399.84765625
# 2021-02-23T15:52:12.973 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.5313564538955688 neg ELBO G: 33329.80078125
# 2021-02-23T15:52:13.044 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.523470401763916 neg ELBO G: 33353.1015625
# 2021-02-23T15:52:13.115 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.5340726375579834 neg ELBO G: 33425.1953125
# 2021-02-23T15:52:13.183 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:15.225 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B60553A of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-23T15:52:16.286 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B605699 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:16.287 INFO mmfunctions.anomaly.execute load model None
# 2021-02-23T15:52:16.325 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.9931498748374186
# 2021-02-23T15:52:16.329 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B605699Prior mean: 0.0, sigma: 0.0034573855863048253
# 2021-02-23T15:52:16.333 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([9995, 1]) Sigma: torch.Size([9995, 1]) loglikelihood: torch.Size([9995, 1]) KL value: tensor(-118.3203, grad_fn=<MeanBackward0>)
# 2021-02-23T15:52:16.335 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([9995, 1]) Sigma: torch.Size([9995, 1]) loglikelihood: torch.Size([9995, 1]) KL: torch.Size([]) KL value: tensor(89.1471, grad_fn=<MulBackward0>)
# 2021-02-23T15:52:16.335 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 119.15357971191406 neg ELBO G: 90.47647857666016
# 2021-02-23T15:52:16.434 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 81.45252990722656 neg ELBO G: 741.1016845703125
# 2021-02-23T15:52:16.543 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 22.86034393310547 neg ELBO G: 5481.3876953125
# 2021-02-23T15:52:16.659 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: 0.16494561731815338 neg ELBO G: 17870.255859375
# 2021-02-23T15:52:16.753 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.586877465248108 neg ELBO G: 29167.96484375
# 2021-02-23T15:52:16.845 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -2.239860773086548 neg ELBO G: 33111.890625
# 2021-02-23T15:52:16.932 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -2.2949962615966797 neg ELBO G: 34531.25390625
# 2021-02-23T15:52:17.014 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -2.3258094787597656 neg ELBO G: 35144.11328125
# 2021-02-23T15:52:17.092 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -2.351210355758667 neg ELBO G: 35454.2265625
# 2021-02-23T15:52:17.172 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -2.3492398262023926 neg ELBO G: 35711.26171875
# 2021-02-23T15:52:17.253 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -2.3518126010894775 neg ELBO G: 35986.9296875
# 2021-02-23T15:52:17.334 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -2.3735239505767822 neg ELBO G: 36202.640625
# 2021-02-23T15:52:17.415 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -2.3598177433013916 neg ELBO G: 36487.65234375
# 2021-02-23T15:52:17.497 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -2.3712127208709717 neg ELBO G: 36679.74609375
# 2021-02-23T15:52:17.575 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -2.3703207969665527 neg ELBO G: 36655.91015625
# 2021-02-23T15:52:17.655 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -2.3766157627105713 neg ELBO G: 37035.91015625
# 2021-02-23T15:52:17.732 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -2.3754994869232178 neg ELBO G: 37466.62890625
# 2021-02-23T15:52:17.824 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -2.389322280883789 neg ELBO G: 37746.51953125
# 2021-02-23T15:52:17.910 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -2.3815953731536865 neg ELBO G: 38135.51953125
# 2021-02-23T15:52:17.991 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -2.382282257080078 neg ELBO G: 38435.8984375
# 2021-02-23T15:52:18.068 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -2.3649425506591797 neg ELBO G: 38713.12890625
# 2021-02-23T15:52:18.149 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -2.3748390674591064 neg ELBO G: 38893.2265625
# 2021-02-23T15:52:18.228 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -2.386322021484375 neg ELBO G: 39046.51953125
# 2021-02-23T15:52:18.311 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -2.378648042678833 neg ELBO G: 39330.30859375
# 2021-02-23T15:52:18.398 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -2.3906147480010986 neg ELBO G: 39572.83203125
# 2021-02-23T15:52:18.479 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -2.3939685821533203 neg ELBO G: 39856.88671875
# 2021-02-23T15:52:18.566 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -2.3904175758361816 neg ELBO G: 40139.31640625
# 2021-02-23T15:52:18.651 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -2.394331455230713 neg ELBO G: 40367.46875
# 2021-02-23T15:52:18.734 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -2.3835034370422363 neg ELBO G: 40460.25
# 2021-02-23T15:52:18.824 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -2.3877155780792236 neg ELBO G: 40448.109375
# 2021-02-23T15:52:18.903 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:19.783 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B605699 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-23T15:52:21.014 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B606390 of size 16638 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:21.024 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:21.077 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.020761343411188005
# CPU times: user 48.4 s, sys: 186 ms, total: 48.6 s
# Wall time: 22 s
#                rms_x          rms_z          rms_y          power  \
# count  861165.000000  861165.000000  861165.000000  861165.000000
# mean        0.076957       0.293800       0.783084       5.998290
# std         0.087492       0.388257       0.427317       8.171752
# min         0.004989       0.010101       0.007598       0.000000
# 25%         0.015818       0.043151       0.956483       0.000000
# 50%         0.045733       0.097804       1.042373       1.742200
# 75%         0.084654       0.165243       1.044580      18.661800
# max         0.580223       1.044346       1.078255      43.012794
#
#                speed
# count  861165.000000
# mean      634.447573
# std       579.508187
# min         0.000000
# 25%         0.000000
# 50%      1059.000000
# 75%      1147.000000
# max      3600.000000

# %%
# %%time
print('Train and evaluate model for ' + df_i.index.levels[0].values)
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsiz = VIAnomalyScore(['speed'], ['rms_z'])
#spsiz.epochs = 1  # only for testing model storage
spsiz.epochs = 300

spsiz.auto_train = True
spsiz.delete_model = delete_model
etz = spsiz._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
etz.name = 'IOT_SHADOW_PUMP_DE_GEN5'

spsiz._entity_type = etz
df_i = spsiz.execute(df=df_i)

EngineLogging.configure_console_logging(logging.INFO)
df_i.describe()
# Out:
# ['Train and evaluate model for 04714B601096'
#  'Train and evaluate model for 04714B603408'
#  'Train and evaluate model for 04714B6036B1'
#  'Train and evaluate model for 04714B6037F8'
#  'Train and evaluate model for 04714B60382B'
#  'Train and evaluate model for 04714B604101'
#  'Train and evaluate model for 04714B60553A'
#  'Train and evaluate model for 04714B605699'
#  'Train and evaluate model for 04714B606390']
# 2021-02-23T15:52:30.198 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2021-02-23T15:52:30.199 DEBUG root.__init__ __init__VIAnomalyScore
# 2021-02-23T15:52:30.199 DEBUG root.__init__ __init__ done with parameters: speed.rms_z
# 2021-02-23T15:52:30.200 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 0.0.1
# 2021-02-23T15:52:30.200 DEBUG iotfunctions.util.__init__ Starting trace
# 2021-02-23T15:52:30.201 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20210223145230
# 2021-02-23T15:52:30.201 DEBUG iotfunctions.util.__init__ auto_save None
# 2021-02-23T15:52:30.202 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2021-02-23T15:52:30.202 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2021-02-23T15:52:30.202 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# 2021-02-23T15:52:30.230 DEBUG mmfunctions.anomaly.execute VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'>
# 2021-02-23T15:52:30.231 DEBUG mmfunctions.anomaly.execute ['04714B601096' '04714B603408' '04714B6036B1' '04714B6037F8'
#  '04714B60382B' '04714B604101' '04714B60553A' '04714B605699'
#  '04714B606390']
# ['speed']
# 2021-02-23T15:52:31.202 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B601096 of size 16636 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:31.208 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:31.290 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.08704876804697158
# ['speed']
# 2021-02-23T15:52:32.243 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B603408 of size 16642 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:32.245 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:32.280 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.04058445240762745
# ['speed']
# 2021-02-23T15:52:33.139 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B6036B1 of size 16640 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:33.141 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:33.177 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.01657187418934978
# ['speed']
# 2021-02-23T15:52:34.131 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B6037F8 of size 16642 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:34.138 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:34.200 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.11003280906274207
# ['speed']
# 2021-02-23T15:52:35.180 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B60382B does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:35.181 INFO mmfunctions.anomaly.execute load model None
# 2021-02-23T15:52:35.218 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.09411398938407611
# 2021-02-23T15:52:35.221 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B60382BPrior mean: 0.0, sigma: 0.007828151516938445
# 2021-02-23T15:52:35.225 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([9985, 1]) Sigma: torch.Size([9985, 1]) loglikelihood: torch.Size([9985, 1]) KL value: tensor(-43.8130, grad_fn=<MeanBackward0>)
# 2021-02-23T15:52:35.227 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([9985, 1]) Sigma: torch.Size([9985, 1]) loglikelihood: torch.Size([9985, 1]) KL: torch.Size([]) KL value: tensor(412.4050, grad_fn=<MulBackward0>)
# 2021-02-23T15:52:35.227 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 44.57907485961914 neg ELBO G: 413.64630126953125
# 2021-02-23T15:52:35.308 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 11.43143367767334 neg ELBO G: 4470.654296875
# 2021-02-23T15:52:35.383 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: -0.7032393217086792 neg ELBO G: 17804.26953125
# 2021-02-23T15:52:35.462 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.7708969116210938 neg ELBO G: 28080.369140625
# 2021-02-23T15:52:35.549 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.9038628339767456 neg ELBO G: 31701.4296875
# 2021-02-23T15:52:35.626 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.9142076969146729 neg ELBO G: 32911.6796875
# 2021-02-23T15:52:35.707 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.9202158451080322 neg ELBO G: 33113.3125
# 2021-02-23T15:52:35.788 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.9189655780792236 neg ELBO G: 32887.71484375
# 2021-02-23T15:52:35.866 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.916890025138855 neg ELBO G: 32556.408203125
# 2021-02-23T15:52:35.942 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.9230934381484985 neg ELBO G: 32267.005859375
# 2021-02-23T15:52:36.018 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.9314959049224854 neg ELBO G: 32057.724609375
# 2021-02-23T15:52:36.099 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.917236566543579 neg ELBO G: 31924.455078125
# 2021-02-23T15:52:36.173 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.9269310235977173 neg ELBO G: 31845.5078125
# 2021-02-23T15:52:36.248 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.9341038465499878 neg ELBO G: 31808.580078125
# 2021-02-23T15:52:36.325 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.935520887374878 neg ELBO G: 31801.0703125
# 2021-02-23T15:52:36.405 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.9188464879989624 neg ELBO G: 31800.888671875
# 2021-02-23T15:52:36.486 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.9105491638183594 neg ELBO G: 31798.59765625
# 2021-02-23T15:52:36.563 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.9257581233978271 neg ELBO G: 31790.38671875
# 2021-02-23T15:52:36.633 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.922811508178711 neg ELBO G: 31785.8828125
# 2021-02-23T15:52:36.703 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.9289451837539673 neg ELBO G: 31783.875
# 2021-02-23T15:52:36.773 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.9327677488327026 neg ELBO G: 31787.484375
# 2021-02-23T15:52:36.848 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.9186737537384033 neg ELBO G: 31787.869140625
# 2021-02-23T15:52:36.927 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.9210528135299683 neg ELBO G: 31786.337890625
# 2021-02-23T15:52:37.004 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.9247456789016724 neg ELBO G: 31790.69140625
# 2021-02-23T15:52:37.077 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.9260932207107544 neg ELBO G: 31793.431640625
# 2021-02-23T15:52:37.154 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.9291728734970093 neg ELBO G: 31793.921875
# 2021-02-23T15:52:37.232 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.9245954751968384 neg ELBO G: 31802.658203125
# 2021-02-23T15:52:37.312 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.9179834127426147 neg ELBO G: 31801.548828125
# 2021-02-23T15:52:37.390 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.9198520183563232 neg ELBO G: 31792.564453125
# 2021-02-23T15:52:37.473 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.9284671545028687 neg ELBO G: 31790.8984375
# 2021-02-23T15:52:37.544 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:38.240 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B60382B of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-23T15:52:39.214 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B604101 of size 16642 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:39.221 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:39.286 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.9515828942401342
# ['speed']
# 2021-02-23T15:52:40.340 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B60553A does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:40.343 INFO mmfunctions.anomaly.execute load model None
# 2021-02-23T15:52:40.401 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.16367652203929897
# 2021-02-23T15:52:40.404 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B60553APrior mean: 0.0, sigma: 0.18808274477027687
# 2021-02-23T15:52:40.409 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([9415, 1]) Sigma: torch.Size([9415, 1]) loglikelihood: torch.Size([9415, 1]) KL value: tensor(-1.8268, grad_fn=<MeanBackward0>)
# 2021-02-23T15:52:40.410 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([9415, 1]) Sigma: torch.Size([9415, 1]) loglikelihood: torch.Size([9415, 1]) KL: torch.Size([]) KL value: tensor(206.3826, grad_fn=<MulBackward0>)
# 2021-02-23T15:52:40.411 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 2.8890035152435303 neg ELBO G: 207.89488220214844
# 2021-02-23T15:52:40.489 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 1.4578784704208374 neg ELBO G: 277.3067321777344
# 2021-02-23T15:52:40.561 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: -0.09098245948553085 neg ELBO G: 7430.181640625
# 2021-02-23T15:52:40.635 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -0.19583338499069214 neg ELBO G: 17423.947265625
# 2021-02-23T15:52:40.707 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -0.2661242187023163 neg ELBO G: 18087.576171875
# 2021-02-23T15:52:40.776 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -0.2690522372722626 neg ELBO G: 18647.349609375
# 2021-02-23T15:52:40.845 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -0.2683449685573578 neg ELBO G: 18732.40234375
# 2021-02-23T15:52:40.928 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -0.28552529215812683 neg ELBO G: 18585.15625
# 2021-02-23T15:52:41.010 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -0.2891550362110138 neg ELBO G: 18339.654296875
# 2021-02-23T15:52:41.095 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -0.28370723128318787 neg ELBO G: 18161.921875
# 2021-02-23T15:52:41.171 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -0.28782951831817627 neg ELBO G: 18225.716796875
# 2021-02-23T15:52:41.238 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -0.27784252166748047 neg ELBO G: 18333.76953125
# 2021-02-23T15:52:41.302 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -0.29251590371131897 neg ELBO G: 18320.02734375
# 2021-02-23T15:52:41.377 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -0.2862398624420166 neg ELBO G: 18275.095703125
# 2021-02-23T15:52:41.454 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -0.2821313440799713 neg ELBO G: 18264.583984375
# 2021-02-23T15:52:41.530 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -0.2727668285369873 neg ELBO G: 18256.037109375
# 2021-02-23T15:52:41.603 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -0.27544504404067993 neg ELBO G: 18319.517578125
# 2021-02-23T15:52:41.684 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -0.275104284286499 neg ELBO G: 18302.001953125
# 2021-02-23T15:52:41.773 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -0.304307222366333 neg ELBO G: 18318.373046875
# 2021-02-23T15:52:41.858 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -0.27908188104629517 neg ELBO G: 18308.8984375
# 2021-02-23T15:52:41.945 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -0.2870969772338867 neg ELBO G: 18251.234375
# 2021-02-23T15:52:42.030 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -0.2790202498435974 neg ELBO G: 18304.853515625
# 2021-02-23T15:52:42.116 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -0.28619441390037537 neg ELBO G: 18306.447265625
# 2021-02-23T15:52:42.201 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -0.293123722076416 neg ELBO G: 18296.87890625
# 2021-02-23T15:52:42.298 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -0.29041704535484314 neg ELBO G: 18331.59765625
# 2021-02-23T15:52:42.394 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -0.29172754287719727 neg ELBO G: 18305.51171875
# 2021-02-23T15:52:42.482 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -0.2829063832759857 neg ELBO G: 18288.626953125
# 2021-02-23T15:52:42.558 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -0.28736254572868347 neg ELBO G: 18244.166015625
# 2021-02-23T15:52:42.630 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -0.29504096508026123 neg ELBO G: 18350.97265625
# 2021-02-23T15:52:42.701 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -0.29437580704689026 neg ELBO G: 18286.521484375
# 2021-02-23T15:52:42.769 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:43.368 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B60553A of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-23T15:52:44.185 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B605699 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:44.188 INFO mmfunctions.anomaly.execute load model None
# 2021-02-23T15:52:44.244 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.07683520740370185
# 2021-02-23T15:52:44.248 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B605699Prior mean: 0.0, sigma: 0.07276953358119809
# 2021-02-23T15:52:44.252 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([9995, 1]) Sigma: torch.Size([9995, 1]) loglikelihood: torch.Size([9995, 1]) KL value: tensor(-7.8347, grad_fn=<MeanBackward0>)
# 2021-02-23T15:52:44.253 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([9995, 1]) Sigma: torch.Size([9995, 1]) loglikelihood: torch.Size([9995, 1]) KL: torch.Size([]) KL value: tensor(356.1361, grad_fn=<MulBackward0>)
# 2021-02-23T15:52:44.254 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 8.9212007522583 neg ELBO G: 357.7293395996094
# 2021-02-23T15:52:44.333 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 6.946444511413574 neg ELBO G: 55.946224212646484
# 2021-02-23T15:52:44.415 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 3.658249855041504 neg ELBO G: 775.74755859375
# 2021-02-23T15:52:44.495 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: 0.039557937532663345 neg ELBO G: 8883.8740234375
# 2021-02-23T15:52:44.575 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -0.668221116065979 neg ELBO G: 16469.251953125
# 2021-02-23T15:52:44.649 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -0.779637336730957 neg ELBO G: 18368.927734375
# 2021-02-23T15:52:44.721 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -0.8037699460983276 neg ELBO G: 21102.228515625
# 2021-02-23T15:52:44.792 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -0.8180792331695557 neg ELBO G: 23531.802734375
# 2021-02-23T15:52:44.865 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -0.8135043978691101 neg ELBO G: 24808.310546875
# 2021-02-23T15:52:44.938 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -0.8218222260475159 neg ELBO G: 25221.396484375
# 2021-02-23T15:52:45.010 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -0.8041080832481384 neg ELBO G: 24884.931640625
# 2021-02-23T15:52:45.080 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -0.8246867656707764 neg ELBO G: 24516.01953125
# 2021-02-23T15:52:45.150 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -0.8146879076957703 neg ELBO G: 24326.52734375
# 2021-02-23T15:52:45.222 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -0.8247405886650085 neg ELBO G: 24337.451171875
# 2021-02-23T15:52:45.300 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -0.808859646320343 neg ELBO G: 24360.193359375
# 2021-02-23T15:52:45.407 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -0.8212621212005615 neg ELBO G: 24343.103515625
# 2021-02-23T15:52:45.511 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -0.8137451410293579 neg ELBO G: 24313.79296875
# 2021-02-23T15:52:45.597 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -0.8151116371154785 neg ELBO G: 24337.361328125
# 2021-02-23T15:52:45.669 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -0.8197875022888184 neg ELBO G: 24366.4609375
# 2021-02-23T15:52:45.739 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -0.8222295641899109 neg ELBO G: 24368.5
# 2021-02-23T15:52:45.809 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -0.8229961395263672 neg ELBO G: 24362.7890625
# 2021-02-23T15:52:45.879 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -0.8168383240699768 neg ELBO G: 24362.359375
# 2021-02-23T15:52:45.962 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -0.8253673911094666 neg ELBO G: 24371.240234375
# 2021-02-23T15:52:46.043 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -0.8090377449989319 neg ELBO G: 24366.4140625
# 2021-02-23T15:52:46.117 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -0.8204835653305054 neg ELBO G: 24372.986328125
# 2021-02-23T15:52:46.197 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -0.8232651352882385 neg ELBO G: 24346.908203125
# 2021-02-23T15:52:46.276 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -0.8180755972862244 neg ELBO G: 24367.802734375
# 2021-02-23T15:52:46.350 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -0.8186206221580505 neg ELBO G: 24352.2890625
# 2021-02-23T15:52:46.437 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -0.8143680095672607 neg ELBO G: 24357.693359375
# 2021-02-23T15:52:46.519 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -0.8193782567977905 neg ELBO G: 24363.6953125
# 2021-02-23T15:52:46.589 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:47.303 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B605699 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-23T15:52:48.330 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B606390 of size 16642 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-23T15:52:48.336 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-23T15:52:48.371 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0210824924163784
# CPU times: user 45.9 s, sys: 204 ms, total: 46.1 s
# Wall time: 18.4 s
#                rms_x          rms_z          rms_y          power  \
# count  861165.000000  861165.000000  861165.000000  861165.000000
# mean        0.076957       0.293800       0.783084       5.998290
# std         0.087492       0.388257       0.427317       8.171752
# min         0.004989       0.010101       0.007598       0.000000
# 25%         0.015818       0.043151       0.956483       0.000000
# 50%         0.045733       0.097804       1.042373       1.742200
# 75%         0.084654       0.165243       1.044580      18.661800
# max         0.580223       1.044346       1.078255      43.012794
#
#                speed
# count  861165.000000
# mean      634.447573
# std       579.508187
# min         0.000000
# 25%         0.000000
# 50%      1059.000000
# 75%      1147.000000
# max      3600.000000

# %%
et.name
# Out:
# 'IOT_SHADOW_PUMP_DE_GEN5'

# %%
df_i.columns
# Out:
# Index(['rms_x', 'rms_z', 'rms_y', 'power', 'speed', 'predicted_rms_x',
#        'pred_dev_rms_x', 'predicted_rms_y', 'pred_dev_rms_y',
#        'predicted_rms_z', 'pred_dev_rms_z'],
#       dtype='object')

# %%
df_i.describe()
# Out:
#                rms_x          rms_z          rms_y          power  \
# count  861165.000000  861165.000000  861165.000000  861165.000000
# mean        0.076957       0.293800       0.783084       5.998290
# std         0.087492       0.388257       0.427317       8.171752
# min         0.004989       0.010101       0.007598       0.000000
# 25%         0.015818       0.043151       0.956483       0.000000
# 50%         0.045733       0.097804       1.042373       1.742200
# 75%         0.084654       0.165243       1.044580      18.661800
# max         0.580223       1.044346       1.078255      43.012794
#
#                speed
# count  861165.000000
# mean      634.447573
# std       579.508187
# min         0.000000
# 25%         0.000000
# 50%      1059.000000
# 75%      1147.000000
# max      3600.000000

# %%
df_i.index.levels[0].values
# Out:
# array(['04714B601096', '04714B603408', '04714B6036B1', '04714B6037F8',
#        '04714B60382B', '04714B604101', '04714B60553A', '04714B605699',
#        '04714B606390'], dtype=object)

# %%
# no multilevel index for plotting
count = 4

df_1 = df_i.loc[df_i.index.levels[0].values[count]].copy()

# remove speed < 400
df_1[df_1['speed'] < 400] = np.nan

print (df_i.index.levels[0].values[count], df_1.shape)
# Out:
# 04714B60382B (9985, 11)

# %%
rmsstr = 'rms_x'
predstr = 'predicted_rms_x'
preddstr = 'pred_dev_rms_x'
anostr = 'AnomalyX'

# X-coordinate
arr1 = np.where(df_1[rmsstr] > df_1[predstr] + df_1[preddstr], df_1[rmsstr], 0) + \
       np.where(df_1[rmsstr] < df_1[predstr] - df_1[preddstr], df_1[rmsstr], 0)
arr1[arr1 == 0] = np.nan
df_1[anostr] = arr1

fig, ax = plt.subplots(1, 1, figsize=(10, 8), squeeze=False)

ax[0,0].scatter(df_1['speed'], df_1[rmsstr])
ax[0,0].scatter(df_1['speed'], df_1[predstr], color='green')
ax[0,0].scatter(df_1['speed'], df_1[predstr] - df_1[preddstr], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['speed'], df_1[predstr] + df_1[preddstr], color='orange', lw=0.1)
ax[0,0].scatter(df_1['speed'], df_1[anostr], color='red', lw=2)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration - X')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i.index.levels[0].values[count])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-8baa797053a5> in <module>
#       5
#       6 # X-coordinate
# ----> 7 arr1 = np.where(df_1[rmsstr] > df_1[predstr] + df_1[preddstr], df_1[rmsstr], 0) + \
#       8        np.where(df_1[rmsstr] < df_1[predstr] - df_1[preddstr], df_1[rmsstr], 0)
#       9 arr1[arr1 == 0] = np.nan
#
# NameError: name 'df_1' is not defined

# %%
rmsstr = 'rms_y'
predstr = 'predicted_rms_y'
preddstr = 'pred_dev_rms_y'
anostr = 'AnomalyY'

# Y-coordinate
arr1 = np.where(df_1[rmsstr] > df_1[predstr] + df_1[preddstr], df_1[rmsstr], 0) + \
       np.where(df_1[rmsstr] < df_1[predstr] - df_1[preddstr], df_1[rmsstr], 0)
arr1[arr1 == 0] = np.nan
df_1[anostr] = arr1

fig, ax = plt.subplots(1, 1, figsize=(10, 8), squeeze=False)

ax[0,0].scatter(df_1['speed'], df_1[rmsstr])
ax[0,0].scatter(df_1['speed'], df_1[predstr], color='green')
ax[0,0].scatter(df_1['speed'], df_1[predstr] - df_1[preddstr], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['speed'], df_1[predstr] + df_1[preddstr], color='orange', lw=0.1)
ax[0,0].scatter(df_1['speed'], df_1[anostr], color='red', lw=2)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration - Y')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i.index.levels[0].values[count])
# Out:
# Text(0.5, 1.0, 'pump 04714B60553A')

# %%
rmsstr = 'rms_z'
predstr = 'predicted_rms_z'
preddstr = 'pred_dev_rms_z'
anostr = 'AnomalyZ'

# Z-coordinate
arr1 = np.where(df_1[rmsstr] > df_1[predstr] + df_1[preddstr], df_1[rmsstr], 0) + \
       np.where(df_1[rmsstr] < df_1[predstr] - df_1[preddstr], df_1[rmsstr], 0)
arr1[arr1 == 0] = np.nan
df_1[anostr] = arr1

fig, ax = plt.subplots(1, 1, figsize=(10, 8), squeeze=False)

ax[0,0].scatter(df_1['speed'], df_1[rmsstr])
ax[0,0].scatter(df_1['speed'], df_1[predstr], color='green')
ax[0,0].scatter(df_1['speed'], df_1[predstr] - df_1[preddstr], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['speed'], df_1[predstr] + df_1[preddstr], color='orange', lw=0.1)
ax[0,0].scatter(df_1['speed'], df_1[anostr], color='red', lw=2)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration - Z')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i.index.levels[0].values[count])
# Out:
# Text(0.5, 1.0, 'pump 04714B60553A')

# %%
#df_1 = df_i.loc[df_i.index.levels[0].values[0]].copy()

fig, ax = plt.subplots(2, 2, figsize=(20, 9), squeeze=False)

ax[0,0].scatter(df_1['speed'], df_1['rms_x'])
ax[0,0].scatter(df_1['speed'], df_1['predicted_rms_x'], color='green')
ax[0,0].scatter(df_1['speed'], df_1['predicted_rms_x'] - df_1['pred_dev_rms_x'], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['speed'], df_1['predicted_rms_x'] + df_1['pred_dev_rms_x'], color='orange', lw=0.1)
ax[0,0].scatter(df_1['speed'], df_1['AnomalyX'], color='red', lw=0.5)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration - X')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i.index.levels[0].values[count])


ax[0,1].scatter(df_1['speed'], df_1['rms_y'])
ax[0,1].scatter(df_1['speed'], df_1['predicted_rms_y'], color='green')
ax[0,1].scatter(df_1['speed'], df_1['predicted_rms_y'] - df_1['pred_dev_rms_y'], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,1].scatter(df_1['speed'], df_1['predicted_rms_y'] + df_1['pred_dev_rms_y'], color='orange', lw=0.1)
ax[0,1].scatter(df_1['speed'], df_1['AnomalyY'], color='red', lw=0.5)
ax[0,1].set_xlabel('Speed')
ax[0,1].set_ylabel('Vibration - Y')
ax[0,1].legend()
ax[0,1].set_title('pump ' + df_i.index.levels[0].values[count])

ax[1,0].scatter(df_1['speed'], df_1['rms_z'])
ax[1,0].scatter(df_1['speed'], df_1['predicted_rms_z'], color='green')
ax[1,0].scatter(df_1['speed'], df_1['predicted_rms_z'] - df_1['pred_dev_rms_z'], color='orange', lw=0.1, label='limit - p<0.05')
ax[1,0].scatter(df_1['speed'], df_1['predicted_rms_z'] + df_1['pred_dev_rms_z'], color='orange', lw=0.1)
ax[1,0].scatter(df_1['speed'], df_1['AnomalyZ'], color='red', lw=0.5)
ax[1,0].set_xlabel('Speed')
ax[1,0].set_ylabel('Vibration - Z')
ax[1,0].legend()
ax[1,0].set_title('pump ' + df_i.index.levels[0].values[count])


#ax[1,1].scatter(df_1['speed'], df_1['rms_y'])
#ax[1,1].set_xlabel('Speed')
#ax[1,1].set_ylabel('Vibration - Y')
#ax[1,1].legend()
ax[1,1].set_title('Hic sunt leones !')

#plt.fill_between(df_1['Ap'], - df_1['pred_dev_Vx'], df_1['pred_dev_Vx'], alpha=0.2)
# Out:
# Text(0.5, 1.0, 'Hic sunt leones !')

# %%
'''
df_1i = df_1[24000:28000]
cnt = 0
fig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)
ax[cnt,0].scatter(df_1i.index,df_1i['rms_x'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyX'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (X)' + df_i.index.levels[0].values[0])
ax[cnt,0].tick_params(axis = "x", which = "both", bottom = False, top = False)
ax[cnt,0].set_xticklabels([])
'''
# Out:
# '\ndf_1i = df_1[24000:28000]\ncnt = 0\nfig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)\nax[cnt,0].scatter(df_1i.index,df_1i[\'rms_x\'], lw=0.4, color=\'green\', label=\'vibration\')\nax[cnt,0].scatter(df_1i.index, df_1i[\'AnomalyX\'], lw=0.4, color=\'red\', zorder=10, label=\'excessive vibration\')\nax[cnt,0].legend()\nax[cnt,0].set_title(\'pump (X)\' + df_i.index.levels[0].values[0])\nax[cnt,0].tick_params(axis = "x", which = "both", bottom = False, top = False)\nax[cnt,0].set_xticklabels([])\n'

# %%
'''
df_1i = df_1[24000:28000]
cnt = 0
fig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)
ax[cnt,0].scatter(df_1i.index,df_1i['rms_y'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyY'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (Y)' + df_i.index.levels[0].values[0])
ax[cnt,0].tick_params(axis = "x", which = "both", bottom = False, top = False)
ax[cnt,0].set_xticklabels([])
'''
# Out:
# '\ndf_1i = df_1[24000:28000]\ncnt = 0\nfig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)\nax[cnt,0].scatter(df_1i.index,df_1i[\'rms_y\'], lw=0.4, color=\'green\', label=\'vibration\')\nax[cnt,0].scatter(df_1i.index, df_1i[\'AnomalyY\'], lw=0.4, color=\'red\', zorder=10, label=\'excessive vibration\')\nax[cnt,0].legend()\nax[cnt,0].set_title(\'pump (Y)\' + df_i.index.levels[0].values[0])\nax[cnt,0].tick_params(axis = "x", which = "both", bottom = False, top = False)\nax[cnt,0].set_xticklabels([])\n'

# %%
# OOM for ~170000 data points
'''
df_1i = df_1[0:4000]
fig, ax = plt.subplots(4, 1, figsize=(15, 12), squeeze=False)

cnt = 0
ax[0,0].scatter(df_1i.index,df_1i['speed'], lw=0.4, color='orange', zorder=5, label='speed')
cnt += 1
ax[cnt,0].scatter(df_1i.index,df_1i['rms_x'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyX'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (X)' + df_i.index.levels[0].values[0])
cnt += 1
ax[cnt,0].scatter(df_1i.index,df_1i['rms_y'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyY'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (Y)' + df_i.index.levels[0].values[0])
cnt += 1
ax[cnt,0].scatter(df_1i.index,df_1i['rms_z'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyZ'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (Z)' + df_i.index.levels[0].values[0])
'''
# Out:
# "\ndf_1i = df_1[0:4000]\nfig, ax = plt.subplots(4, 1, figsize=(15, 12), squeeze=False)\n\ncnt = 0\nax[0,0].scatter(df_1i.index,df_1i['speed'], lw=0.4, color='orange', zorder=5, label='speed')\ncnt += 1\nax[cnt,0].scatter(df_1i.index,df_1i['rms_x'], lw=0.4, color='green', label='vibration')\nax[cnt,0].scatter(df_1i.index, df_1i['AnomalyX'], lw=0.4, color='red', zorder=10, label='excessive vibration')\nax[cnt,0].legend()\nax[cnt,0].set_title('pump (X)' + df_i.index.levels[0].values[0])\ncnt += 1\nax[cnt,0].scatter(df_1i.index,df_1i['rms_y'], lw=0.4, color='green', label='vibration')\nax[cnt,0].scatter(df_1i.index, df_1i['AnomalyY'], lw=0.4, color='red', zorder=10, label='excessive vibration')\nax[cnt,0].legend()\nax[cnt,0].set_title('pump (Y)' + df_i.index.levels[0].values[0])\ncnt += 1\nax[cnt,0].scatter(df_1i.index,df_1i['rms_z'], lw=0.4, color='green', label='vibration')\nax[cnt,0].scatter(df_1i.index, df_1i['AnomalyZ'], lw=0.4, color='red', zorder=10, label='excessive vibration')\nax[cnt,0].legend()\nax[cnt,0].set_title('pump (Z)' + df_i.index.levels[0].values[0])\n"

# %%
df_i.loc['04714B601096'].index
# Out:
# Index(['2020-07-19-11.39.28.701000', '2020-07-19-11.39.48.701000',
#        '2020-07-19-11.40.08.701000', '2020-07-19-11.40.28.701000',
#        '2020-07-19-11.40.48.701000', '2020-07-19-11.44.28.948000',
#        '2020-07-19-11.44.48.948000', '2020-07-19-11.45.08.948000',
#        '2020-07-19-11.45.28.948000', '2020-07-19-11.45.48.948000',
#        ...
#        '2021-01-11-11.35.48.595000', '2021-01-11-11.39.28.840000',
#        '2021-01-11-11.39.48.840000', '2021-01-11-11.40.08.840000',
#        '2021-01-11-11.40.28.840000', '2021-01-11-11.40.48.840000',
#        '2021-01-11-14.14.56.144000', '2021-01-11-14.15.16.144000',
#        '2021-01-11-14.15.36.144000', '2021-01-11-14.15.56.144000'],
#       dtype='object', name='evt_timestamp', length=177980)

# %% [markdown]
# #### Does it make sense to have both accel values as features

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 5), squeeze=False)
ax[0,0].scatter(df_i['speed'].values, df_i['power'].values)
ax[0,0].set_xlabel('accel speed')
ax[0,0].set_ylabel('accel power')

#ax[0,1].plot(df_i.loc['04714B601096'].index, df_i['speed'].values, color='green')
#ax[0,1].plot(df_i.loc['04714B601096'].index, df_i['power'].values*100 + 400, color='orange')

#df_i[['As','Ap']].plot(figsize=(20,20))
# Out:
# Text(0, 0.5, 'accel power')

# %%
# hack - do not store model in db2
old_model_store = db.model_store
db.model_store = FileModelStore()

# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsib = BayesRidgeRegressor(['speed'], ['power'])
et = spsib._build_entity_type(columns = [Column('speed',Float())], **jobsettings)
spsib._entity_type = et
df_i = spsib.execute(df=df_i)

db.model_store = old_model_store
df_i.describe()
# Out:
# 2021-02-05T15:14:53.524 INFO iotfunctions.dbtables.__init__ Init FileModelStore
# 2021-02-05T15:14:53.525 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2021-02-05T15:14:53.526 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.3.1
# 2021-02-05T15:14:53.526 DEBUG iotfunctions.util.__init__ Starting trace
# 2021-02-05T15:14:53.527 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_BayesRidgeRegressor_20210205141453
# 2021-02-05T15:14:53.527 DEBUG iotfunctions.util.__init__ auto_save None
# 2021-02-05T15:14:53.528 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2021-02-05T15:14:53.529 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2021-02-05T15:14:53.529 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR
# Functions:
# Granularities:
# No schedules metadata
# 2021-02-05T15:14:53.532 DEBUG iotfunctions.anomaly.execute ['04714B601096'] predicting ['power'] from ['speed'] to appear in ['predicted_power'] with confidence interval ['stddev_power']
# 2021-02-05T15:14:53.536 DEBUG iotfunctions.anomaly.execute check passed
# 2021-02-05T15:14:53.562 INFO iotfunctions.base.get_models_for_training predicting target power
# 2021-02-05T15:14:53.564 INFO iotfunctions.dbtables.retrieve_model Model model.TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR.BayesRidgeRegressor.power.04714B601096 of size 1825 bytes has been retrieved from filesystem
# 2021-02-05T15:14:53.564 INFO iotfunctions.base.get_models_for_training load model {
#  "name": "model.TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR.BayesRidgeRegressor.power.04714B601096",
#  "target": "power",
#  "features": [
#   "speed"
#  ],
#  "estimator_name": "bayesianridge",
#  "eval_metric_name": "r2_score",
#  "eval_metric_train": 1.0,
#  "eval_metric_test": 1.0,
#  "trained_date": "2021-02-04T09:03:27.991368",
#  "expiry_date": null,
#  "col_name": "predicted_power",
#  "col_name_stddev": "stddev_power"
# }
# 2021-02-05T15:14:53.565 INFO iotfunctions.base.get_models_for_training training required: False  results: Existing model has not expired and eval metric is good
# 2021-02-05T15:14:53.565 INFO iotfunctions.dbtables.retrieve_model Model model.TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR.BayesRidgeRegressor.power.04714B601096 of size 1825 bytes has been retrieved from filesystem
# 2021-02-05T15:14:53.576 INFO iotfunctions.metadata.predict_with_std_dev predicted using model model.TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR.BayesRidgeRegressor.power.04714B601096
# 2021-02-05T15:14:53.581 DEBUG iotfunctions.util.log_df_info After adding predictions for target power ; df row count: 177980  ; index: { deviceid , evt_timestamp }  ; columns: { rms_x , rms_z , rms_y , power , speed , predicted_rms_x , pred_dev_rms_x , predicted_rms_y , pred_dev_rms_y , predicted_rms_z , pred_dev_rms_z , predicted_power , stddev_power }
# 2021-02-05T15:14:53.607 DEBUG iotfunctions.anomaly.execute BayesianRidge: Entity 04714B601096 Type of pred, stddev arrays <class 'pandas.core.frame.DataFrame'><class 'numpy.ndarray'>
#                rms_x          rms_z          rms_y          power  \
# count  177980.000000  177980.000000  177980.000000  177980.000000
# mean        0.201499       0.087049       0.964827       2.052877
# std         0.101279       0.028381       0.005473       0.435038
# min         0.018446       0.027219       0.952113       0.115600
# 25%         0.108721       0.065397       0.959472       1.740200
# 50%         0.189055       0.078209       0.965996       1.795200
# 75%         0.278364       0.100557       0.969530       2.325800
# max         0.576303       0.244273       0.979979       6.122200
#
#                speed  predicted_rms_x  pred_dev_rms_x  predicted_rms_y  \
# count  177980.000000    177980.000000   177980.000000    177980.000000
# mean     1079.609838         0.199317        0.243256         0.964607
# std        30.031477         0.050033        0.103079         0.004391
# min       212.000000         0.051936       -0.043635         0.959193
# 25%      1059.000000         0.202365        0.173472         0.960191
# 50%      1062.000000         0.205529        0.305867         0.963184
# 75%      1096.000000         0.218051        0.306096         0.969012
# max      1353.000000         0.274805        1.510480         0.977185
#
#        pred_dev_rms_y  predicted_rms_z  pred_dev_rms_z  predicted_power  \
# count   177980.000000    177980.000000   177980.000000    177980.000000
# mean         0.024917         0.080121        0.096390      1079.609838
# std          0.005371         0.002173        0.027322        30.031477
# min          0.007013        -0.304107       -0.205957       212.000000
# 25%          0.020119         0.080134        0.075043      1059.000000
# 50%          0.022496         0.080134        0.083694      1062.000000
# 75%          0.030674         0.080134        0.112059      1096.000000
# max          0.134411         0.080134        0.160004      1353.000000
#
#        stddev_power
# count  1.779800e+05
# mean   2.494303e-05
# std    6.791502e-07
# min    6.093499e-06
# 25%    2.447661e-05
# 50%    2.454446e-05
# 75%    2.531369e-05
# max    3.114243e-05

# %%
df_2 = df_i[0:10000]
df_2 = df_2[df_2['speed'] > 400]

# %%
plots = 1

fig, ax = plt.subplots(plots, 1, figsize=(20,10), squeeze=False)
cnt = 0
ax[cnt,0].plot(df_2.unstack(level=0).index, df_2['speed'],linewidth=0.5,color='blue',label='speed')
ax[cnt,0].plot(df_2.unstack(level=0).index, df_2['power'],linewidth=0.5,color='green',label='power')
ax[cnt,0].plot(df_2.unstack(level=0).index, df_2['predicted_power'],linewidth=0.5,color='red',label='MaxTemp pred')
ax[cnt,0].fill_between(df_2.unstack(level=0).index, df_2['predicted_power'] - df_2['stddev_power'],
                df_2['predicted_power'] + df_2['stddev_power'], color="pink", alpha=0.3, label="predict stddev")
ax[cnt,0].legend(bbox_to_anchor=(1.1, 1.05))
ax[cnt,0].set_ylabel('power',fontsize=12,weight="bold")
ax[cnt,0].set_xlabel('speed',fontsize=12,weight="bold")
cnt = 1
# Out:
# 2021-02-05T15:16:27.266 DEBUG matplotlib.font_manager._findfont_cached findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=bold:stretch=normal:size=12.0.
# 2021-02-05T15:16:27.266 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.335
# 2021-02-05T15:16:27.267 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>) = 10.335
# 2021-02-05T15:16:27.267 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>) = 10.335
# 2021-02-05T15:16:27.268 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>) = 10.335
# 2021-02-05T15:16:27.268 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>) = 10.335
# 2021-02-05T15:16:27.269 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal bold normal>) = 1.0
# 2021-02-05T15:16:27.269 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.335
# 2021-02-05T15:16:27.270 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal bold normal>) = 0.0
# 2021-02-05T15:16:27.270 DEBUG matplotlib.font_manager._findfont_cached findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=bold:stretch=normal:size=12.0 to DejaVu Sans ('/home/markus/.local/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf') with score of 0.000000.

# %%
def load_data_short(filename):
    # load data
    df_input = pd.read_csv(filename, parse_dates=['RCV_TIMESTAMP_UTC'], comment='#')
    #df_input = df_input.asfreq('H')
    df_input = df_input.sort_values(by='RCV_TIMESTAMP_UTC').\
                    rename(columns={'RCV_TIMESTAMP_UTC':'timestamp', 'DEVICEID': 'entity'}).\
                    drop(columns=['DEVICETYPE', 'FORMAT','UPDATED_UTC','LOGICALINTERFACE_ID','DEVICE_ID']).\
                    drop(columns=['RMS_X','RMS_Y','RMS_Z'])
    #df_input = df_input[df_input['VERSION'] != 0].drop(columns=['VERSION'])
       
    return df_input
    
def prep_data_short(df_input):
    entity = df_input['entity'].values[0]
    
    list_ac_vx = []
    cnt = 0
    for idx,row in df_input[['timestamp','VIBRATIONS_XAXIS','ACCEL_SPEED']].iterrows():
        if isinstance(row['timestamp'], str):
            ts = datetime.datetime.strptime(row['timestamp'], '%Y-%m-%d-%H.%M.%S.%f')
        else:
            ts = row['timestamp']
            
        rvibs = row['VIBRATIONS_XAXIS']
        racc = row['ACCEL_SPEED']
        
        if isinstance(racc, str):
            racc = eval(racc)

        if not isinstance(racc, list) and math.isnan(racc):
            continue
            
        if isinstance(rvibs, str):
            list_ac = []
           
            for ac in racc:
                #print(ac)
                list_ac.append(eval(ac))
                list_ac.append(eval(ac))
                list_ac.append(eval(ac))
                #print (list_ac)

            list_vx = []
            for vx in eval(rvibs):
                list_vx.append(vx)
                #print (list_vx)

            #print(list_ac, list_vx)
            cnt2 = 0
            for p in zip(list_ac, list_vx):
                #print(ts + datetime.timedelta(seconds = cnt2 * 10), p[0],p[1])
                list_ac_vx.append([ts + datetime.timedelta(seconds = cnt2 * 10), p[0],p[1]])
                cnt2 += 1
        cnt += 1

    df_clean = pd.DataFrame(list_ac_vx, columns=['timestamp','Ap','Vx'])
    df_clean['Ap'] = df_clean['Ap']/1000
    df_clean['entity'] = entity
    
    return df_clean.set_index(['entity','timestamp'])

# %%
#df_clean2 = prep_data(load_data('./IOT_PUMP_DE_GEN5_202012151526.csv'))
df_clean2 = prep_data_short(load_data_short('./04714B603408.csv'))
#df_clean2.describe()
df_clean2.head(2)
df_clean2.index.levels[0].values[0]
# Out:
# '04714B603408'

# %%
df_clean2.describe()
# Out:
#                  Ap            Vx
# count  1.371300e+06  1.371300e+06
# mean   1.501744e+00 -2.946143e-02
# std    1.482848e+00  1.308858e-01
# min    0.000000e+00 -1.039100e+00
# 25%    0.000000e+00 -4.390000e-02
# 50%    1.281000e+00 -2.730000e-02
# 75%    3.099000e+00 -8.800000e-03
# max    3.780000e+00  1.035200e+00

# %%
plt.figure(figsize=(16, 6))
g = sns.displot(df_clean2[['Ap','Vx']], x='Ap', y='Vx', kind="kde", rug=True)
    
g.set_titles('KDE for' + df_clean2.index.levels[0].values[0])

# %%
df_i2 = df_clean2.copy()

# %%
# %%time
print('Train and evaluate model for ' + df_i2.index.levels[0].values[0])
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsi2 = VIAnomalyScore(['Ap'], ['Vx'])
et = spsi2._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
spsi2._entity_type = et
spsi2.epochs = 300   # 1500 takes ages
df_i2 = spsi.execute(df=df_i2)

EngineLogging.configure_console_logging(logging.INFO)
df_i2.describe()
# Out:
# Train and evaluate model for 04714B603408
# 2020-12-22T13:57:10.081 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2020-12-22T13:57:10.082 DEBUG mmfunctions.anomaly.__init__ init KDE Estimator
# 2020-12-22T13:57:10.083 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.2.1
# 2020-12-22T13:57:10.084 DEBUG iotfunctions.util.__init__ Starting trace
# 2020-12-22T13:57:10.084 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20201222125710
# 2020-12-22T13:57:10.084 DEBUG iotfunctions.util.__init__ auto_save None
# 2020-12-22T13:57:10.085 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2020-12-22T13:57:10.085 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2020-12-22T13:57:10.085 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# Here 1 <class 'pandas.core.frame.DataFrame'>
# 2020-12-22T13:57:10.093 DEBUG mmfunctions.anomaly.execute ['04714B603408']
# ['Ap']
# 2020-12-22T13:57:10.306 INFO iotfunctions.dbtables.retrieve_model Model model.TEST_ENTITY_FOR_VIANOMALYSCORE.VIAnomalyScore.Vx.04714B603408 does not exist in filesystem
# 2020-12-22T13:57:10.306 INFO mmfunctions.anomaly.execute load model None
# 2020-12-22T13:57:11.221 DEBUG mmfunctions.anomaly.execute Epoch: 0, Loss: 0.8914065361022949
# 2020-12-22T13:57:21.196 DEBUG mmfunctions.anomaly.execute Epoch: 10, Loss: 0.6331454515457153
# 2020-12-22T13:57:31.118 DEBUG mmfunctions.anomaly.execute Epoch: 20, Loss: 0.56513911485672
# 2020-12-22T13:57:41.202 DEBUG mmfunctions.anomaly.execute Epoch: 30, Loss: 0.5272055268287659
# 2020-12-22T13:57:51.118 DEBUG mmfunctions.anomaly.execute Epoch: 40, Loss: 0.51528400182724
# 2020-12-22T13:58:01.048 DEBUG mmfunctions.anomaly.execute Epoch: 50, Loss: 0.5176530480384827
# 2020-12-22T13:58:11.025 DEBUG mmfunctions.anomaly.execute Epoch: 60, Loss: 0.5161495208740234
# 2020-12-22T13:58:21.046 DEBUG mmfunctions.anomaly.execute Epoch: 70, Loss: 0.515254020690918
# 2020-12-22T13:58:31.043 DEBUG mmfunctions.anomaly.execute Epoch: 80, Loss: 0.5147814750671387
# 2020-12-22T13:58:41.231 DEBUG mmfunctions.anomaly.execute Epoch: 90, Loss: 0.5146395564079285
# 2020-12-22T13:58:51.802 DEBUG mmfunctions.anomaly.execute Epoch: 100, Loss: 0.515004575252533
# 2020-12-22T13:59:02.172 DEBUG mmfunctions.anomaly.execute Epoch: 110, Loss: 0.5155276656150818
# 2020-12-22T13:59:12.339 DEBUG mmfunctions.anomaly.execute Epoch: 120, Loss: 0.5141093134880066
# 2020-12-22T13:59:22.321 DEBUG mmfunctions.anomaly.execute Epoch: 130, Loss: 0.5144382119178772
# 2020-12-22T13:59:32.385 DEBUG mmfunctions.anomaly.execute Epoch: 140, Loss: 0.5153028964996338
# 2020-12-22T13:59:42.491 DEBUG mmfunctions.anomaly.execute Epoch: 150, Loss: 0.5147557258605957
# 2020-12-22T13:59:52.704 DEBUG mmfunctions.anomaly.execute Epoch: 160, Loss: 0.514911949634552
# 2020-12-22T14:00:02.880 DEBUG mmfunctions.anomaly.execute Epoch: 170, Loss: 0.5151118040084839
# 2020-12-22T14:00:13.050 DEBUG mmfunctions.anomaly.execute Epoch: 180, Loss: 0.5142313241958618
# 2020-12-22T14:00:23.218 DEBUG mmfunctions.anomaly.execute Epoch: 190, Loss: 0.5151821970939636
# 2020-12-22T14:00:33.321 DEBUG mmfunctions.anomaly.execute Epoch: 200, Loss: 0.5146312117576599
# 2020-12-22T14:00:43.626 DEBUG mmfunctions.anomaly.execute Epoch: 210, Loss: 0.5153499245643616
# 2020-12-22T14:00:53.778 DEBUG mmfunctions.anomaly.execute Epoch: 220, Loss: 0.5148592591285706
# 2020-12-22T14:01:04.026 DEBUG mmfunctions.anomaly.execute Epoch: 230, Loss: 0.5150873064994812
# 2020-12-22T14:01:14.208 DEBUG mmfunctions.anomaly.execute Epoch: 240, Loss: 0.5148673057556152
# 2020-12-22T14:01:24.167 DEBUG mmfunctions.anomaly.execute Epoch: 250, Loss: 0.515082836151123
# 2020-12-22T14:01:34.233 DEBUG mmfunctions.anomaly.execute Epoch: 260, Loss: 0.515089213848114
# 2020-12-22T14:01:44.408 DEBUG mmfunctions.anomaly.execute Epoch: 270, Loss: 0.5139238834381104
# 2020-12-22T14:01:54.596 DEBUG mmfunctions.anomaly.execute Epoch: 280, Loss: 0.5150812864303589
# 2020-12-22T14:02:05.458 DEBUG mmfunctions.anomaly.execute Epoch: 290, Loss: 0.5146006345748901
# 2020-12-22T14:02:15.839 DEBUG mmfunctions.anomaly.execute Epoch: 300, Loss: 0.5148071050643921
# 2020-12-22T14:02:25.985 DEBUG mmfunctions.anomaly.execute Epoch: 310, Loss: 0.5151475667953491
# 2020-12-22T14:02:36.358 DEBUG mmfunctions.anomaly.execute Epoch: 320, Loss: 0.5154476761817932
# 2020-12-22T14:02:46.581 DEBUG mmfunctions.anomaly.execute Epoch: 330, Loss: 0.5145741701126099
# 2020-12-22T14:02:56.706 DEBUG mmfunctions.anomaly.execute Epoch: 340, Loss: 0.5140682458877563
# 2020-12-22T14:03:06.818 DEBUG mmfunctions.anomaly.execute Epoch: 350, Loss: 0.5148553252220154
# 2020-12-22T14:03:16.944 DEBUG mmfunctions.anomaly.execute Epoch: 360, Loss: 0.5152938961982727
# 2020-12-22T14:03:26.998 DEBUG mmfunctions.anomaly.execute Epoch: 370, Loss: 0.5144619345664978
# 2020-12-22T14:03:37.211 DEBUG mmfunctions.anomaly.execute Epoch: 380, Loss: 0.5145074725151062
# 2020-12-22T14:03:47.529 DEBUG mmfunctions.anomaly.execute Epoch: 390, Loss: 0.5141514539718628
# 2020-12-22T14:03:57.711 DEBUG mmfunctions.anomaly.execute Epoch: 400, Loss: 0.515694260597229
# 2020-12-22T14:04:07.877 DEBUG mmfunctions.anomaly.execute Epoch: 410, Loss: 0.5152667760848999
# 2020-12-22T14:04:17.942 DEBUG mmfunctions.anomaly.execute Epoch: 420, Loss: 0.514506995677948
# 2020-12-22T14:04:28.160 DEBUG mmfunctions.anomaly.execute Epoch: 430, Loss: 0.5140680074691772
# 2020-12-22T14:04:38.418 DEBUG mmfunctions.anomaly.execute Epoch: 440, Loss: 0.5151513814926147
# 2020-12-22T14:04:48.858 DEBUG mmfunctions.anomaly.execute Epoch: 450, Loss: 0.5153243541717529
# 2020-12-22T14:04:59.093 DEBUG mmfunctions.anomaly.execute Epoch: 460, Loss: 0.5149504542350769
# 2020-12-22T14:05:09.372 DEBUG mmfunctions.anomaly.execute Epoch: 470, Loss: 0.5146647691726685
# 2020-12-22T14:05:19.537 DEBUG mmfunctions.anomaly.execute Epoch: 480, Loss: 0.5142231583595276
# 2020-12-22T14:05:29.721 DEBUG mmfunctions.anomaly.execute Epoch: 490, Loss: 0.5133796334266663
# 2020-12-22T14:05:39.882 DEBUG mmfunctions.anomaly.execute Epoch: 500, Loss: 0.5152966380119324
# 2020-12-22T14:05:50.110 DEBUG mmfunctions.anomaly.execute Epoch: 510, Loss: 0.5144299864768982
# 2020-12-22T14:06:00.274 DEBUG mmfunctions.anomaly.execute Epoch: 520, Loss: 0.5148006677627563
# 2020-12-22T14:06:10.541 DEBUG mmfunctions.anomaly.execute Epoch: 530, Loss: 0.5146817564964294
# 2020-12-22T14:06:20.738 DEBUG mmfunctions.anomaly.execute Epoch: 540, Loss: 0.5140889286994934
# 2020-12-22T14:06:30.766 DEBUG mmfunctions.anomaly.execute Epoch: 550, Loss: 0.5141640901565552
# 2020-12-22T14:06:40.877 DEBUG mmfunctions.anomaly.execute Epoch: 560, Loss: 0.5149827003479004
# 2020-12-22T14:06:51.163 DEBUG mmfunctions.anomaly.execute Epoch: 570, Loss: 0.5139686465263367
# 2020-12-22T14:07:01.329 DEBUG mmfunctions.anomaly.execute Epoch: 580, Loss: 0.5154014229774475
# 2020-12-22T14:07:11.506 DEBUG mmfunctions.anomaly.execute Epoch: 590, Loss: 0.5142351984977722
# 2020-12-22T14:07:21.830 DEBUG mmfunctions.anomaly.execute Epoch: 600, Loss: 0.5153434872627258
# 2020-12-22T14:07:32.068 DEBUG mmfunctions.anomaly.execute Epoch: 610, Loss: 0.5152716040611267
# 2020-12-22T14:07:42.397 DEBUG mmfunctions.anomaly.execute Epoch: 620, Loss: 0.5144082307815552
# 2020-12-22T14:07:52.674 DEBUG mmfunctions.anomaly.execute Epoch: 630, Loss: 0.5143427848815918
# 2020-12-22T14:08:03.039 DEBUG mmfunctions.anomaly.execute Epoch: 640, Loss: 0.5143038034439087
# 2020-12-22T14:08:13.204 DEBUG mmfunctions.anomaly.execute Epoch: 650, Loss: 0.5141136050224304
# 2020-12-22T14:08:23.457 DEBUG mmfunctions.anomaly.execute Epoch: 660, Loss: 0.5130411982536316
# 2020-12-22T14:08:33.750 DEBUG mmfunctions.anomaly.execute Epoch: 670, Loss: 0.5142372250556946
# 2020-12-22T14:08:43.972 DEBUG mmfunctions.anomaly.execute Epoch: 680, Loss: 0.5152056217193604
# 2020-12-22T14:08:54.216 DEBUG mmfunctions.anomaly.execute Epoch: 690, Loss: 0.5141973495483398
# 2020-12-22T14:09:04.555 DEBUG mmfunctions.anomaly.execute Epoch: 700, Loss: 0.5143685340881348
# 2020-12-22T14:09:14.739 DEBUG mmfunctions.anomaly.execute Epoch: 710, Loss: 0.5157939791679382
# 2020-12-22T14:09:25.001 DEBUG mmfunctions.anomaly.execute Epoch: 720, Loss: 0.5140376091003418
# 2020-12-22T14:09:35.230 DEBUG mmfunctions.anomaly.execute Epoch: 730, Loss: 0.5148692727088928
# 2020-12-22T14:09:45.743 DEBUG mmfunctions.anomaly.execute Epoch: 740, Loss: 0.513357400894165
# 2020-12-22T14:09:56.328 DEBUG mmfunctions.anomaly.execute Epoch: 750, Loss: 0.5140331387519836
# 2020-12-22T14:10:06.852 DEBUG mmfunctions.anomaly.execute Epoch: 760, Loss: 0.5143701434135437
# 2020-12-22T14:10:17.249 DEBUG mmfunctions.anomaly.execute Epoch: 770, Loss: 0.5141509175300598
# 2020-12-22T14:10:27.786 DEBUG mmfunctions.anomaly.execute Epoch: 780, Loss: 0.5143022537231445
# 2020-12-22T14:10:38.410 DEBUG mmfunctions.anomaly.execute Epoch: 790, Loss: 0.5142222046852112
# 2020-12-22T14:10:49.238 DEBUG mmfunctions.anomaly.execute Epoch: 800, Loss: 0.5146180987358093
# 2020-12-22T14:11:00.254 DEBUG mmfunctions.anomaly.execute Epoch: 810, Loss: 0.5139776468276978
# 2020-12-22T14:11:11.208 DEBUG mmfunctions.anomaly.execute Epoch: 820, Loss: 0.5138651728630066
# 2020-12-22T14:11:22.086 DEBUG mmfunctions.anomaly.execute Epoch: 830, Loss: 0.5135164260864258
# 2020-12-22T14:11:32.951 DEBUG mmfunctions.anomaly.execute Epoch: 840, Loss: 0.5155550241470337
# 2020-12-22T14:11:44.073 DEBUG mmfunctions.anomaly.execute Epoch: 850, Loss: 0.5142265558242798
# 2020-12-22T14:11:55.120 DEBUG mmfunctions.anomaly.execute Epoch: 860, Loss: 0.5138198137283325
# 2020-12-22T14:12:05.962 DEBUG mmfunctions.anomaly.execute Epoch: 870, Loss: 0.5144504308700562
# 2020-12-22T14:12:16.919 DEBUG mmfunctions.anomaly.execute Epoch: 880, Loss: 0.5146055221557617
# 2020-12-22T14:12:28.016 DEBUG mmfunctions.anomaly.execute Epoch: 890, Loss: 0.5149950981140137
# 2020-12-22T14:12:39.038 DEBUG mmfunctions.anomaly.execute Epoch: 900, Loss: 0.5134389996528625
# 2020-12-22T14:12:50.154 DEBUG mmfunctions.anomaly.execute Epoch: 910, Loss: 0.5146349668502808
# 2020-12-22T14:13:01.462 DEBUG mmfunctions.anomaly.execute Epoch: 920, Loss: 0.5140714049339294
# 2020-12-22T14:13:12.553 DEBUG mmfunctions.anomaly.execute Epoch: 930, Loss: 0.513556957244873
# 2020-12-22T14:13:23.657 DEBUG mmfunctions.anomaly.execute Epoch: 940, Loss: 0.5141644477844238
# 2020-12-22T14:13:34.755 DEBUG mmfunctions.anomaly.execute Epoch: 950, Loss: 0.5147133469581604
# 2020-12-22T14:13:45.849 DEBUG mmfunctions.anomaly.execute Epoch: 960, Loss: 0.5143046975135803
# 2020-12-22T14:13:56.907 DEBUG mmfunctions.anomaly.execute Epoch: 970, Loss: 0.5137965083122253
# 2020-12-22T14:14:07.925 DEBUG mmfunctions.anomaly.execute Epoch: 980, Loss: 0.5133213996887207
# 2020-12-22T14:14:18.996 DEBUG mmfunctions.anomaly.execute Epoch: 990, Loss: 0.5144398808479309
# 2020-12-22T14:14:29.859 DEBUG mmfunctions.anomaly.execute Epoch: 1000, Loss: 0.5143953561782837
# 2020-12-22T14:14:40.803 DEBUG mmfunctions.anomaly.execute Epoch: 1010, Loss: 0.5149785280227661
# 2020-12-22T14:14:51.799 DEBUG mmfunctions.anomaly.execute Epoch: 1020, Loss: 0.5142021775245667
# 2020-12-22T14:15:02.932 DEBUG mmfunctions.anomaly.execute Epoch: 1030, Loss: 0.5147781372070312
# 2020-12-22T14:15:13.969 DEBUG mmfunctions.anomaly.execute Epoch: 1040, Loss: 0.5149414539337158
# 2020-12-22T14:15:24.995 DEBUG mmfunctions.anomaly.execute Epoch: 1050, Loss: 0.5148706436157227
# 2020-12-22T14:15:36.048 DEBUG mmfunctions.anomaly.execute Epoch: 1060, Loss: 0.5148179531097412
# 2020-12-22T14:15:47.303 DEBUG mmfunctions.anomaly.execute Epoch: 1070, Loss: 0.5138766765594482
# 2020-12-22T14:15:58.392 DEBUG mmfunctions.anomaly.execute Epoch: 1080, Loss: 0.5141459107398987
# 2020-12-22T14:16:09.395 DEBUG mmfunctions.anomaly.execute Epoch: 1090, Loss: 0.5145758390426636
# 2020-12-22T14:16:20.458 DEBUG mmfunctions.anomaly.execute Epoch: 1100, Loss: 0.5150577425956726
# 2020-12-22T14:16:31.653 DEBUG mmfunctions.anomaly.execute Epoch: 1110, Loss: 0.5130228400230408
# 2020-12-22T14:16:42.898 DEBUG mmfunctions.anomaly.execute Epoch: 1120, Loss: 0.5149590969085693
# 2020-12-22T14:16:53.885 DEBUG mmfunctions.anomaly.execute Epoch: 1130, Loss: 0.5144556164741516
# 2020-12-22T14:17:04.967 DEBUG mmfunctions.anomaly.execute Epoch: 1140, Loss: 0.5144173502922058
# 2020-12-22T14:17:16.056 DEBUG mmfunctions.anomaly.execute Epoch: 1150, Loss: 0.5134467482566833
# 2020-12-22T14:17:27.178 DEBUG mmfunctions.anomaly.execute Epoch: 1160, Loss: 0.514385998249054
# 2020-12-22T14:17:38.269 DEBUG mmfunctions.anomaly.execute Epoch: 1170, Loss: 0.5140436291694641
# 2020-12-22T14:17:49.507 DEBUG mmfunctions.anomaly.execute Epoch: 1180, Loss: 0.5149255990982056
# 2020-12-22T14:18:00.623 DEBUG mmfunctions.anomaly.execute Epoch: 1190, Loss: 0.5143675804138184
# 2020-12-22T14:18:11.658 DEBUG mmfunctions.anomaly.execute Epoch: 1200, Loss: 0.5145463347434998
# 2020-12-22T14:18:22.687 DEBUG mmfunctions.anomaly.execute Epoch: 1210, Loss: 0.5148018598556519
# 2020-12-22T14:18:33.756 DEBUG mmfunctions.anomaly.execute Epoch: 1220, Loss: 0.51361083984375
# 2020-12-22T14:18:44.918 DEBUG mmfunctions.anomaly.execute Epoch: 1230, Loss: 0.5146350860595703
# 2020-12-22T14:18:55.906 DEBUG mmfunctions.anomaly.execute Epoch: 1240, Loss: 0.5146235227584839
# 2020-12-22T14:19:07.103 DEBUG mmfunctions.anomaly.execute Epoch: 1250, Loss: 0.5154386162757874
# 2020-12-22T14:19:18.151 DEBUG mmfunctions.anomaly.execute Epoch: 1260, Loss: 0.5131248235702515
# 2020-12-22T14:19:29.191 DEBUG mmfunctions.anomaly.execute Epoch: 1270, Loss: 0.5137571692466736
# 2020-12-22T14:19:40.291 DEBUG mmfunctions.anomaly.execute Epoch: 1280, Loss: 0.5144015550613403
# 2020-12-22T14:19:51.426 DEBUG mmfunctions.anomaly.execute Epoch: 1290, Loss: 0.5150455832481384
# 2020-12-22T14:20:02.474 DEBUG mmfunctions.anomaly.execute Epoch: 1300, Loss: 0.5150640606880188
# 2020-12-22T14:20:13.698 DEBUG mmfunctions.anomaly.execute Epoch: 1310, Loss: 0.5138633847236633
# 2020-12-22T14:20:24.754 DEBUG mmfunctions.anomaly.execute Epoch: 1320, Loss: 0.5143010020256042
# 2020-12-22T14:20:35.925 DEBUG mmfunctions.anomaly.execute Epoch: 1330, Loss: 0.5139129757881165
# 2020-12-22T14:20:47.151 DEBUG mmfunctions.anomaly.execute Epoch: 1340, Loss: 0.513812243938446
# 2020-12-22T14:20:58.316 DEBUG mmfunctions.anomaly.execute Epoch: 1350, Loss: 0.5140603184700012
# 2020-12-22T14:21:09.781 DEBUG mmfunctions.anomaly.execute Epoch: 1360, Loss: 0.5139245986938477
# 2020-12-22T14:21:20.931 DEBUG mmfunctions.anomaly.execute Epoch: 1370, Loss: 0.5143417716026306
# 2020-12-22T14:21:32.036 DEBUG mmfunctions.anomaly.execute Epoch: 1380, Loss: 0.5143312811851501
# 2020-12-22T14:21:43.320 DEBUG mmfunctions.anomaly.execute Epoch: 1390, Loss: 0.5150663256645203
# 2020-12-22T14:21:54.519 DEBUG mmfunctions.anomaly.execute Epoch: 1400, Loss: 0.5134438872337341
# 2020-12-22T14:22:05.661 DEBUG mmfunctions.anomaly.execute Epoch: 1410, Loss: 0.5146374106407166
# 2020-12-22T14:22:16.888 DEBUG mmfunctions.anomaly.execute Epoch: 1420, Loss: 0.5138710737228394
# 2020-12-22T14:22:28.274 DEBUG mmfunctions.anomaly.execute Epoch: 1430, Loss: 0.5140697956085205
# 2020-12-22T14:22:39.539 DEBUG mmfunctions.anomaly.execute Epoch: 1440, Loss: 0.5143080353736877
# 2020-12-22T14:22:50.828 DEBUG mmfunctions.anomaly.execute Epoch: 1450, Loss: 0.5147854089736938
# 2020-12-22T14:23:02.188 DEBUG mmfunctions.anomaly.execute Epoch: 1460, Loss: 0.513729989528656
# 2020-12-22T14:23:13.125 DEBUG mmfunctions.anomaly.execute Epoch: 1470, Loss: 0.5134919285774231
# 2020-12-22T14:23:24.424 DEBUG mmfunctions.anomaly.execute Epoch: 1480, Loss: 0.5124624967575073
# 2020-12-22T14:23:35.644 DEBUG mmfunctions.anomaly.execute Epoch: 1490, Loss: 0.5135117769241333
# 2020-12-22T14:23:46.644 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# <ipython-input-17-bb9e9a5bbb29>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   get_ipython().run_cell_magic('time', '', "print('Train and evaluate model for ' + df_i2.index.levels[0].values[0])\n# Now run the anomaly functions as if they were executed in a pipeline\nEngineLogging.configure_console_logging(logging.DEBUG)\njobsettings = { 'db': db, \n               '_db_schema': 'public', 'save_trace_to_file' : True}\n\nspsi2 = VIAnomalyScore(['Ap'], ['Vx'])\net = spsi2._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)\nspsi2._entity_type = et\nspsi2.epochs = 300   # 1500 takes ages\ndf_i2 = spsi.execute(df=df_i2)\n\nEngineLogging.configure_console_logging(logging.INFO)\ndf_i2.describe()\n")
# CPU times: user 1h 59min 6s, sys: 30min 21s, total: 2h 29min 27s
# Wall time: 26min 37s
#                  Ap            Vx  predicted_Vx   pred_dev_Vx
# count  1.371300e+06  1.371300e+06  1.371300e+06  1.371300e+06
# mean   1.501744e+00 -2.946143e-02 -2.734308e-02  4.044737e-01
# std    1.482848e+00  1.308858e-01  1.372179e-03  2.715333e-01
# min    0.000000e+00 -1.039100e+00 -3.356946e-02  1.361498e-01
# 25%    0.000000e+00 -4.390000e-02 -2.845207e-02  1.361498e-01
# 50%    1.281000e+00 -2.730000e-02 -2.845207e-02  2.858738e-01
# 75%    3.099000e+00 -8.800000e-03 -2.569535e-02  6.752676e-01
# max    3.780000e+00  1.035200e+00 -1.292527e-03  8.986392e-01

# %%
entity = df_i2.index.levels[0].values[0]

df_1 = df_i2.loc[entity].copy()


arr1 = np.where(df_1['Vx'] > df_1['predicted_Vx'] + df_1['pred_dev_Vx'], df_1['Vx'], 0) + \
       np.where(df_1['Vx'] < df_1['predicted_Vx'] - df_1['pred_dev_Vx'], df_1['Vx'], 0)
arr1[arr1 == 0] = np.nan
df_1['Anomaly'] = arr1

fig, ax = plt.subplots(1, 2, figsize=(20, 6), squeeze=False)

ax[0,0].scatter(df_1['Ap'], df_1['Vx'])
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'], color='green')
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'] - df_1['pred_dev_Vx'], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'] + df_1['pred_dev_Vx'], color='orange', lw=0.1)
ax[0,0].scatter(df_1['Ap'], df_1['Anomaly'], color='red', lw=2)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration')
ax[0,0].legend()
ax[0,0].set_title('pump ' + entity)

ax[0,1].scatter(df_i2['Ap'], df_i2['Vx'])
ax[0,1].set_xlabel('Speed')
ax[0,1].set_ylabel('Vibration')
ax[0,1].legend()
ax[0,1].set_title('pump ' + entity + ' - plain scatterplot')
# Out:
# 2020-12-22T14:50:14.011 WARNING matplotlib.legend._parse_legend_args No handles with labels found to put in legend.
# Text(0.5, 1.0, 'pump 04714B603408 - plain scatterplot')

# %%
df_1[df_1['Ap'] < 2.0]['Anomaly'] = np.nan
df_1[np.abs(df_1['Vx']) < 0.7]['Anomaly'] = np.nan
# Out:
# <ipython-input-27-11cbb9c58f70>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[df_1['Ap'] < 2.0]['Anomaly'] = np.nan
# <ipython-input-27-11cbb9c58f70>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[np.abs(df_1['Vx']) < 0.7]['Anomaly'] = np.nan

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)
#ax[0,0].plot(df_1['max'] + 2.0, lw=0.4, color='blue', label='smoothed max vib + 1')
ax[0,0].scatter(df_1.index,df_1['Vx'], lw=0.4, color='green', label='vibration')
ax[0,0].scatter(df_1.index,df_1['Ap']/3, lw=0.4, color='orange', zorder=5, label='accel speed')
ax[0,0].scatter(df_1.index, df_1['Anomaly'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i2.index.levels[0].values[0])
# Out:
# Text(0.5, 1.0, 'pump 04714B603408')

# %%
df_clean3 = prep_data_short(load_data_short('./04714B6036B1.csv'))
df_clean3.head(2)
df_clean3.index.levels[0].values[0]
# Out:
# '04714B6036B1'

# %%
plt.figure(figsize=(16, 6))
g = sns.displot(df_clean3[['Ap','Vx']], x='Ap', y='Vx', kind="kde", rug=True)
    
g.set_titles('KDE for' + df_clean3.index.levels[0].values[0])

# %%
df_i3 = df_clean3.copy()

# %%
# %%time
print('Train and evaluate model for ' + df_i3.index.levels[0].values[0])
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsi3 = VIAnomalyScore(['Ap'], ['Vx'])
et = spsi3._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
spsi3._entity_type = et
df_i3 = spsi.execute(df=df_i3)

EngineLogging.configure_console_logging(logging.INFO)
df_i3.describe()
# Out:
# Train and evaluate model for 04714B6036B1
# 2020-12-22T15:50:44.327 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2020-12-22T15:50:44.328 DEBUG mmfunctions.anomaly.__init__ init KDE Estimator
# 2020-12-22T15:50:44.328 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.2.1
# 2020-12-22T15:50:44.329 DEBUG iotfunctions.util.__init__ Starting trace
# 2020-12-22T15:50:44.330 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20201222145044
# 2020-12-22T15:50:44.330 DEBUG iotfunctions.util.__init__ auto_save None
# 2020-12-22T15:50:44.331 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2020-12-22T15:50:44.331 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2020-12-22T15:50:44.332 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# Here 1 <class 'pandas.core.frame.DataFrame'>
# 2020-12-22T15:50:44.338 DEBUG mmfunctions.anomaly.execute ['04714B6036B1']
# ['Ap']
# 2020-12-22T15:50:44.552 INFO iotfunctions.dbtables.retrieve_model Model model.TEST_ENTITY_FOR_VIANOMALYSCORE.VIAnomalyScore.Vx.04714B6036B1 does not exist in filesystem
# 2020-12-22T15:50:44.552 INFO mmfunctions.anomaly.execute load model None
# 2020-12-22T15:50:45.588 DEBUG mmfunctions.anomaly.execute Epoch: 0, Loss: 0.8325163125991821
# 2020-12-22T15:50:56.103 DEBUG mmfunctions.anomaly.execute Epoch: 10, Loss: 0.5652421712875366
# 2020-12-22T15:51:06.955 DEBUG mmfunctions.anomaly.execute Epoch: 20, Loss: 0.5153636932373047
# 2020-12-22T15:51:17.711 DEBUG mmfunctions.anomaly.execute Epoch: 30, Loss: 0.4913690984249115
# 2020-12-22T15:51:28.383 DEBUG mmfunctions.anomaly.execute Epoch: 40, Loss: 0.4863063097000122
# 2020-12-22T15:51:38.963 DEBUG mmfunctions.anomaly.execute Epoch: 50, Loss: 0.4872589111328125
# 2020-12-22T15:51:49.619 DEBUG mmfunctions.anomaly.execute Epoch: 60, Loss: 0.486362099647522
# 2020-12-22T15:51:59.948 DEBUG mmfunctions.anomaly.execute Epoch: 70, Loss: 0.48674455285072327
# 2020-12-22T15:52:10.797 DEBUG mmfunctions.anomaly.execute Epoch: 80, Loss: 0.48609670996665955
# 2020-12-22T15:52:21.633 DEBUG mmfunctions.anomaly.execute Epoch: 90, Loss: 0.48684075474739075
# 2020-12-22T15:52:32.288 DEBUG mmfunctions.anomaly.execute Epoch: 100, Loss: 0.48644647002220154
# 2020-12-22T15:52:43.031 DEBUG mmfunctions.anomaly.execute Epoch: 110, Loss: 0.4854465425014496
# 2020-12-22T15:52:53.978 DEBUG mmfunctions.anomaly.execute Epoch: 120, Loss: 0.48618194460868835
# 2020-12-22T15:53:04.776 DEBUG mmfunctions.anomaly.execute Epoch: 130, Loss: 0.4873572289943695
# 2020-12-22T15:53:15.521 DEBUG mmfunctions.anomaly.execute Epoch: 140, Loss: 0.4859188497066498
# 2020-12-22T15:53:26.247 DEBUG mmfunctions.anomaly.execute Epoch: 150, Loss: 0.48691684007644653
# 2020-12-22T15:53:37.112 DEBUG mmfunctions.anomaly.execute Epoch: 160, Loss: 0.4861513674259186
# 2020-12-22T15:53:48.188 DEBUG mmfunctions.anomaly.execute Epoch: 170, Loss: 0.48652270436286926
# 2020-12-22T15:53:58.871 DEBUG mmfunctions.anomaly.execute Epoch: 180, Loss: 0.4864473342895508
# 2020-12-22T15:54:09.567 DEBUG mmfunctions.anomaly.execute Epoch: 190, Loss: 0.4863928258419037
# 2020-12-22T15:54:20.527 DEBUG mmfunctions.anomaly.execute Epoch: 200, Loss: 0.48636096715927124
# 2020-12-22T15:54:31.252 DEBUG mmfunctions.anomaly.execute Epoch: 210, Loss: 0.48703843355178833
# 2020-12-22T15:54:42.669 DEBUG mmfunctions.anomaly.execute Epoch: 220, Loss: 0.48699185252189636
# 2020-12-22T15:54:53.437 DEBUG mmfunctions.anomaly.execute Epoch: 230, Loss: 0.4859136939048767
# 2020-12-22T15:55:04.288 DEBUG mmfunctions.anomaly.execute Epoch: 240, Loss: 0.4861014187335968
# 2020-12-22T15:55:15.210 DEBUG mmfunctions.anomaly.execute Epoch: 250, Loss: 0.48731422424316406
# 2020-12-22T15:55:26.216 DEBUG mmfunctions.anomaly.execute Epoch: 260, Loss: 0.48592686653137207
# 2020-12-22T15:55:39.288 DEBUG mmfunctions.anomaly.execute Epoch: 270, Loss: 0.48709630966186523
# 2020-12-22T15:55:50.662 DEBUG mmfunctions.anomaly.execute Epoch: 280, Loss: 0.4863559305667877
# 2020-12-22T15:56:01.874 DEBUG mmfunctions.anomaly.execute Epoch: 290, Loss: 0.4861152470111847
# 2020-12-22T15:56:13.266 DEBUG mmfunctions.anomaly.execute Epoch: 300, Loss: 0.4857954978942871
# 2020-12-22T15:56:24.917 DEBUG mmfunctions.anomaly.execute Epoch: 310, Loss: 0.48659488558769226
# 2020-12-22T15:56:38.002 DEBUG mmfunctions.anomaly.execute Epoch: 320, Loss: 0.486554354429245
# 2020-12-22T15:56:50.738 DEBUG mmfunctions.anomaly.execute Epoch: 330, Loss: 0.4864659309387207
# 2020-12-22T15:57:04.072 DEBUG mmfunctions.anomaly.execute Epoch: 340, Loss: 0.48656079173088074
# 2020-12-22T15:57:16.402 DEBUG mmfunctions.anomaly.execute Epoch: 350, Loss: 0.4858933687210083
# 2020-12-22T15:57:28.602 DEBUG mmfunctions.anomaly.execute Epoch: 360, Loss: 0.48608890175819397
# 2020-12-22T15:57:40.958 DEBUG mmfunctions.anomaly.execute Epoch: 370, Loss: 0.4864509105682373
# 2020-12-22T15:57:56.109 DEBUG mmfunctions.anomaly.execute Epoch: 380, Loss: 0.48563650250434875
# 2020-12-22T15:58:11.466 DEBUG mmfunctions.anomaly.execute Epoch: 390, Loss: 0.48714694380760193
# 2020-12-22T15:58:32.321 DEBUG mmfunctions.anomaly.execute Epoch: 400, Loss: 0.487199604511261
# 2020-12-22T15:58:56.036 DEBUG mmfunctions.anomaly.execute Epoch: 410, Loss: 0.4866694509983063
# 2020-12-22T15:59:17.196 DEBUG mmfunctions.anomaly.execute Epoch: 420, Loss: 0.4864768385887146
# 2020-12-22T15:59:36.088 DEBUG mmfunctions.anomaly.execute Epoch: 430, Loss: 0.4860832095146179
# 2020-12-22T15:59:55.002 DEBUG mmfunctions.anomaly.execute Epoch: 440, Loss: 0.4863526523113251
# 2020-12-22T16:00:11.835 DEBUG mmfunctions.anomaly.execute Epoch: 450, Loss: 0.48591163754463196
# 2020-12-22T16:00:29.052 DEBUG mmfunctions.anomaly.execute Epoch: 460, Loss: 0.48736992478370667
# 2020-12-22T16:00:46.637 DEBUG mmfunctions.anomaly.execute Epoch: 470, Loss: 0.486917644739151
# 2020-12-22T16:01:04.056 DEBUG mmfunctions.anomaly.execute Epoch: 480, Loss: 0.48650404810905457
# 2020-12-22T16:01:23.137 DEBUG mmfunctions.anomaly.execute Epoch: 490, Loss: 0.48635298013687134
# 2020-12-22T16:01:40.722 DEBUG mmfunctions.anomaly.execute Epoch: 500, Loss: 0.4861403703689575
# 2020-12-22T16:01:59.116 DEBUG mmfunctions.anomaly.execute Epoch: 510, Loss: 0.48623207211494446
# 2020-12-22T16:02:18.820 DEBUG mmfunctions.anomaly.execute Epoch: 520, Loss: 0.4860113859176636
# 2020-12-22T16:02:36.960 DEBUG mmfunctions.anomaly.execute Epoch: 530, Loss: 0.4870612919330597
# 2020-12-22T16:02:56.152 DEBUG mmfunctions.anomaly.execute Epoch: 540, Loss: 0.4864642918109894
# 2020-12-22T16:03:14.533 DEBUG mmfunctions.anomaly.execute Epoch: 550, Loss: 0.4874727129936218
# 2020-12-22T16:03:34.348 DEBUG mmfunctions.anomaly.execute Epoch: 560, Loss: 0.48634791374206543
# 2020-12-22T16:03:53.736 DEBUG mmfunctions.anomaly.execute Epoch: 570, Loss: 0.48615625500679016
# 2020-12-22T16:04:14.594 DEBUG mmfunctions.anomaly.execute Epoch: 580, Loss: 0.48614296317100525
# 2020-12-22T16:04:36.694 DEBUG mmfunctions.anomaly.execute Epoch: 590, Loss: 0.48542025685310364
# 2020-12-22T16:04:54.580 DEBUG mmfunctions.anomaly.execute Epoch: 600, Loss: 0.4853813946247101
# 2020-12-22T16:05:13.723 DEBUG mmfunctions.anomaly.execute Epoch: 610, Loss: 0.4863088130950928
# 2020-12-22T16:05:34.084 DEBUG mmfunctions.anomaly.execute Epoch: 620, Loss: 0.4867885112762451
# 2020-12-22T16:05:58.037 DEBUG mmfunctions.anomaly.execute Epoch: 630, Loss: 0.4858531951904297
# 2020-12-22T16:06:19.762 DEBUG mmfunctions.anomaly.execute Epoch: 640, Loss: 0.48698464035987854
# 2020-12-22T16:06:37.212 DEBUG mmfunctions.anomaly.execute Epoch: 650, Loss: 0.48672446608543396
# 2020-12-22T16:06:55.175 DEBUG mmfunctions.anomaly.execute Epoch: 660, Loss: 0.4864636957645416
# 2020-12-22T16:07:12.830 DEBUG mmfunctions.anomaly.execute Epoch: 670, Loss: 0.48536059260368347
# 2020-12-22T16:07:33.552 DEBUG mmfunctions.anomaly.execute Epoch: 680, Loss: 0.4857752025127411
# 2020-12-22T16:07:54.241 DEBUG mmfunctions.anomaly.execute Epoch: 690, Loss: 0.48669639229774475
# 2020-12-22T16:08:10.764 DEBUG mmfunctions.anomaly.execute Epoch: 700, Loss: 0.4875572919845581
# 2020-12-22T16:08:27.718 DEBUG mmfunctions.anomaly.execute Epoch: 710, Loss: 0.4861690402030945
# 2020-12-22T16:08:48.223 DEBUG mmfunctions.anomaly.execute Epoch: 720, Loss: 0.4854114055633545
# 2020-12-22T16:09:10.729 DEBUG mmfunctions.anomaly.execute Epoch: 730, Loss: 0.48605582118034363
# 2020-12-22T16:09:31.181 DEBUG mmfunctions.anomaly.execute Epoch: 740, Loss: 0.48728975653648376
# 2020-12-22T16:09:41.966 DEBUG mmfunctions.anomaly.execute Epoch: 750, Loss: 0.4858241081237793
# 2020-12-22T16:09:52.462 DEBUG mmfunctions.anomaly.execute Epoch: 760, Loss: 0.4855801463127136
# 2020-12-22T16:10:02.648 DEBUG mmfunctions.anomaly.execute Epoch: 770, Loss: 0.48650646209716797
# 2020-12-22T16:10:13.460 DEBUG mmfunctions.anomaly.execute Epoch: 780, Loss: 0.4863134026527405
# 2020-12-22T16:10:24.221 DEBUG mmfunctions.anomaly.execute Epoch: 790, Loss: 0.48651033639907837
# 2020-12-22T16:10:34.580 DEBUG mmfunctions.anomaly.execute Epoch: 800, Loss: 0.48592084646224976
# 2020-12-22T16:10:45.270 DEBUG mmfunctions.anomaly.execute Epoch: 810, Loss: 0.4858454465866089
# 2020-12-22T16:10:55.837 DEBUG mmfunctions.anomaly.execute Epoch: 820, Loss: 0.4861123859882355
# 2020-12-22T16:11:07.126 DEBUG mmfunctions.anomaly.execute Epoch: 830, Loss: 0.48574298620224
# 2020-12-22T16:11:17.557 DEBUG mmfunctions.anomaly.execute Epoch: 840, Loss: 0.48601198196411133
# 2020-12-22T16:11:28.256 DEBUG mmfunctions.anomaly.execute Epoch: 850, Loss: 0.48634594678878784
# 2020-12-22T16:11:38.814 DEBUG mmfunctions.anomaly.execute Epoch: 860, Loss: 0.4857790172100067
# 2020-12-22T16:11:49.332 DEBUG mmfunctions.anomaly.execute Epoch: 870, Loss: 0.4871848523616791
# 2020-12-22T16:11:59.930 DEBUG mmfunctions.anomaly.execute Epoch: 880, Loss: 0.4860883057117462
# 2020-12-22T16:12:11.145 DEBUG mmfunctions.anomaly.execute Epoch: 890, Loss: 0.48607900738716125
# 2020-12-22T16:12:21.549 DEBUG mmfunctions.anomaly.execute Epoch: 900, Loss: 0.4859886169433594
# 2020-12-22T16:12:32.143 DEBUG mmfunctions.anomaly.execute Epoch: 910, Loss: 0.48615342378616333
# 2020-12-22T16:12:42.831 DEBUG mmfunctions.anomaly.execute Epoch: 920, Loss: 0.48666912317276
# 2020-12-22T16:12:54.207 DEBUG mmfunctions.anomaly.execute Epoch: 930, Loss: 0.4866842031478882
# 2020-12-22T16:13:05.347 DEBUG mmfunctions.anomaly.execute Epoch: 940, Loss: 0.4850946366786957
# 2020-12-22T16:13:16.280 DEBUG mmfunctions.anomaly.execute Epoch: 950, Loss: 0.48710891604423523
# 2020-12-22T16:13:27.371 DEBUG mmfunctions.anomaly.execute Epoch: 960, Loss: 0.486395925283432
# 2020-12-22T16:13:38.240 DEBUG mmfunctions.anomaly.execute Epoch: 970, Loss: 0.48582524061203003
# 2020-12-22T16:13:49.514 DEBUG mmfunctions.anomaly.execute Epoch: 980, Loss: 0.4864894449710846
# 2020-12-22T16:14:00.490 DEBUG mmfunctions.anomaly.execute Epoch: 990, Loss: 0.48681971430778503
# 2020-12-22T16:14:12.278 DEBUG mmfunctions.anomaly.execute Epoch: 1000, Loss: 0.4864182472229004
# 2020-12-22T16:14:23.575 DEBUG mmfunctions.anomaly.execute Epoch: 1010, Loss: 0.487104594707489
# 2020-12-22T16:14:34.735 DEBUG mmfunctions.anomaly.execute Epoch: 1020, Loss: 0.48670080304145813
# 2020-12-22T16:14:46.180 DEBUG mmfunctions.anomaly.execute Epoch: 1030, Loss: 0.4866601526737213
# 2020-12-22T16:14:58.478 DEBUG mmfunctions.anomaly.execute Epoch: 1040, Loss: 0.48662593960762024
# 2020-12-22T16:15:09.799 DEBUG mmfunctions.anomaly.execute Epoch: 1050, Loss: 0.4856388568878174
# 2020-12-22T16:15:20.386 DEBUG mmfunctions.anomaly.execute Epoch: 1060, Loss: 0.48538678884506226
# 2020-12-22T16:15:30.865 DEBUG mmfunctions.anomaly.execute Epoch: 1070, Loss: 0.48568153381347656
# 2020-12-22T16:15:41.711 DEBUG mmfunctions.anomaly.execute Epoch: 1080, Loss: 0.4858759641647339
# 2020-12-22T16:15:52.250 DEBUG mmfunctions.anomaly.execute Epoch: 1090, Loss: 0.4856809377670288
# 2020-12-22T16:16:03.035 DEBUG mmfunctions.anomaly.execute Epoch: 1100, Loss: 0.48627591133117676
# 2020-12-22T16:16:14.084 DEBUG mmfunctions.anomaly.execute Epoch: 1110, Loss: 0.4862355887889862
# 2020-12-22T16:16:25.733 DEBUG mmfunctions.anomaly.execute Epoch: 1120, Loss: 0.48609238862991333
# 2020-12-22T16:16:36.640 DEBUG mmfunctions.anomaly.execute Epoch: 1130, Loss: 0.4869769811630249
# 2020-12-22T16:16:47.439 DEBUG mmfunctions.anomaly.execute Epoch: 1140, Loss: 0.4861745238304138
# 2020-12-22T16:16:58.072 DEBUG mmfunctions.anomaly.execute Epoch: 1150, Loss: 0.486310750246048
# 2020-12-22T16:17:09.259 DEBUG mmfunctions.anomaly.execute Epoch: 1160, Loss: 0.48594656586647034
# 2020-12-22T16:17:20.027 DEBUG mmfunctions.anomaly.execute Epoch: 1170, Loss: 0.4859270751476288
# 2020-12-22T16:17:30.787 DEBUG mmfunctions.anomaly.execute Epoch: 1180, Loss: 0.48596322536468506
# 2020-12-22T16:17:41.901 DEBUG mmfunctions.anomaly.execute Epoch: 1190, Loss: 0.4862907826900482
# 2020-12-22T16:17:53.092 DEBUG mmfunctions.anomaly.execute Epoch: 1200, Loss: 0.4856567978858948
# 2020-12-22T16:18:05.058 DEBUG mmfunctions.anomaly.execute Epoch: 1210, Loss: 0.4859086275100708
# 2020-12-22T16:18:17.537 DEBUG mmfunctions.anomaly.execute Epoch: 1220, Loss: 0.48617538809776306
# 2020-12-22T16:18:30.283 DEBUG mmfunctions.anomaly.execute Epoch: 1230, Loss: 0.4870046377182007
# 2020-12-22T16:18:42.879 DEBUG mmfunctions.anomaly.execute Epoch: 1240, Loss: 0.48572883009910583
# 2020-12-22T16:18:55.700 DEBUG mmfunctions.anomaly.execute Epoch: 1250, Loss: 0.48631376028060913
# 2020-12-22T16:19:08.318 DEBUG mmfunctions.anomaly.execute Epoch: 1260, Loss: 0.4862262010574341
# 2020-12-22T16:19:21.067 DEBUG mmfunctions.anomaly.execute Epoch: 1270, Loss: 0.4854844808578491
# 2020-12-22T16:19:33.953 DEBUG mmfunctions.anomaly.execute Epoch: 1280, Loss: 0.48578497767448425
# 2020-12-22T16:19:48.351 DEBUG mmfunctions.anomaly.execute Epoch: 1290, Loss: 0.485117107629776
# 2020-12-22T16:20:03.213 DEBUG mmfunctions.anomaly.execute Epoch: 1300, Loss: 0.4853770136833191
# 2020-12-22T16:20:19.919 DEBUG mmfunctions.anomaly.execute Epoch: 1310, Loss: 0.4856608510017395
# 2020-12-22T16:20:38.667 DEBUG mmfunctions.anomaly.execute Epoch: 1320, Loss: 0.48569896817207336
# 2020-12-22T16:20:55.478 DEBUG mmfunctions.anomaly.execute Epoch: 1330, Loss: 0.48554328083992004
# 2020-12-22T16:21:13.278 DEBUG mmfunctions.anomaly.execute Epoch: 1340, Loss: 0.4855981767177582
# 2020-12-22T16:21:30.950 DEBUG mmfunctions.anomaly.execute Epoch: 1350, Loss: 0.48531609773635864
# 2020-12-22T16:21:49.096 DEBUG mmfunctions.anomaly.execute Epoch: 1360, Loss: 0.48670801520347595
# 2020-12-22T16:22:05.546 DEBUG mmfunctions.anomaly.execute Epoch: 1370, Loss: 0.4852875769138336
# 2020-12-22T16:22:22.686 DEBUG mmfunctions.anomaly.execute Epoch: 1380, Loss: 0.4848087430000305
# 2020-12-22T16:22:39.363 DEBUG mmfunctions.anomaly.execute Epoch: 1390, Loss: 0.4856317639350891
# 2020-12-22T16:22:55.841 DEBUG mmfunctions.anomaly.execute Epoch: 1400, Loss: 0.4858027994632721
# 2020-12-22T16:23:12.857 DEBUG mmfunctions.anomaly.execute Epoch: 1410, Loss: 0.4848630726337433
# 2020-12-22T16:23:29.226 DEBUG mmfunctions.anomaly.execute Epoch: 1420, Loss: 0.4854389727115631
# 2020-12-22T16:23:45.377 DEBUG mmfunctions.anomaly.execute Epoch: 1430, Loss: 0.486282616853714
# 2020-12-22T16:24:01.841 DEBUG mmfunctions.anomaly.execute Epoch: 1440, Loss: 0.4853481650352478
# 2020-12-22T16:24:18.709 DEBUG mmfunctions.anomaly.execute Epoch: 1450, Loss: 0.48608991503715515
# 2020-12-22T16:24:35.701 DEBUG mmfunctions.anomaly.execute Epoch: 1460, Loss: 0.4854182004928589
# 2020-12-22T16:24:54.074 DEBUG mmfunctions.anomaly.execute Epoch: 1470, Loss: 0.48608341813087463
# 2020-12-22T16:25:11.277 DEBUG mmfunctions.anomaly.execute Epoch: 1480, Loss: 0.48522114753723145
# 2020-12-22T16:25:27.729 DEBUG mmfunctions.anomaly.execute Epoch: 1490, Loss: 0.4852508306503296
# 2020-12-22T16:25:44.498 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# <ipython-input-32-c9f26aead716>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   get_ipython().run_cell_magic('time', '', "print('Train and evaluate model for ' + df_i3.index.levels[0].values[0])\n# Now run the anomaly functions as if they were executed in a pipeline\nEngineLogging.configure_console_logging(logging.DEBUG)\njobsettings = { 'db': db, \n               '_db_schema': 'public', 'save_trace_to_file' : True}\n\nspsi3 = VIAnomalyScore(['Ap'], ['Vx'])\net = spsi3._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)\nspsi3._entity_type = et\ndf_i3 = spsi.execute(df=df_i3)\n\nEngineLogging.configure_console_logging(logging.INFO)\ndf_i3.describe()\n")
# CPU times: user 2h 33min 9s, sys: 41min 20s, total: 3h 14min 30s
# Wall time: 35min 1s
#                  Ap            Vx  predicted_Vx   pred_dev_Vx
# count  1.368975e+06  1.368975e+06  1.368975e+06  1.368975e+06
# mean   1.400429e+00  9.770501e-03  8.359868e-03  3.902670e-01
# std    1.396439e+00  8.449316e-02  2.403382e-03  1.797408e-01
# min    0.000000e+00 -9.580000e-01  6.013222e-03  2.128958e-01
# 25%    0.000000e+00 -1.370000e-02  6.013222e-03  2.128958e-01
# 50%    1.234000e+00  6.800000e-03  7.152006e-03  2.514825e-01
# 75%    3.099000e+00  2.930000e-02  1.133477e-02  5.796511e-01
# max    3.780000e+00  9.834000e-01  1.609729e-02  6.654118e-01

# %%
entity = df_i3.index.levels[0].values[0]

df_1 = df_i3.loc[entity].copy()


arr1 = np.where(df_1['Vx'] > df_1['predicted_Vx'] + df_1['pred_dev_Vx'], df_1['Vx'], 0) + \
       np.where(df_1['Vx'] < df_1['predicted_Vx'] - df_1['pred_dev_Vx'], df_1['Vx'], 0)
arr1[arr1 == 0] = np.nan
df_1['Anomaly'] = arr1

fig, ax = plt.subplots(1, 2, figsize=(20, 6), squeeze=False)

ax[0,0].scatter(df_1['Ap'], df_1['Vx'])
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'], color='green')
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'] - df_1['pred_dev_Vx'], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'] + df_1['pred_dev_Vx'], color='orange', lw=0.1)
ax[0,0].scatter(df_1['Ap'], df_1['Anomaly'], color='red', lw=2)
ax[0,0].set_xlabel('Accel Speed')
ax[0,0].set_ylabel('Vibration')
ax[0,0].legend()
ax[0,0].set_title('pump ' + entity)

ax[0,1].scatter(df_i3['Ap'], df_i3['Vx'])
ax[0,1].set_xlabel('Power')
ax[0,1].set_ylabel('Vibration')
ax[0,1].legend()
ax[0,1].set_title('pump ' + entity + ' - plain scatterplot')
# Out:
# 2020-12-22T16:26:02.429 WARNING matplotlib.legend._parse_legend_args No handles with labels found to put in legend.
# Text(0.5, 1.0, 'pump 04714B6036B1 - plain scatterplot')

# %%
df_1[df_1['Ap'] < 0.5]['Anomaly'] = np.nan
df_1[np.abs(df_1['Vx']) < 0.5]['Anomaly'] = np.nan
# Out:
# <ipython-input-34-dac41d32ec2f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[df_1['Ap'] < 0.5]['Anomaly'] = np.nan
# <ipython-input-34-dac41d32ec2f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[np.abs(df_1['Vx']) < 0.5]['Anomaly'] = np.nan

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)
#ax[0,0].plot(df_1['max'] + 2.0, lw=0.4, color='blue', label='smoothed max vib + 1')
ax[0,0].scatter(df_1.index,df_1['Vx'], lw=0.4, color='green', label='vibration')
ax[0,0].scatter(df_1.index,df_1['Ap']/3, lw=0.4, color='orange', zorder=5, label='accel speed')
ax[0,0].scatter(df_1.index, df_1['Anomaly'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i3.index.levels[0].values[0])
# Out:
# Text(0.5, 1.0, 'pump 04714B6036B1')

# %% [markdown]
# #### Approximate with Gaussian
#
# major contribution: gaussian along x/y coordinates, start with diagonal covariance matrix:
#
# likelihood:
#
# $e^{\frac{ {(\mu_0 - x)}^2}{\sigma_0} \frac{ {(\mu_1 - y)}^2}{\sigma_1}  }$

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-29b13a3a01e9> in <module>
# ----> 1 import edward
#
# ~/src/mmfunctions/src/edward/edward/__init__.py in <module>
#       3 from __future__ import print_function
#       4
# ----> 5 from edward import criticisms
#       6 from edward import inferences
#       7 from edward import models
#
# ~/src/mmfunctions/src/edward/edward/criticisms/__init__.py in <module>
#       5 from __future__ import print_function
#       6
# ----> 7 from edward.criticisms.evaluate import *
#       8 from edward.criticisms.ppc import *
#       9 from edward.criticisms.ppc_plots import *
#
# ~/src/mmfunctions/src/edward/edward/criticisms/evaluate.py in <module>
#       7 import tensorflow as tf
#       8
# ----> 9 from edward.models import RandomVariable
#      10 from edward.util import check_data, get_session, compute_multinomial_mode, \
#      11     with_binary_averaging
#
# ~/src/mmfunctions/src/edward/edward/models/__init__.py in <module>
#       5 from __future__ import print_function
#       6
# ----> 7 from edward.models.dirichlet_process import *
#       8 from edward.models.empirical import *
#       9 from edward.models.param_mixture import *
#
# ~/src/mmfunctions/src/edward/edward/models/dirichlet_process.py in <module>
#       6
#       7 from edward.models.random_variable import RandomVariable
# ----> 8 from tensorflow.contrib.distributions import Distribution
#       9
#      10 try:
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
# theta_0, theta_1 = mu_0/mu_1, theta_2/theta_3 = sigma_0/ sigma_1
def log_likelihood(theta, F, e):
    
    
    return np.sum(theta[0]
        
        np.log(2 * np.pi * (theta[1] ** 2 + theta[2] ** 2))
                         + (theta[0]) ** 2 / (theta[1] ** 2 + theta[2] ** 2))



def log_prior(theta):
    # sigma needs to be positive.
    if theta[1] <= 0:
        return -np.inf
    else:
        return 0

def log_posterior(theta, F, e):
    return log_prior(theta) + log_likelihood(theta, F, e)

# same setup as above:
ndim, nwalkers = 2, 50
nsteps, nburn = 2000, 1000

starting_guesses = np.random.rand(nwalkers, ndim)
starting_guesses[:, 0] *= 2000  # start mu between 0 and 2000
starting_guesses[:, 1] *= 20    # start sigma between 0 and 20

sampler = emcee.EnsembleSampler(nwalkers, ndim, log_posterior, args=[F, e])
sampler.run_mcmc(starting_guesses, nsteps)

sample = sampler.chain  # shape = (nwalkers, nsteps, ndim)
sample = sampler.chain[:, nburn:, :].reshape(-1, 2)
