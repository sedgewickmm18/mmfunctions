# %% [markdown]
# ### Preparation steps
#
# Install iotfunctions with
#
# `pip install git+https://github.com/ibm-watson-iot/functions@development`
#
# This projects contains the code for the Analytics Service pipeline as well as the anomaly functions and should pull in most of this notebook's dependencies.
#
# The plotting library matplotlib is the exception, so you need to run
# `pip install matplotlib`
#
#
# #### Unpacking the data
#
# Data is stored in `ArmstarkPumps_3408_36B1_096.tar.bz2`
#
# Please run `tar xfj ArmstarkPumps_3408_36B1_096.tar.bz2` to unpack it prior to running this notebook. You should find
#
# ```
# -rw-rw-r-- 1 markus markus 72361832 Dez 22 17:10 04714B603408.csv
# -rw-rw-r-- 1 markus markus 71782702 Dez 22 16:43 04714B6036B1.csv
# -rw-rw-r-- 1 markus markus 50373659 Dez 22 16:43 IOT_PUMP_DE_GEN5_202012141519.csv
# ```

# %%
# Real life data

import logging
import threading
import itertools
import math
import datetime
import pandas as pd  
import numpy as np  
import scipy as sp
import json
import ibm_db

import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d
import seaborn as seabornInstance
from sqlalchemy import Column, Integer, String, Float, DateTime, Boolean, func
from iotfunctions import base
from iotfunctions import bif
from iotfunctions import entity
from iotfunctions import metadata
from iotfunctions.metadata import EntityType
from iotfunctions.db import Database
from iotfunctions.dbtables import FileModelStore, DBModelStore
from iotfunctions.enginelog import EngineLogging
from iotfunctions import estimator
from iotfunctions.bif import PythonExpression
from iotfunctions.ui import (UISingle, UIMultiItem, UIFunctionOutSingle,
                 UISingleItem, UIFunctionOutMulti, UIMulti, UIExpression,
                 UIText, UIStatusFlag, UIParameters)
from iotfunctions.anomaly import (SaliencybasedGeneralizedAnomalyScore, SpectralAnomalyScore,
                 FFTbasedGeneralizedAnomalyScore, KMeansAnomalyScore,
                 SaliencybasedGeneralizedAnomalyScoreV2, FFTbasedGeneralizedAnomalyScoreV2, 
                 KMeansAnomalyScoreV2, BayesRidgeRegressor,)
from mmfunctions.anomaly import (FeatureBuilder, GBMForecaster, KDEAnomalyScore, VIAnomalyScore)
from poc.functions import State_Timer
import datetime as dt
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn import metrics
from pandas.plotting import register_matplotlib_converters
import seaborn as sns
register_matplotlib_converters()

EngineLogging.configure_console_logging(logging.INFO)
# Out:
# Warning: confluent_kafka is not installed. Publish to MessageHub not supported.

# %%
# set up a db object with a FileModelStore to support scaling
with open('credentials_as_beta3.json', encoding='utf-8') as F:
    credentials = json.loads(F.read())
db_schema=None
#fm = FileModelStore()
#db = Database(credentials=credentials, model_store=fm)
# 11390 is the entity type id of shadow_pump_de_gen5
db=Database(credentials=credentials, entity_type_id=11930)


# 11390 is the entity type id of shadow_pump_de_gen5
if db.model_store is None:
     db.model_store = DBModelStore('beta-3', 11390, 'bluadmin', db.native_connection, db.db_type)

print (db)
# Out:
# <iotfunctions.db.Database object at 0x7ff11c1483a0>

# %%
db.native_connection

# %%
def load_data(filename):
    # load data
    df_input = pd.read_csv(filename, parse_dates=['RCV_TIMESTAMP_UTC'], comment='#')
    #df_input = df_input.asfreq('H')
    df_input = df_input.sort_values(by='RCV_TIMESTAMP_UTC').\
                    rename(columns={'RCV_TIMESTAMP_UTC':'timestamp', 'DEVICEID': 'entity'}).\
                    drop(columns=['DEVICETYPE','ID','FORMAT','UPDATED_UTC','LOGICALINTERFACE_ID','PUMP_MODE',\
                                  'DEVICE_ID','FIRMWARE_VER','PTS_COUNT','SERIAL_NUMBER', 'HARDWARE_VER',\
                                  'TAG_NUMBER','PWR','HW_VER','DQ','FW_VER','PTS','PERF_OPTION']).\
                    drop(columns=['VIBRATION_N_XAXIS','VIBRATION_N_YAXIS','VIBRATION_N_ZAXIS','REATED_POWER',\
                                  'RATED_SPEED','RATED_CURRENT','RMSN_X','RMSN_Y','RMSN_Z','RUN_QTY',\
                                  'DESIGN_HEAD','DESIGN_FLOW','RMS_X_AVG'])

    df_input = df_input[df_input['VERSION'] != 0].drop(columns=['VERSION'])
    
    
    return df_input


    
def prep_data(df_input):
    entity = df_input['entity'].values[0]
    
    list_ac_vx = []
    cnt = 0
    for idx,row in df_input[['timestamp','VIBRATIONS_XAXIS','VIBRATIONS_YAXIS','VIBRATIONS_ZAXIS',
                             'ACCEL_POWER','ACCEL_SPEED']].iterrows():
        if isinstance(row['timestamp'], str):
            ts = datetime.datetime.strptime(row['timestamp'], '%Y-%m-%d-%H.%M.%S.%f')
        else:
            ts = row['timestamp']
            
        rvibxs = row['VIBRATIONS_XAXIS']
        rvibys = row['VIBRATIONS_YAXIS']
        rvibzs = row['VIBRATIONS_ZAXIS']
        racc = row['ACCEL_POWER']
        rspd = row['ACCEL_SPEED']

        if isinstance(racc, str):
            racc = eval(racc)
        if isinstance(rspd, str):
            rspd = eval(rspd)
            
        if isinstance(rvibxs, str):
            list_ac = []
           
            for ac in racc:
                #print(ac)
                list_ac.append(eval(ac))
                list_ac.append(eval(ac))
                list_ac.append(eval(ac))
                #print (list_ac)
            
            list_as = []
            for as_ in rspd:
                list_as.append(eval(as_))
                list_as.append(eval(as_))
                list_as.append(eval(as_))
            
            list_vx = []
            for vx in eval(rvibxs):
                list_vx.append(vx)
                #print (list_vx)
            
            list_vy = []
            for vy in eval(rvibys):
                list_vy.append(vy)
            
            list_vz = []
            for vz in eval(rvibzs):
                list_vz.append(vz)

            #print(list_ac, list_vx)
            cnt2 = 0
            for p in zip(list_ac, list_as, list_vx, list_vy, list_vz):
                #print(ts + datetime.timedelta(seconds = cnt2 * 10), p[0],p[1])
                list_ac_vx.append([ts + datetime.timedelta(seconds = cnt2 * 10), p[0],p[1],p[2],p[3],p[4]])
                cnt2 += 1
        cnt += 1

    df_clean = pd.DataFrame(list_ac_vx, columns=['timestamp','power','speed','rms_x', 'rms_y', 'rms_z'])
    df_clean['entity'] = entity
    
    return df_clean.set_index(['entity','timestamp'])

# %%
#df_clean = prep_data(load_data('./IOT_PUMP_DE_GEN5_202012141519.csv'))

#df_clean.head(2)

# %%
filename = "./IOT_SHADOW_PUMP_DE_GEN5_202102111449.csv"
dff = pd.read_csv(filename, parse_dates=['EVT_TIMESTAMP'], comment='#')
dff.columns = dff.columns.str.lower() 
df_clean = dff.drop(columns=['devicetype','logicalinterface_id','eventtype','format',
                             'rcv_timestamp_utc','updated_utc']).set_index(['deviceid','evt_timestamp'])

# %%
df_clean
# Out:
#                                             rms_x     rms_z     rms_y   power  \
# deviceid     evt_timestamp
# 04714B601096 2020-07-19-10.15.05.144000  0.095934  0.059262  0.956817  1.7270
#              2020-07-19-10.15.25.144000  0.093044  0.060636  0.957341  1.7298
#              2020-07-19-10.15.45.144000  0.090586  0.062215  0.956682  1.7298
#              2020-07-19-10.16.05.144000       NaN       NaN       NaN  1.7298
#              2020-07-19-10.16.25.144000       NaN       NaN       NaN  1.7318
# ...                                           ...       ...       ...     ...
# 04714B606390 2021-02-11-08.52.46.662000       NaN       NaN       NaN  2.2874
#              2021-02-11-08.53.06.662000       NaN       NaN       NaN  2.2874
#              2021-02-11-08.53.26.662000       NaN       NaN       NaN  2.2882
#              2021-02-11-08.53.46.662000       NaN       NaN       NaN  2.2882
#              2021-02-11-08.54.06.662000       NaN       NaN       NaN  2.2882
#
#                                           speed
# deviceid     evt_timestamp
# 04714B601096 2020-07-19-10.15.05.144000  1059.0
#              2020-07-19-10.15.25.144000  1059.0
#              2020-07-19-10.15.45.144000  1059.0
#              2020-07-19-10.16.05.144000  1059.0
#              2020-07-19-10.16.25.144000  1059.0
# ...                                         ...
# 04714B606390 2021-02-11-08.52.46.662000  1299.0
#              2021-02-11-08.53.06.662000  1299.0
#              2021-02-11-08.53.26.662000  1298.0
#              2021-02-11-08.53.46.662000  1298.0
#              2021-02-11-08.54.06.662000  1298.0
#
# [2287890 rows x 5 columns]

# %%
df_clean.index.levels[0].values[1]
# Out:
# '04714B603408'

# %%
#plt.figure(figsize=(20, 6))

df_display = df_clean[df_clean['speed'] > 1000]

sns.set_style('ticks')
#fig, ax = plt.subplots(1,1,figsize=(20,8))
gx = sns.displot(df_display[['speed','rms_x']], x='speed', y='rms_x', kind="kde", 
                 rug=False, height=6, aspect=2)
    
gx.set_titles('KDE for' + df_clean.index.levels[0].values[0])

# %%
#plt.figure(figsize=(16, 6))
sns.set_style('ticks')
#fig, ax = plt.subplots(1,1,figsize=(20,8))
gy = sns.displot(df_display[['speed','rms_y']], x='speed', y='rms_y', kind="kde", 
                 rug=False, height=6, aspect=2)
gy.set_titles('KDE for' + df_clean.index.levels[0].values[0])

# %%
# prepare
delete_model = False
df_i = df_clean.dropna()
#df_i['speed'] /= 10
# Out:
# 2021-02-11T14:55:52.302 INFO numexpr.utils._init_num_threads Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2021-02-11T14:55:52.302 INFO numexpr.utils._init_num_threads NumExpr defaulting to 8 threads.

# %%
# %%time
print('Train and evaluate model for ' + df_i.index.levels[0].values[0])
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsi = VIAnomalyScore(['speed'], ['rms_x'])
#spsi.epochs = 1  # only for testing model storage
spsi.epochs = 300

spsi.auto_train = True
spsi.delete_model = delete_model
et = spsi._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
et.name = 'IOT_SHADOW_PUMP_DE_GEN5'



spsi._entity_type = et
df_i = spsi.execute(df=df_i)

EngineLogging.configure_console_logging(logging.INFO)
df_i.describe()
# Out:
# Train and evaluate model for 04714B601096
# 2021-02-11T14:56:07.484 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2021-02-11T14:56:07.487 DEBUG root.__init__ __init__VIAnomalyScore
# 2021-02-11T14:56:07.488 DEBUG root.__init__ __init__ done with parameters: speed.rms_x
# 2021-02-11T14:56:07.490 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.3.1
# 2021-02-11T14:56:07.491 DEBUG iotfunctions.util.__init__ Starting trace
# 2021-02-11T14:56:07.492 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20210211135607
# 2021-02-11T14:56:07.494 DEBUG iotfunctions.util.__init__ auto_save None
# 2021-02-11T14:56:07.495 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2021-02-11T14:56:07.496 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2021-02-11T14:56:07.496 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# 2021-02-11T14:56:07.507 DEBUG mmfunctions.anomaly.execute VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'>
# 2021-02-11T14:56:07.508 DEBUG mmfunctions.anomaly.execute ['04714B601096' '04714B603408' '04714B6036B1' '04714B6037F8'
#  '04714B604101' '04714B606390']
# ['speed']
# 2021-02-11T14:56:10.198 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B601096 of size 16618 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T14:56:10.209 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T14:56:10.271 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.2014988813574559
# ['speed']
# 2021-02-11T14:56:11.193 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B603408 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T14:56:11.194 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T14:56:11.242 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.014546396186272847
# 2021-02-11T14:56:11.264 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B603408Prior mean: 0.0, sigma: 0.015483930784374171
# 2021-02-11T14:56:11.295 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([88365, 1]) Sigma: torch.Size([88365, 1]) loglikelihood: torch.Size([88365, 1]) KL value: tensor(-26.4463, grad_fn=<MeanBackward0>)
# 2021-02-11T14:56:11.299 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([88365, 1]) Sigma: torch.Size([88365, 1]) loglikelihood: torch.Size([88365, 1]) KL: torch.Size([]) KL value: tensor(958.7089, grad_fn=<MulBackward0>)
# 2021-02-11T14:56:11.300 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 27.311119079589844 neg ELBO G: 960.0654907226562
# 2021-02-11T14:56:11.952 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 19.155555725097656 neg ELBO G: 4272.8017578125
# 2021-02-11T14:56:12.599 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 10.802391052246094 neg ELBO G: 17142.51953125
# 2021-02-11T14:56:13.310 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: 2.5046443939208984 neg ELBO G: 56870.140625
# 2021-02-11T14:56:14.023 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -0.7387174963951111 neg ELBO G: 121127.078125
# 2021-02-11T14:56:14.732 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.4411475658416748 neg ELBO G: 180013.890625
# 2021-02-11T14:56:15.612 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.5669020414352417 neg ELBO G: 221289.859375
# 2021-02-11T14:56:17.050 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.5944229364395142 neg ELBO G: 246482.171875
# 2021-02-11T14:56:18.405 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.6073615550994873 neg ELBO G: 261052.390625
# 2021-02-11T14:56:19.556 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.6029621362686157 neg ELBO G: 269091.90625
# 2021-02-11T14:56:20.693 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.6023391485214233 neg ELBO G: 272768.09375
# 2021-02-11T14:56:21.733 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.6049468517303467 neg ELBO G: 273857.34375
# 2021-02-11T14:56:22.890 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.6090823411941528 neg ELBO G: 273863.53125
# 2021-02-11T14:56:23.950 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.6076114177703857 neg ELBO G: 273524.71875
# 2021-02-11T14:56:24.998 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.6048654317855835 neg ELBO G: 273204.21875
# 2021-02-11T14:56:26.063 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.608195424079895 neg ELBO G: 272978.65625
# 2021-02-11T14:56:27.090 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.606740117073059 neg ELBO G: 272871.5
# 2021-02-11T14:56:28.214 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.606571078300476 neg ELBO G: 272849.46875
# 2021-02-11T14:56:29.478 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.6081830263137817 neg ELBO G: 272541.46875
# 2021-02-11T14:56:30.683 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.606890320777893 neg ELBO G: 271883.78125
# 2021-02-11T14:56:31.659 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.6061993837356567 neg ELBO G: 271771.34375
# 2021-02-11T14:56:32.602 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.6015516519546509 neg ELBO G: 271995.5
# 2021-02-11T14:56:33.607 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.606101632118225 neg ELBO G: 272313.96875
# 2021-02-11T14:56:34.629 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.6075466871261597 neg ELBO G: 272612.71875
# 2021-02-11T14:56:35.892 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.6036429405212402 neg ELBO G: 272798.96875
# 2021-02-11T14:56:37.100 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.6080589294433594 neg ELBO G: 272888.46875
# 2021-02-11T14:56:38.510 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.6064320802688599 neg ELBO G: 272901.90625
# 2021-02-11T14:56:39.575 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.6070655584335327 neg ELBO G: 272897.59375
# 2021-02-11T14:56:40.667 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.6059805154800415 neg ELBO G: 272885.34375
# 2021-02-11T14:56:41.829 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.607090950012207 neg ELBO G: 272865.53125
# 2021-02-11T14:56:42.678 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T14:56:53.269 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B603408 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T14:56:54.095 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B6036B1 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T14:56:54.098 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T14:56:54.164 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.03445810706807764
# 2021-02-11T14:56:54.183 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B6036B1Prior mean: 0.0, sigma: 0.020177142205837845
# 2021-02-11T14:56:54.214 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([88355, 1]) Sigma: torch.Size([88355, 1]) loglikelihood: torch.Size([88355, 1]) KL value: tensor(-35.5123, grad_fn=<MeanBackward0>)
# 2021-02-11T14:56:54.216 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([88355, 1]) Sigma: torch.Size([88355, 1]) loglikelihood: torch.Size([88355, 1]) KL: torch.Size([]) KL value: tensor(14450.9160, grad_fn=<MulBackward0>)
# 2021-02-11T14:56:54.216 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 36.65962600708008 neg ELBO G: 14452.4365234375
# 2021-02-11T14:56:54.974 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 11.986082077026367 neg ELBO G: 14275.7568359375
# 2021-02-11T14:56:56.023 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 1.6858769655227661 neg ELBO G: 79841.2890625
# 2021-02-11T14:56:57.341 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: 0.23136034607887268 neg ELBO G: 148101.421875
# 2021-02-11T14:56:58.613 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -0.4839420020580292 neg ELBO G: 155504.703125
# 2021-02-11T14:56:59.853 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -0.9841101169586182 neg ELBO G: 148830.15625
# 2021-02-11T14:57:00.928 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.238489031791687 neg ELBO G: 162304.625
# 2021-02-11T14:57:01.873 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.3737983703613281 neg ELBO G: 186896.859375
# 2021-02-11T14:57:03.074 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.4212843179702759 neg ELBO G: 210680.40625
# 2021-02-11T14:57:04.412 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.448812484741211 neg ELBO G: 227945.875
# 2021-02-11T14:57:05.596 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.4670865535736084 neg ELBO G: 240507.984375
# 2021-02-11T14:57:06.631 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.472822666168213 neg ELBO G: 250916.109375
# 2021-02-11T14:57:07.652 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.4790196418762207 neg ELBO G: 259473.390625
# 2021-02-11T14:57:08.630 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.4820441007614136 neg ELBO G: 266209.59375
# 2021-02-11T14:57:09.764 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.4799576997756958 neg ELBO G: 271287.65625
# 2021-02-11T14:57:11.010 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.478772759437561 neg ELBO G: 274949.0
# 2021-02-11T14:57:12.222 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.4807394742965698 neg ELBO G: 277525.78125
# 2021-02-11T14:57:13.303 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.4824552536010742 neg ELBO G: 279372.3125
# 2021-02-11T14:57:14.339 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.4841430187225342 neg ELBO G: 280593.25
# 2021-02-11T14:57:15.531 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.4811707735061646 neg ELBO G: 281419.15625
# 2021-02-11T14:57:16.583 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.4830697774887085 neg ELBO G: 281917.625
# 2021-02-11T14:57:17.712 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.4817297458648682 neg ELBO G: 282066.46875
# 2021-02-11T14:57:18.719 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.4834725856781006 neg ELBO G: 282113.875
# 2021-02-11T14:57:19.771 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.4858753681182861 neg ELBO G: 282214.625
# 2021-02-11T14:57:21.019 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.4819813966751099 neg ELBO G: 282260.15625
# 2021-02-11T14:57:22.122 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.4834932088851929 neg ELBO G: 282323.125
# 2021-02-11T14:57:23.191 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.4844720363616943 neg ELBO G: 282342.8125
# 2021-02-11T14:57:24.252 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.4844563007354736 neg ELBO G: 282280.40625
# 2021-02-11T14:57:25.285 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.481123685836792 neg ELBO G: 282264.96875
# 2021-02-11T14:57:26.333 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.4801214933395386 neg ELBO G: 282267.34375
# 2021-02-11T14:57:27.897 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T14:57:31.251 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B6036B1 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T14:57:32.120 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B6037F8 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T14:57:32.123 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T14:57:32.207 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.07890054813869779
# 2021-02-11T14:57:32.269 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B6037F8Prior mean: 0.0, sigma: 0.008851542489757041
# 2021-02-11T14:57:32.342 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([219470, 1]) Sigma: torch.Size([219470, 1]) loglikelihood: torch.Size([219470, 1]) KL value: tensor(-46.2777, grad_fn=<MeanBackward0>)
# 2021-02-11T14:57:32.346 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([219470, 1]) Sigma: torch.Size([219470, 1]) loglikelihood: torch.Size([219470, 1]) KL: torch.Size([]) KL value: tensor(1791.2363, grad_fn=<MulBackward0>)
# 2021-02-11T14:57:32.347 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 47.126121520996094 neg ELBO G: 1792.5816650390625
# 2021-02-11T14:57:34.683 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 30.46953773498535 neg ELBO G: 15025.9033203125
# 2021-02-11T14:57:37.510 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 6.0044636726379395 neg ELBO G: 127981.3515625
# 2021-02-11T14:57:40.188 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.3439515829086304 neg ELBO G: 434797.5
# 2021-02-11T14:57:42.940 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.8230537176132202 neg ELBO G: 667134.125
# 2021-02-11T14:57:45.909 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.8138662576675415 neg ELBO G: 752253.1875
# 2021-02-11T14:57:48.672 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.8351178169250488 neg ELBO G: 760717.0625
# 2021-02-11T14:57:51.778 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.8580715656280518 neg ELBO G: 703653.375
# 2021-02-11T14:57:54.439 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.8590199947357178 neg ELBO G: 673852.375
# 2021-02-11T14:57:57.638 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.8612542152404785 neg ELBO G: 705930.5625
# 2021-02-11T14:58:00.300 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.8623130321502686 neg ELBO G: 703818.375
# 2021-02-11T14:58:03.151 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.862601399421692 neg ELBO G: 695028.0
# 2021-02-11T14:58:05.897 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.8664928674697876 neg ELBO G: 698420.5
# 2021-02-11T14:58:08.610 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.8672027587890625 neg ELBO G: 702420.1875
# 2021-02-11T14:58:11.397 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.8650100231170654 neg ELBO G: 702155.25
# 2021-02-11T14:58:14.151 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.8677808046340942 neg ELBO G: 701863.25
# 2021-02-11T14:58:17.144 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.8691823482513428 neg ELBO G: 702850.4375
# 2021-02-11T14:58:19.949 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.8648515939712524 neg ELBO G: 703751.75
# 2021-02-11T14:58:22.594 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.8669785261154175 neg ELBO G: 704026.5625
# 2021-02-11T14:58:25.301 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.8693270683288574 neg ELBO G: 704289.6875
# 2021-02-11T14:58:27.910 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.8703992366790771 neg ELBO G: 704871.1875
# 2021-02-11T14:58:30.616 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.869166374206543 neg ELBO G: 705215.6875
# 2021-02-11T14:58:33.373 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.868432641029358 neg ELBO G: 705402.875
# 2021-02-11T14:58:35.988 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.8732110261917114 neg ELBO G: 705668.75
# 2021-02-11T14:58:38.857 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.8700827360153198 neg ELBO G: 706110.125
# 2021-02-11T14:58:41.506 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.869474172592163 neg ELBO G: 706275.625
# 2021-02-11T14:58:44.312 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.8727519512176514 neg ELBO G: 706428.75
# 2021-02-11T14:58:47.131 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.8715587854385376 neg ELBO G: 706652.9375
# 2021-02-11T14:58:49.954 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.8724119663238525 neg ELBO G: 706867.4375
# 2021-02-11T14:58:53.069 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.872902512550354 neg ELBO G: 707043.9375
# 2021-02-11T14:58:55.994 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T14:58:58.218 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B6037F8 of size 16636 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T14:58:59.218 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B604101 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T14:58:59.220 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T14:58:59.292 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.019913966045340053
# 2021-02-11T14:58:59.320 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B604101Prior mean: 0.0, sigma: 0.01242930747556037
# 2021-02-11T14:58:59.361 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([119100, 1]) Sigma: torch.Size([119100, 1]) loglikelihood: torch.Size([119100, 1]) KL value: tensor(-51.6430, grad_fn=<MeanBackward0>)
# 2021-02-11T14:58:59.366 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([119100, 1]) Sigma: torch.Size([119100, 1]) loglikelihood: torch.Size([119100, 1]) KL: torch.Size([]) KL value: tensor(5536.8062, grad_fn=<MulBackward0>)
# 2021-02-11T14:58:59.372 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 52.71287155151367 neg ELBO G: 5538.35595703125
# 2021-02-11T14:59:00.463 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 12.520075798034668 neg ELBO G: 23535.15234375
# 2021-02-11T14:59:01.827 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: -0.969016969203949 neg ELBO G: 182817.171875
# 2021-02-11T14:59:03.343 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.5820140838623047 neg ELBO G: 349052.3125
# 2021-02-11T14:59:04.830 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.6956462860107422 neg ELBO G: 419061.5625
# 2021-02-11T14:59:06.492 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.7040282487869263 neg ELBO G: 423564.875
# 2021-02-11T14:59:08.029 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.7256852388381958 neg ELBO G: 396587.15625
# 2021-02-11T14:59:09.526 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.7261419296264648 neg ELBO G: 388098.8125
# 2021-02-11T14:59:10.912 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.7328884601593018 neg ELBO G: 404089.5625
# 2021-02-11T14:59:12.314 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.7397494316101074 neg ELBO G: 417601.78125
# 2021-02-11T14:59:13.667 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.7373576164245605 neg ELBO G: 424807.78125
# 2021-02-11T14:59:15.126 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.7378827333450317 neg ELBO G: 428602.0625
# 2021-02-11T14:59:16.583 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.7460181713104248 neg ELBO G: 431101.375
# 2021-02-11T14:59:18.017 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.7441834211349487 neg ELBO G: 433235.53125
# 2021-02-11T14:59:19.563 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.7435184717178345 neg ELBO G: 435269.5
# 2021-02-11T14:59:20.989 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.7457784414291382 neg ELBO G: 437187.90625
# 2021-02-11T14:59:22.411 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.74851655960083 neg ELBO G: 438728.0625
# 2021-02-11T14:59:23.920 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.7454167604446411 neg ELBO G: 439818.28125
# 2021-02-11T14:59:25.403 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.7462190389633179 neg ELBO G: 440850.875
# 2021-02-11T14:59:26.888 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.7449822425842285 neg ELBO G: 441819.78125
# 2021-02-11T14:59:28.324 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.7463560104370117 neg ELBO G: 442696.90625
# 2021-02-11T14:59:29.700 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.743237853050232 neg ELBO G: 443473.21875
# 2021-02-11T14:59:31.134 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.7495388984680176 neg ELBO G: 444113.90625
# 2021-02-11T14:59:32.442 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.7487801313400269 neg ELBO G: 444622.09375
# 2021-02-11T14:59:34.011 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.7514307498931885 neg ELBO G: 445003.75
# 2021-02-11T14:59:35.308 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.7454643249511719 neg ELBO G: 445282.0
# 2021-02-11T14:59:36.609 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.7137068510055542 neg ELBO G: 444953.21875
# 2021-02-11T14:59:37.957 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.7424547672271729 neg ELBO G: 435869.84375
# 2021-02-11T14:59:39.319 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.7453014850616455 neg ELBO G: 431253.0
# 2021-02-11T14:59:40.750 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.7432419061660767 neg ELBO G: 431655.15625
# 2021-02-11T14:59:42.182 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T14:59:44.602 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B604101 of size 16640 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T14:59:45.510 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B606390 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T14:59:45.513 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T14:59:45.578 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.015163923168973466
# 2021-02-11T14:59:45.592 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B606390Prior mean: 0.0, sigma: 0.006738683094916505
# 2021-02-11T14:59:45.616 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([69360, 1]) Sigma: torch.Size([69360, 1]) loglikelihood: torch.Size([69360, 1]) KL value: tensor(-89.9651, grad_fn=<MeanBackward0>)
# 2021-02-11T14:59:45.618 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([69360, 1]) Sigma: torch.Size([69360, 1]) loglikelihood: torch.Size([69360, 1]) KL: torch.Size([]) KL value: tensor(8971.0176, grad_fn=<MulBackward0>)
# 2021-02-11T14:59:45.619 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 91.01212310791016 neg ELBO G: 8972.43359375
# 2021-02-11T14:59:46.109 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 49.421234130859375 neg ELBO G: 2972.118896484375
# 2021-02-11T14:59:46.770 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 15.848161697387695 neg ELBO G: 25185.751953125
# 2021-02-11T14:59:47.586 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -0.00953515525907278 neg ELBO G: 96960.03125
# 2021-02-11T14:59:48.497 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.792046308517456 neg ELBO G: 174354.65625
# 2021-02-11T14:59:49.346 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.8868954181671143 neg ELBO G: 216709.75
# 2021-02-11T14:59:50.192 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.899467945098877 neg ELBO G: 229949.140625
# 2021-02-11T14:59:51.234 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.9473876953125 neg ELBO G: 229124.046875
# 2021-02-11T14:59:52.210 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.976875901222229 neg ELBO G: 225136.25
# 2021-02-11T14:59:53.044 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.9882258176803589 neg ELBO G: 222305.46875
# 2021-02-11T14:59:53.822 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -2.0017545223236084 neg ELBO G: 221033.609375
# 2021-02-11T14:59:54.633 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -2.0004348754882812 neg ELBO G: 220967.265625
# 2021-02-11T14:59:55.494 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -2.0024807453155518 neg ELBO G: 221635.0
# 2021-02-11T14:59:56.500 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -2.0031280517578125 neg ELBO G: 222712.875
# 2021-02-11T14:59:57.484 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -2.0070152282714844 neg ELBO G: 223983.09375
# 2021-02-11T14:59:58.289 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -2.0010170936584473 neg ELBO G: 225290.046875
# 2021-02-11T14:59:59.067 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -2.007802724838257 neg ELBO G: 226546.21875
# 2021-02-11T14:59:59.855 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -2.006744623184204 neg ELBO G: 227715.328125
# 2021-02-11T15:00:00.740 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -2.005570888519287 neg ELBO G: 228773.828125
# 2021-02-11T15:00:01.558 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -2.0099380016326904 neg ELBO G: 229714.46875
# 2021-02-11T15:00:02.456 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -2.0033998489379883 neg ELBO G: 230539.046875
# 2021-02-11T15:00:03.445 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -2.0127217769622803 neg ELBO G: 231253.375
# 2021-02-11T15:00:04.569 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -2.0110867023468018 neg ELBO G: 231865.703125
# 2021-02-11T15:00:05.385 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -2.009403944015503 neg ELBO G: 232376.671875
# 2021-02-11T15:00:06.211 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -2.0064432621002197 neg ELBO G: 232814.1875
# 2021-02-11T15:00:07.039 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -2.004316806793213 neg ELBO G: 233181.78125
# 2021-02-11T15:00:07.810 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -2.010390520095825 neg ELBO G: 233489.6875
# 2021-02-11T15:00:08.598 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -2.0128843784332275 neg ELBO G: 233751.671875
# 2021-02-11T15:00:09.420 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -2.0043559074401855 neg ELBO G: 233976.34375
# 2021-02-11T15:00:10.409 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -2.0073318481445312 neg ELBO G: 234149.8125
# 2021-02-11T15:00:11.257 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:00:17.008 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_x.04714B606390 of size 16640 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# CPU times: user 20min 45s, sys: 40.5 s, total: 21min 25s
# Wall time: 4min 9s
#                rms_x          rms_z          rms_y          power  \
# count  762630.000000  762630.000000  762630.000000  762630.000000
# mean        0.079898       0.300077       0.774366       6.199184
# std         0.087452       0.390011       0.431330       8.178557
# min         0.005411       0.010101       0.008728       0.000000
# 25%         0.014603       0.059778       0.955331       0.000000
# 50%         0.067691       0.101045       1.042266       1.753800
# 75%         0.087985       0.178913       1.044446      18.714600
# max         0.576303       1.044346       1.078255      20.277399
#
#                speed
# count  762630.000000
# mean      670.653717
# std       572.746119
# min         0.000000
# 25%         0.000000
# 50%      1060.000000
# 75%      1147.000000
# max      3600.000000

# %%
# %%time
print('Train and evaluate model for ' + df_i.index.levels[0].values[0])
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsiy = VIAnomalyScore(['speed'], ['rms_y'])
#spsiy.epochs = 1  # only for testing model storage
spsiy.epochs = 300

spsiy.auto_train = True
spsiy.delete_model = delete_model
ety = spsiy._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
ety.name = 'IOT_SHADOW_PUMP_DE_GEN5'

spsiy._entity_type = ety
df_i = spsiy.execute(df=df_i)

EngineLogging.configure_console_logging(logging.INFO)
df_i.describe()
# Out:
# Train and evaluate model for 04714B601096
# 2021-02-11T15:02:30.014 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2021-02-11T15:02:30.015 DEBUG root.__init__ __init__VIAnomalyScore
# 2021-02-11T15:02:30.016 DEBUG root.__init__ __init__ done with parameters: speed.rms_y
# 2021-02-11T15:02:30.016 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.3.1
# 2021-02-11T15:02:30.017 DEBUG iotfunctions.util.__init__ Starting trace
# 2021-02-11T15:02:30.017 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20210211140230
# 2021-02-11T15:02:30.018 DEBUG iotfunctions.util.__init__ auto_save None
# 2021-02-11T15:02:30.018 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2021-02-11T15:02:30.019 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2021-02-11T15:02:30.019 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# 2021-02-11T15:02:30.036 DEBUG mmfunctions.anomaly.execute VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'>
# 2021-02-11T15:02:30.036 DEBUG mmfunctions.anomaly.execute ['04714B601096' '04714B603408' '04714B6036B1' '04714B6037F8'
#  '04714B604101' '04714B606390']
# ['speed']
# 2021-02-11T15:02:32.427 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B601096 of size 16634 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:02:32.434 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:02:32.506 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.9648271186706371
# ['speed']
# 2021-02-11T15:02:33.383 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B603408 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:02:33.383 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:02:33.439 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0517420700729927
# 2021-02-11T15:02:33.459 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B603408Prior mean: 0.0, sigma: 0.027585601235662897
# 2021-02-11T15:02:33.489 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([88365, 1]) Sigma: torch.Size([88365, 1]) loglikelihood: torch.Size([88365, 1]) KL value: tensor(-19.5019, grad_fn=<MeanBackward0>)
# 2021-02-11T15:02:33.493 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([88365, 1]) Sigma: torch.Size([88365, 1]) loglikelihood: torch.Size([88365, 1]) KL: torch.Size([]) KL value: tensor(3549.6147, grad_fn=<MulBackward0>)
# 2021-02-11T15:02:33.493 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 20.51695442199707 neg ELBO G: 3551.09619140625
# 2021-02-11T15:02:34.122 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 10.052549362182617 neg ELBO G: 5891.5859375
# 2021-02-11T15:02:34.785 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 0.8688968420028687 neg ELBO G: 59072.05859375
# 2021-02-11T15:02:35.591 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.1106940507888794 neg ELBO G: 164891.703125
# 2021-02-11T15:02:36.240 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.112077236175537 neg ELBO G: 233074.515625
# 2021-02-11T15:02:37.144 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.1226537227630615 neg ELBO G: 233533.0625
# 2021-02-11T15:02:38.192 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.1913480758666992 neg ELBO G: 206421.078125
# 2021-02-11T15:02:39.271 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.2045782804489136 neg ELBO G: 189894.5
# 2021-02-11T15:02:40.408 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.2079989910125732 neg ELBO G: 186429.546875
# 2021-02-11T15:02:41.550 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.2099183797836304 neg ELBO G: 189629.5625
# 2021-02-11T15:02:42.714 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.209449291229248 neg ELBO G: 193621.5625
# 2021-02-11T15:02:43.816 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.2074973583221436 neg ELBO G: 195451.171875
# 2021-02-11T15:02:44.862 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.2104884386062622 neg ELBO G: 195199.9375
# 2021-02-11T15:02:45.923 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.2089709043502808 neg ELBO G: 194379.09375
# 2021-02-11T15:02:47.037 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.2111014127731323 neg ELBO G: 193959.203125
# 2021-02-11T15:02:48.082 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.2117999792099 neg ELBO G: 193992.109375
# 2021-02-11T15:02:49.071 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.2083929777145386 neg ELBO G: 194171.125
# 2021-02-11T15:02:50.126 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.2093018293380737 neg ELBO G: 194248.578125
# 2021-02-11T15:02:51.206 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.2099120616912842 neg ELBO G: 194291.859375
# 2021-02-11T15:02:52.255 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.206863522529602 neg ELBO G: 194265.96875
# 2021-02-11T15:02:53.380 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.208997130393982 neg ELBO G: 194214.734375
# 2021-02-11T15:02:54.412 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.2116146087646484 neg ELBO G: 194207.21875
# 2021-02-11T15:02:55.325 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.2109739780426025 neg ELBO G: 194277.21875
# 2021-02-11T15:02:56.276 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.208383560180664 neg ELBO G: 194298.09375
# 2021-02-11T15:02:57.325 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.2092554569244385 neg ELBO G: 194225.59375
# 2021-02-11T15:02:58.374 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.2104986906051636 neg ELBO G: 194182.46875
# 2021-02-11T15:02:59.594 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.2147506475448608 neg ELBO G: 194231.21875
# 2021-02-11T15:03:00.795 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.2116620540618896 neg ELBO G: 194289.0
# 2021-02-11T15:03:02.012 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.2096019983291626 neg ELBO G: 194270.84375
# 2021-02-11T15:03:03.395 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.2078901529312134 neg ELBO G: 194224.984375
# 2021-02-11T15:03:04.538 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:03:07.000 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B603408 of size 16638 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T15:03:08.099 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B6036B1 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:03:08.099 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:03:08.144 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0439549532907022
# 2021-02-11T15:03:08.164 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B6036B1Prior mean: 0.0, sigma: 0.001562089960435565
# 2021-02-11T15:03:08.196 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([88355, 1]) Sigma: torch.Size([88355, 1]) loglikelihood: torch.Size([88355, 1]) KL value: tensor(-277.3807, grad_fn=<MeanBackward0>)
# 2021-02-11T15:03:08.199 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([88355, 1]) Sigma: torch.Size([88355, 1]) loglikelihood: torch.Size([88355, 1]) KL: torch.Size([]) KL value: tensor(3122.1431, grad_fn=<MulBackward0>)
# 2021-02-11T15:03:08.201 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 278.2331237792969 neg ELBO G: 3123.465087890625
# 2021-02-11T15:03:08.947 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 39.05127716064453 neg ELBO G: 56961.53515625
# 2021-02-11T15:03:09.829 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 1.9170823097229004 neg ELBO G: 167023.015625
# 2021-02-11T15:03:10.844 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -2.084137439727783 neg ELBO G: 238308.171875
# 2021-02-11T15:03:11.833 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -2.5185866355895996 neg ELBO G: 282402.78125
# 2021-02-11T15:03:12.843 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -2.597744941711426 neg ELBO G: 306717.625
# 2021-02-11T15:03:13.929 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -2.623244524002075 neg ELBO G: 321516.53125
# 2021-02-11T15:03:15.129 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -2.7332797050476074 neg ELBO G: 334476.4375
# 2021-02-11T15:03:16.386 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -2.7483131885528564 neg ELBO G: 345270.1875
# 2021-02-11T15:03:17.752 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -2.7563388347625732 neg ELBO G: 352856.0
# 2021-02-11T15:03:19.144 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -2.7704148292541504 neg ELBO G: 357932.0625
# 2021-02-11T15:03:20.313 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -2.7683067321777344 neg ELBO G: 362502.34375
# 2021-02-11T15:03:21.499 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -2.773049831390381 neg ELBO G: 367528.25
# 2021-02-11T15:03:22.742 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -2.7779438495635986 neg ELBO G: 372949.4375
# 2021-02-11T15:03:23.978 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -2.776970148086548 neg ELBO G: 378350.9375
# 2021-02-11T15:03:24.935 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -2.77909517288208 neg ELBO G: 383430.9375
# 2021-02-11T15:03:26.007 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -2.7785961627960205 neg ELBO G: 388097.9375
# 2021-02-11T15:03:27.205 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -2.7843234539031982 neg ELBO G: 392416.5625
# 2021-02-11T15:03:28.117 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -2.781294107437134 neg ELBO G: 396440.5
# 2021-02-11T15:03:29.038 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -2.786637306213379 neg ELBO G: 400138.1875
# 2021-02-11T15:03:30.220 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -2.7838962078094482 neg ELBO G: 403514.96875
# 2021-02-11T15:03:31.413 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -2.7889630794525146 neg ELBO G: 406610.21875
# 2021-02-11T15:03:32.295 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -2.7915146350860596 neg ELBO G: 409392.84375
# 2021-02-11T15:03:33.161 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -2.7839808464050293 neg ELBO G: 411817.375
# 2021-02-11T15:03:34.092 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -2.787586212158203 neg ELBO G: 413971.25
# 2021-02-11T15:03:35.037 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -2.786325693130493 neg ELBO G: 415840.15625
# 2021-02-11T15:03:35.966 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -2.7894127368927 neg ELBO G: 417475.625
# 2021-02-11T15:03:37.025 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -2.7897937297821045 neg ELBO G: 418872.15625
# 2021-02-11T15:03:38.124 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -2.786743640899658 neg ELBO G: 420031.6875
# 2021-02-11T15:03:39.177 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -2.787912130355835 neg ELBO G: 421033.90625
# 2021-02-11T15:03:40.386 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:03:42.343 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B6036B1 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T15:03:43.595 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B6037F8 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:03:43.598 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:03:43.691 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0441421700323505
# 2021-02-11T15:03:43.764 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B6037F8Prior mean: 0.0, sigma: 0.0013465266755358282
# 2021-02-11T15:03:43.839 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([219470, 1]) Sigma: torch.Size([219470, 1]) loglikelihood: torch.Size([219470, 1]) KL value: tensor(-437.5734, grad_fn=<MeanBackward0>)
# 2021-02-11T15:03:43.844 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([219470, 1]) Sigma: torch.Size([219470, 1]) loglikelihood: torch.Size([219470, 1]) KL: torch.Size([]) KL value: tensor(16685.3184, grad_fn=<MulBackward0>)
# 2021-02-11T15:03:43.845 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 438.5827941894531 neg ELBO G: 16686.755859375
# 2021-02-11T15:03:46.144 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 219.9210205078125 neg ELBO G: 19600.41015625
# 2021-02-11T15:03:49.163 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 63.74702072143555 neg ELBO G: 120567.46875
# 2021-02-11T15:03:51.849 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: 8.10233211517334 neg ELBO G: 369432.4375
# 2021-02-11T15:03:54.263 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -0.8361985087394714 neg ELBO G: 549807.8125
# 2021-02-11T15:03:56.955 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.577571988105774 neg ELBO G: 647565.3125
# 2021-02-11T15:04:00.002 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -2.0394363403320312 neg ELBO G: 685097.8125
# 2021-02-11T15:04:02.720 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -2.393449306488037 neg ELBO G: 697943.4375
# 2021-02-11T15:04:05.786 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -2.5619072914123535 neg ELBO G: 709752.4375
# 2021-02-11T15:04:08.877 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -2.62231707572937 neg ELBO G: 726137.75
# 2021-02-11T15:04:11.548 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -2.6536545753479004 neg ELBO G: 745052.9375
# 2021-02-11T15:04:14.601 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -2.687741994857788 neg ELBO G: 764008.25
# 2021-02-11T15:04:17.490 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -2.71024489402771 neg ELBO G: 781872.125
# 2021-02-11T15:04:20.160 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -2.7296578884124756 neg ELBO G: 798141.3125
# 2021-02-11T15:04:23.136 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -2.7417144775390625 neg ELBO G: 812755.1875
# 2021-02-11T15:04:25.938 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -2.75705623626709 neg ELBO G: 825831.625
# 2021-02-11T15:04:28.749 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -2.7623846530914307 neg ELBO G: 837508.875
# 2021-02-11T15:04:31.486 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -2.770840644836426 neg ELBO G: 847897.0625
# 2021-02-11T15:04:34.072 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -2.776811361312866 neg ELBO G: 857138.4375
# 2021-02-11T15:04:36.998 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -2.7695810794830322 neg ELBO G: 864760.0625
# 2021-02-11T15:04:39.690 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -2.7811942100524902 neg ELBO G: 870965.625
# 2021-02-11T15:04:42.487 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -2.7887821197509766 neg ELBO G: 877018.3125
# 2021-02-11T15:04:45.106 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -2.79351544380188 neg ELBO G: 882974.625
# 2021-02-11T15:04:48.030 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -2.7987899780273438 neg ELBO G: 888662.125
# 2021-02-11T15:04:50.729 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -2.8004987239837646 neg ELBO G: 893938.1875
# 2021-02-11T15:04:53.357 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -2.7899985313415527 neg ELBO G: 898549.5625
# 2021-02-11T15:04:56.017 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -2.804863452911377 neg ELBO G: 901214.125
# 2021-02-11T15:04:58.600 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -2.8045105934143066 neg ELBO G: 904026.3125
# 2021-02-11T15:05:01.038 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -2.805581569671631 neg ELBO G: 907192.25
# 2021-02-11T15:05:03.633 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -2.8090567588806152 neg ELBO G: 910485.6875
# 2021-02-11T15:05:06.680 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:05:08.689 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B6037F8 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T15:05:09.702 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B604101 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:05:09.703 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:05:09.779 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.025699096582703612
# 2021-02-11T15:05:09.806 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B604101Prior mean: 0.0, sigma: 0.0075352797645436695
# 2021-02-11T15:05:09.845 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([119100, 1]) Sigma: torch.Size([119100, 1]) loglikelihood: torch.Size([119100, 1]) KL value: tensor(-56.7547, grad_fn=<MeanBackward0>)
# 2021-02-11T15:05:09.850 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([119100, 1]) Sigma: torch.Size([119100, 1]) loglikelihood: torch.Size([119100, 1]) KL: torch.Size([]) KL value: tensor(8689.3066, grad_fn=<MulBackward0>)
# 2021-02-11T15:05:09.850 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 57.626617431640625 neg ELBO G: 8690.6005859375
# 2021-02-11T15:05:10.803 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 8.262608528137207 neg ELBO G: 77136.7578125
# 2021-02-11T15:05:12.217 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: -1.146259069442749 neg ELBO G: 324652.71875
# 2021-02-11T15:05:13.649 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.4481555223464966 neg ELBO G: 394048.1875
# 2021-02-11T15:05:14.964 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.9173208475112915 neg ELBO G: 371186.03125
# 2021-02-11T15:05:16.481 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.9229931831359863 neg ELBO G: 359414.90625
# 2021-02-11T15:05:17.985 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.9353219270706177 neg ELBO G: 362057.65625
# 2021-02-11T15:05:19.316 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.9507778882980347 neg ELBO G: 372316.96875
# 2021-02-11T15:05:20.587 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.9603981971740723 neg ELBO G: 385061.3125
# 2021-02-11T15:05:21.875 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.9687325954437256 neg ELBO G: 396937.53125
# 2021-02-11T15:05:23.174 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.9697773456573486 neg ELBO G: 406416.84375
# 2021-02-11T15:05:24.576 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.9704629182815552 neg ELBO G: 413358.6875
# 2021-02-11T15:05:25.786 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.9748121500015259 neg ELBO G: 418211.65625
# 2021-02-11T15:05:27.147 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.9749869108200073 neg ELBO G: 421732.0625
# 2021-02-11T15:05:28.449 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.9737426042556763 neg ELBO G: 424580.5
# 2021-02-11T15:05:29.838 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.975180745124817 neg ELBO G: 427224.53125
# 2021-02-11T15:05:31.139 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.980669617652893 neg ELBO G: 429956.34375
# 2021-02-11T15:05:32.694 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.9857300519943237 neg ELBO G: 433392.25
# 2021-02-11T15:05:33.955 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.986799716949463 neg ELBO G: 437909.25
# 2021-02-11T15:05:35.453 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.985874056816101 neg ELBO G: 442440.0
# 2021-02-11T15:05:36.652 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.9882006645202637 neg ELBO G: 446446.65625
# 2021-02-11T15:05:38.107 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.989857792854309 neg ELBO G: 449873.25
# 2021-02-11T15:05:39.513 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.9876079559326172 neg ELBO G: 452859.9375
# 2021-02-11T15:05:40.758 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.9946153163909912 neg ELBO G: 455592.78125
# 2021-02-11T15:05:42.184 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.990700125694275 neg ELBO G: 458189.375
# 2021-02-11T15:05:43.641 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.9923629760742188 neg ELBO G: 460699.0
# 2021-02-11T15:05:45.396 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.9944367408752441 neg ELBO G: 463150.0625
# 2021-02-11T15:05:46.823 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.9966788291931152 neg ELBO G: 465502.4375
# 2021-02-11T15:05:48.103 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.989713430404663 neg ELBO G: 463236.15625
# 2021-02-11T15:05:49.411 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.9887161254882812 neg ELBO G: 457246.03125
# 2021-02-11T15:05:50.826 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:05:56.099 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B604101 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T15:05:58.864 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B606390 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:05:58.865 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:05:58.929 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.020761343411188005
# 2021-02-11T15:05:58.944 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B606390Prior mean: 0.0, sigma: 0.010838607597333733
# 2021-02-11T15:05:58.968 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([69360, 1]) Sigma: torch.Size([69360, 1]) loglikelihood: torch.Size([69360, 1]) KL value: tensor(-51.9681, grad_fn=<MeanBackward0>)
# 2021-02-11T15:05:58.971 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([69360, 1]) Sigma: torch.Size([69360, 1]) loglikelihood: torch.Size([69360, 1]) KL: torch.Size([]) KL value: tensor(939.0809, grad_fn=<MulBackward0>)
# 2021-02-11T15:05:58.971 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 52.979000091552734 neg ELBO G: 940.5819091796875
# 2021-02-11T15:05:59.436 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 10.968503952026367 neg ELBO G: 28719.1953125
# 2021-02-11T15:05:59.919 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: -0.49173226952552795 neg ELBO G: 153815.046875
# 2021-02-11T15:06:00.518 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.6552438735961914 neg ELBO G: 191019.921875
# 2021-02-11T15:06:01.278 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.7392727136611938 neg ELBO G: 194906.234375
# 2021-02-11T15:06:02.112 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.741141438484192 neg ELBO G: 198637.375
# 2021-02-11T15:06:03.414 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.7428351640701294 neg ELBO G: 201988.75
# 2021-02-11T15:06:04.443 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.7481216192245483 neg ELBO G: 204796.25
# 2021-02-11T15:06:05.288 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.7444733381271362 neg ELBO G: 206784.5625
# 2021-02-11T15:06:06.187 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.754800796508789 neg ELBO G: 207843.875
# 2021-02-11T15:06:07.180 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.7515760660171509 neg ELBO G: 208150.828125
# 2021-02-11T15:06:08.094 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.7532230615615845 neg ELBO G: 207961.84375
# 2021-02-11T15:06:09.022 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.7497978210449219 neg ELBO G: 207540.375
# 2021-02-11T15:06:09.823 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.7483516931533813 neg ELBO G: 207069.953125
# 2021-02-11T15:06:10.648 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.7485060691833496 neg ELBO G: 206657.421875
# 2021-02-11T15:06:11.482 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.7514420747756958 neg ELBO G: 206371.265625
# 2021-02-11T15:06:12.258 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.751120686531067 neg ELBO G: 206198.875
# 2021-02-11T15:06:13.113 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.7513973712921143 neg ELBO G: 206098.640625
# 2021-02-11T15:06:13.940 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.7500393390655518 neg ELBO G: 206040.953125
# 2021-02-11T15:06:14.806 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.750654697418213 neg ELBO G: 206015.703125
# 2021-02-11T15:06:15.661 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.750983476638794 neg ELBO G: 206000.109375
# 2021-02-11T15:06:16.446 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.7546197175979614 neg ELBO G: 205981.5
# 2021-02-11T15:06:17.130 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.7540693283081055 neg ELBO G: 205971.84375
# 2021-02-11T15:06:17.882 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.7484021186828613 neg ELBO G: 205964.015625
# 2021-02-11T15:06:18.689 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.7481966018676758 neg ELBO G: 205951.734375
# 2021-02-11T15:06:19.526 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.7517114877700806 neg ELBO G: 205953.421875
# 2021-02-11T15:06:20.371 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.753172755241394 neg ELBO G: 205964.375
# 2021-02-11T15:06:21.329 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.7536104917526245 neg ELBO G: 205980.734375
# 2021-02-11T15:06:22.238 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.7555912733078003 neg ELBO G: 206002.390625
# 2021-02-11T15:06:22.998 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.753029465675354 neg ELBO G: 205999.75
# 2021-02-11T15:06:23.743 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:06:24.671 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_y.04714B606390 of size 16638 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# CPU times: user 20min 12s, sys: 46.6 s, total: 20min 59s
# Wall time: 3min 54s
#                rms_x          rms_z          rms_y          power  \
# count  762630.000000  762630.000000  762630.000000  762630.000000
# mean        0.079898       0.300077       0.774366       6.199184
# std         0.087452       0.390011       0.431330       8.178557
# min         0.005411       0.010101       0.008728       0.000000
# 25%         0.014603       0.059778       0.955331       0.000000
# 50%         0.067691       0.101045       1.042266       1.753800
# 75%         0.087985       0.178913       1.044446      18.714600
# max         0.576303       1.044346       1.078255      20.277399
#
#                speed
# count  762630.000000
# mean      670.653717
# std       572.746119
# min         0.000000
# 25%         0.000000
# 50%      1060.000000
# 75%      1147.000000
# max      3600.000000

# %%
# %%time
print('Train and evaluate model for ' + df_i.index.levels[0].values[0])
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsiz = VIAnomalyScore(['speed'], ['rms_z'])
#spsiz.epochs = 1  # only for testing model storage
spsiz.epochs = 300

spsiz.auto_train = True
spsiz.delete_model = delete_model
etz = spsiz._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
etz.name = 'IOT_SHADOW_PUMP_DE_GEN5'

spsiz._entity_type = etz
df_i = spsiz.execute(df=df_i)

EngineLogging.configure_console_logging(logging.INFO)
df_i.describe()
# Out:
# Train and evaluate model for 04714B601096
# 2021-02-11T15:10:48.000 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2021-02-11T15:10:48.002 DEBUG root.__init__ __init__VIAnomalyScore
# 2021-02-11T15:10:48.004 DEBUG root.__init__ __init__ done with parameters: speed.rms_z
# 2021-02-11T15:10:48.005 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.3.1
# 2021-02-11T15:10:48.007 DEBUG iotfunctions.util.__init__ Starting trace
# 2021-02-11T15:10:48.008 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20210211141048
# 2021-02-11T15:10:48.009 DEBUG iotfunctions.util.__init__ auto_save None
# 2021-02-11T15:10:48.010 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2021-02-11T15:10:48.011 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2021-02-11T15:10:48.012 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# 2021-02-11T15:10:48.037 DEBUG mmfunctions.anomaly.execute VIAnomalyScore execute: <class 'pandas.core.frame.DataFrame'>
# 2021-02-11T15:10:48.038 DEBUG mmfunctions.anomaly.execute ['04714B601096' '04714B603408' '04714B6036B1' '04714B6037F8'
#  '04714B604101' '04714B606390']
# ['speed']
# 2021-02-11T15:10:49.923 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B601096 of size 16636 bytes has been retrieved from table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:10:49.928 INFO mmfunctions.anomaly.execute load model VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:10:49.997 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.08704876804697158
# ['speed']
# 2021-02-11T15:10:51.216 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B603408 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:10:51.219 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:10:51.295 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.04058445240762745
# 2021-02-11T15:10:51.314 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B603408Prior mean: 0.0, sigma: 0.02929058170547041
# 2021-02-11T15:10:51.347 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([88365, 1]) Sigma: torch.Size([88365, 1]) loglikelihood: torch.Size([88365, 1]) KL value: tensor(-21.5975, grad_fn=<MeanBackward0>)
# 2021-02-11T15:10:51.351 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([88365, 1]) Sigma: torch.Size([88365, 1]) loglikelihood: torch.Size([88365, 1]) KL: torch.Size([]) KL value: tensor(4004.3159, grad_fn=<MulBackward0>)
# 2021-02-11T15:10:51.352 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 22.685670852661133 neg ELBO G: 4005.892333984375
# 2021-02-11T15:10:52.066 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 16.520524978637695 neg ELBO G: 406.6100158691406
# 2021-02-11T15:10:52.751 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 9.240260124206543 neg ELBO G: 6229.65966796875
# 2021-02-11T15:10:53.464 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: 2.0390453338623047 neg ELBO G: 41772.1640625
# 2021-02-11T15:10:54.166 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -0.5796592235565186 neg ELBO G: 103772.5390625
# 2021-02-11T15:10:54.870 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.1149179935455322 neg ELBO G: 156010.453125
# 2021-02-11T15:10:55.537 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.1801680326461792 neg ELBO G: 188631.65625
# 2021-02-11T15:10:56.272 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.178544282913208 neg ELBO G: 203008.65625
# 2021-02-11T15:10:56.918 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.1738756895065308 neg ELBO G: 205374.96875
# 2021-02-11T15:10:57.663 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.179773211479187 neg ELBO G: 202073.703125
# 2021-02-11T15:10:58.294 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.1779427528381348 neg ELBO G: 197648.90625
# 2021-02-11T15:10:58.927 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.1797748804092407 neg ELBO G: 194307.328125
# 2021-02-11T15:10:59.583 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.1829566955566406 neg ELBO G: 192564.0625
# 2021-02-11T15:11:00.224 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.182152271270752 neg ELBO G: 192028.640625
# 2021-02-11T15:11:00.898 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.182783603668213 neg ELBO G: 192100.625
# 2021-02-11T15:11:01.636 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.1847165822982788 neg ELBO G: 192366.390625
# 2021-02-11T15:11:02.290 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.1829577684402466 neg ELBO G: 192623.546875
# 2021-02-11T15:11:03.007 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.1800199747085571 neg ELBO G: 192774.828125
# 2021-02-11T15:11:03.835 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.1801337003707886 neg ELBO G: 192802.546875
# 2021-02-11T15:11:04.499 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.1836228370666504 neg ELBO G: 192774.171875
# 2021-02-11T15:11:05.229 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.1818804740905762 neg ELBO G: 192730.515625
# 2021-02-11T15:11:05.877 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.1828196048736572 neg ELBO G: 192746.390625
# 2021-02-11T15:11:06.534 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.1826940774917603 neg ELBO G: 192781.890625
# 2021-02-11T15:11:07.228 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.183091402053833 neg ELBO G: 192794.625
# 2021-02-11T15:11:07.901 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.1850535869598389 neg ELBO G: 192778.03125
# 2021-02-11T15:11:08.587 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.1881890296936035 neg ELBO G: 192767.359375
# 2021-02-11T15:11:09.342 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.1811270713806152 neg ELBO G: 192763.890625
# 2021-02-11T15:11:10.026 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.1828486919403076 neg ELBO G: 192753.296875
# 2021-02-11T15:11:10.831 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.1846768856048584 neg ELBO G: 192752.25
# 2021-02-11T15:11:11.520 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.1870088577270508 neg ELBO G: 192768.5
# 2021-02-11T15:11:12.166 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:11:15.339 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B603408 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T15:11:16.349 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B6036B1 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:11:16.350 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:11:16.412 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.01657187418934978
# 2021-02-11T15:11:16.429 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B6036B1Prior mean: 0.0, sigma: 0.0155171803203516
# 2021-02-11T15:11:16.463 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([88355, 1]) Sigma: torch.Size([88355, 1]) loglikelihood: torch.Size([88355, 1]) KL value: tensor(-23.1417, grad_fn=<MeanBackward0>)
# 2021-02-11T15:11:16.466 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([88355, 1]) Sigma: torch.Size([88355, 1]) loglikelihood: torch.Size([88355, 1]) KL: torch.Size([]) KL value: tensor(4119.6587, grad_fn=<MulBackward0>)
# 2021-02-11T15:11:16.467 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 23.941991806030273 neg ELBO G: 4120.927734375
# 2021-02-11T15:11:17.141 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 11.246695518493652 neg ELBO G: 14969.0166015625
# 2021-02-11T15:11:17.808 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 1.1173441410064697 neg ELBO G: 71383.90625
# 2021-02-11T15:11:18.457 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.2954012155532837 neg ELBO G: 168104.578125
# 2021-02-11T15:11:19.122 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.5692695379257202 neg ELBO G: 233222.609375
# 2021-02-11T15:11:19.789 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.6133257150650024 neg ELBO G: 266127.15625
# 2021-02-11T15:11:20.461 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.6104544401168823 neg ELBO G: 280226.875
# 2021-02-11T15:11:21.143 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.615145206451416 neg ELBO G: 284985.65625
# 2021-02-11T15:11:21.873 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.6158902645111084 neg ELBO G: 285957.5
# 2021-02-11T15:11:22.580 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.6136633157730103 neg ELBO G: 285412.40625
# 2021-02-11T15:11:23.300 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.614766240119934 neg ELBO G: 284416.59375
# 2021-02-11T15:11:24.002 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.6150150299072266 neg ELBO G: 283460.28125
# 2021-02-11T15:11:24.810 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.6187238693237305 neg ELBO G: 282674.625
# 2021-02-11T15:11:25.526 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.6173393726348877 neg ELBO G: 282105.625
# 2021-02-11T15:11:26.232 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.6184191703796387 neg ELBO G: 281710.21875
# 2021-02-11T15:11:26.903 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.6158671379089355 neg ELBO G: 281452.1875
# 2021-02-11T15:11:27.596 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.6115312576293945 neg ELBO G: 281294.40625
# 2021-02-11T15:11:28.320 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.617233395576477 neg ELBO G: 281188.5
# 2021-02-11T15:11:28.995 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.6157548427581787 neg ELBO G: 281120.5625
# 2021-02-11T15:11:29.744 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.6171916723251343 neg ELBO G: 281106.53125
# 2021-02-11T15:11:30.443 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.6189119815826416 neg ELBO G: 281111.9375
# 2021-02-11T15:11:31.141 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.6162720918655396 neg ELBO G: 281114.5
# 2021-02-11T15:11:31.832 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.6130765676498413 neg ELBO G: 281126.65625
# 2021-02-11T15:11:32.524 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.6205835342407227 neg ELBO G: 281123.875
# 2021-02-11T15:11:33.229 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.6145894527435303 neg ELBO G: 281121.8125
# 2021-02-11T15:11:33.912 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.6154402494430542 neg ELBO G: 281130.5
# 2021-02-11T15:11:34.612 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.6189581155776978 neg ELBO G: 281110.46875
# 2021-02-11T15:11:35.303 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.6199880838394165 neg ELBO G: 281105.71875
# 2021-02-11T15:11:35.995 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.617906093597412 neg ELBO G: 281099.71875
# 2021-02-11T15:11:36.683 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.6172494888305664 neg ELBO G: 281102.625
# 2021-02-11T15:11:37.326 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:11:41.363 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B6036B1 of size 16640 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T15:11:42.178 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B6037F8 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:11:42.179 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:11:42.274 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.11003280906274207
# 2021-02-11T15:11:42.334 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B6037F8Prior mean: 0.0, sigma: 0.02090557360067074
# 2021-02-11T15:11:42.404 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([219470, 1]) Sigma: torch.Size([219470, 1]) loglikelihood: torch.Size([219470, 1]) KL value: tensor(-27.0919, grad_fn=<MeanBackward0>)
# 2021-02-11T15:11:42.408 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([219470, 1]) Sigma: torch.Size([219470, 1]) loglikelihood: torch.Size([219470, 1]) KL: torch.Size([]) KL value: tensor(7227.9810, grad_fn=<MulBackward0>)
# 2021-02-11T15:11:42.409 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 28.118064880371094 neg ELBO G: 7229.48583984375
# 2021-02-11T15:11:44.224 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 15.243931770324707 neg ELBO G: 15860.826171875
# 2021-02-11T15:11:46.016 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 1.6192638874053955 neg ELBO G: 168478.09375
# 2021-02-11T15:11:47.802 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -0.9182575941085815 neg ELBO G: 357481.5
# 2021-02-11T15:11:49.615 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -1.232734203338623 neg ELBO G: 432513.28125
# 2021-02-11T15:11:51.429 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -1.2881779670715332 neg ELBO G: 496681.96875
# 2021-02-11T15:11:53.222 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -1.3074809312820435 neg ELBO G: 531289.4375
# 2021-02-11T15:11:54.985 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -1.3239316940307617 neg ELBO G: 539074.5625
# 2021-02-11T15:11:56.865 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -1.3371974229812622 neg ELBO G: 535192.875
# 2021-02-11T15:11:58.661 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -1.3432379961013794 neg ELBO G: 531414.625
# 2021-02-11T15:12:00.514 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -1.3527908325195312 neg ELBO G: 531382.25
# 2021-02-11T15:12:02.334 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -1.360969066619873 neg ELBO G: 534424.5625
# 2021-02-11T15:12:04.245 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -1.3633208274841309 neg ELBO G: 538548.25
# 2021-02-11T15:12:06.029 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -1.36924409866333 neg ELBO G: 542070.1875
# 2021-02-11T15:12:07.784 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -1.369410514831543 neg ELBO G: 544210.75
# 2021-02-11T15:12:09.585 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -1.3724894523620605 neg ELBO G: 545247.9375
# 2021-02-11T15:12:11.421 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -1.376210331916809 neg ELBO G: 545832.375
# 2021-02-11T15:12:13.225 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -1.3762986660003662 neg ELBO G: 546382.1875
# 2021-02-11T15:12:14.995 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -1.3788319826126099 neg ELBO G: 546892.4375
# 2021-02-11T15:12:16.849 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -1.3821808099746704 neg ELBO G: 547260.3125
# 2021-02-11T15:12:18.606 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -1.3832275867462158 neg ELBO G: 547601.875
# 2021-02-11T15:12:20.323 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -1.3814997673034668 neg ELBO G: 547801.8125
# 2021-02-11T15:12:22.089 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -1.3821046352386475 neg ELBO G: 547921.4375
# 2021-02-11T15:12:23.871 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -1.383959412574768 neg ELBO G: 548036.5625
# 2021-02-11T15:12:25.634 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -1.3831934928894043 neg ELBO G: 548172.5
# 2021-02-11T15:12:27.333 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -1.3868874311447144 neg ELBO G: 548191.9375
# 2021-02-11T15:12:29.113 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -1.3862409591674805 neg ELBO G: 548138.875
# 2021-02-11T15:12:30.891 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -1.386237621307373 neg ELBO G: 548206.375
# 2021-02-11T15:12:32.631 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -1.385657787322998 neg ELBO G: 548246.9375
# 2021-02-11T15:12:34.390 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -1.3898478746414185 neg ELBO G: 548062.4375
# 2021-02-11T15:12:36.115 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:12:38.600 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B6037F8 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T15:12:39.472 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B604101 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:12:39.474 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:12:39.555 INFO mmfunctions.anomaly.execute Adjusting target mean with 0.9515828942401342
# 2021-02-11T15:12:39.582 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B604101Prior mean: 0.0, sigma: 0.0022294619445541912
# 2021-02-11T15:12:39.622 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([119100, 1]) Sigma: torch.Size([119100, 1]) loglikelihood: torch.Size([119100, 1]) KL value: tensor(-178.2005, grad_fn=<MeanBackward0>)
# 2021-02-11T15:12:39.625 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([119100, 1]) Sigma: torch.Size([119100, 1]) loglikelihood: torch.Size([119100, 1]) KL: torch.Size([]) KL value: tensor(2160.0415, grad_fn=<MulBackward0>)
# 2021-02-11T15:12:39.626 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 179.01092529296875 neg ELBO G: 2161.34814453125
# 2021-02-11T15:12:40.534 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 75.5414047241211 neg ELBO G: 24842.099609375
# 2021-02-11T15:12:41.430 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 9.28297233581543 neg ELBO G: 119777.5703125
# 2021-02-11T15:12:42.348 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.5301889181137085 neg ELBO G: 259813.90625
# 2021-02-11T15:12:43.314 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -2.3689582347869873 neg ELBO G: 356989.53125
# 2021-02-11T15:12:44.228 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -2.465485095977783 neg ELBO G: 405884.375
# 2021-02-11T15:12:45.145 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -2.5054256916046143 neg ELBO G: 427036.90625
# 2021-02-11T15:12:46.076 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -2.5168471336364746 neg ELBO G: 435247.21875
# 2021-02-11T15:12:46.970 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -2.5361785888671875 neg ELBO G: 438352.71875
# 2021-02-11T15:12:47.914 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -2.541672945022583 neg ELBO G: 439965.375
# 2021-02-11T15:12:48.837 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -2.5532093048095703 neg ELBO G: 441527.125
# 2021-02-11T15:12:49.750 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -2.559530258178711 neg ELBO G: 443484.96875
# 2021-02-11T15:12:50.715 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -2.5650789737701416 neg ELBO G: 445907.4375
# 2021-02-11T15:12:51.617 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -2.572244882583618 neg ELBO G: 448726.84375
# 2021-02-11T15:12:52.515 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -2.577662944793701 neg ELBO G: 451860.0
# 2021-02-11T15:12:53.474 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -2.5423226356506348 neg ELBO G: 453857.8125
# 2021-02-11T15:12:54.388 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -2.5456223487854004 neg ELBO G: 451343.09375
# 2021-02-11T15:12:55.302 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -2.583059549331665 neg ELBO G: 451077.9375
# 2021-02-11T15:12:56.232 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -2.5847208499908447 neg ELBO G: 453143.96875
# 2021-02-11T15:12:57.156 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -2.5881175994873047 neg ELBO G: 456534.46875
# 2021-02-11T15:12:58.033 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -2.5927207469940186 neg ELBO G: 460537.75
# 2021-02-11T15:12:58.924 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -2.592590808868408 neg ELBO G: 464749.28125
# 2021-02-11T15:12:59.826 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -2.592019557952881 neg ELBO G: 468965.65625
# 2021-02-11T15:13:00.733 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -2.578744411468506 neg ELBO G: 473067.625
# 2021-02-11T15:13:01.627 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -2.411982774734497 neg ELBO G: 463387.53125
# 2021-02-11T15:13:02.519 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -2.527346134185791 neg ELBO G: 451448.1875
# 2021-02-11T15:13:03.498 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -2.568389415740967 neg ELBO G: 448281.59375
# 2021-02-11T15:13:04.406 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -2.585272789001465 neg ELBO G: 450343.09375
# 2021-02-11T15:13:05.331 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -2.588778257369995 neg ELBO G: 454828.03125
# 2021-02-11T15:13:06.429 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -2.5926225185394287 neg ELBO G: 460209.0
# 2021-02-11T15:13:07.329 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:13:09.139 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B604101 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# ['speed']
# 2021-02-11T15:13:13.655 INFO iotfunctions.dbtables.retrieve_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B606390 does not exist in table "BLUADMIN"."KPI_MODEL_STORE"
# 2021-02-11T15:13:13.657 INFO mmfunctions.anomaly.execute load model None
# 2021-02-11T15:13:13.731 INFO mmfunctions.anomaly.execute Adjusting target mean with 1.0210824924163784
# 2021-02-11T15:13:13.747 DEBUG mmfunctions.anomaly.execute Training VI model 1 for entity: 04714B606390Prior mean: 0.0, sigma: 0.002498010439096527
# 2021-02-11T15:13:13.772 INFO mmfunctions.anomaly.elbo Cardinalities: Mu: torch.Size([69360, 1]) Sigma: torch.Size([69360, 1]) loglikelihood: torch.Size([69360, 1]) KL value: tensor(-227.9799, grad_fn=<MeanBackward0>)
# 2021-02-11T15:13:13.775 INFO mmfunctions.anomaly.elbo_gauss Cardinalities: Mu: torch.Size([69360, 1]) Sigma: torch.Size([69360, 1]) loglikelihood: torch.Size([69360, 1]) KL: torch.Size([]) KL value: tensor(4512.0303, grad_fn=<MulBackward0>)
# 2021-02-11T15:13:13.776 DEBUG mmfunctions.anomaly.execute Epoch: 0, neg ELBO: 228.9693145751953 neg ELBO G: 4513.462890625
# 2021-02-11T15:13:14.335 DEBUG mmfunctions.anomaly.execute Epoch: 10, neg ELBO: 89.42282104492188 neg ELBO G: 9793.1552734375
# 2021-02-11T15:13:14.840 DEBUG mmfunctions.anomaly.execute Epoch: 20, neg ELBO: 7.1279072761535645 neg ELBO G: 77085.125
# 2021-02-11T15:13:15.354 DEBUG mmfunctions.anomaly.execute Epoch: 30, neg ELBO: -1.4010562896728516 neg ELBO G: 181422.265625
# 2021-02-11T15:13:15.861 DEBUG mmfunctions.anomaly.execute Epoch: 40, neg ELBO: -2.320091962814331 neg ELBO G: 239428.1875
# 2021-02-11T15:13:16.365 DEBUG mmfunctions.anomaly.execute Epoch: 50, neg ELBO: -2.4336204528808594 neg ELBO G: 259018.125
# 2021-02-11T15:13:16.869 DEBUG mmfunctions.anomaly.execute Epoch: 60, neg ELBO: -2.490309715270996 neg ELBO G: 263710.125
# 2021-02-11T15:13:17.396 DEBUG mmfunctions.anomaly.execute Epoch: 70, neg ELBO: -2.5197179317474365 neg ELBO G: 265422.625
# 2021-02-11T15:13:17.934 DEBUG mmfunctions.anomaly.execute Epoch: 80, neg ELBO: -2.519981861114502 neg ELBO G: 267228.25
# 2021-02-11T15:13:18.470 DEBUG mmfunctions.anomaly.execute Epoch: 90, neg ELBO: -2.529636859893799 neg ELBO G: 269173.875
# 2021-02-11T15:13:19.016 DEBUG mmfunctions.anomaly.execute Epoch: 100, neg ELBO: -2.5317978858947754 neg ELBO G: 271331.875
# 2021-02-11T15:13:19.693 DEBUG mmfunctions.anomaly.execute Epoch: 110, neg ELBO: -2.53067684173584 neg ELBO G: 273502.59375
# 2021-02-11T15:13:20.242 DEBUG mmfunctions.anomaly.execute Epoch: 120, neg ELBO: -2.53446888923645 neg ELBO G: 275582.96875
# 2021-02-11T15:13:20.761 DEBUG mmfunctions.anomaly.execute Epoch: 130, neg ELBO: -2.5360682010650635 neg ELBO G: 277515.46875
# 2021-02-11T15:13:21.281 DEBUG mmfunctions.anomaly.execute Epoch: 140, neg ELBO: -2.535830020904541 neg ELBO G: 279276.09375
# 2021-02-11T15:13:21.803 DEBUG mmfunctions.anomaly.execute Epoch: 150, neg ELBO: -2.537973403930664 neg ELBO G: 280855.125
# 2021-02-11T15:13:22.315 DEBUG mmfunctions.anomaly.execute Epoch: 160, neg ELBO: -2.5358636379241943 neg ELBO G: 282252.09375
# 2021-02-11T15:13:22.855 DEBUG mmfunctions.anomaly.execute Epoch: 170, neg ELBO: -2.536571741104126 neg ELBO G: 283465.21875
# 2021-02-11T15:13:23.405 DEBUG mmfunctions.anomaly.execute Epoch: 180, neg ELBO: -2.538421392440796 neg ELBO G: 284510.46875
# 2021-02-11T15:13:23.957 DEBUG mmfunctions.anomaly.execute Epoch: 190, neg ELBO: -2.542834520339966 neg ELBO G: 285410.34375
# 2021-02-11T15:13:24.485 DEBUG mmfunctions.anomaly.execute Epoch: 200, neg ELBO: -2.5375165939331055 neg ELBO G: 286180.15625
# 2021-02-11T15:13:25.026 DEBUG mmfunctions.anomaly.execute Epoch: 210, neg ELBO: -2.537548542022705 neg ELBO G: 286829.5
# 2021-02-11T15:13:25.543 DEBUG mmfunctions.anomaly.execute Epoch: 220, neg ELBO: -2.537674903869629 neg ELBO G: 287373.40625
# 2021-02-11T15:13:26.063 DEBUG mmfunctions.anomaly.execute Epoch: 230, neg ELBO: -2.542358160018921 neg ELBO G: 287832.34375
# 2021-02-11T15:13:26.576 DEBUG mmfunctions.anomaly.execute Epoch: 240, neg ELBO: -2.5390846729278564 neg ELBO G: 288224.84375
# 2021-02-11T15:13:27.099 DEBUG mmfunctions.anomaly.execute Epoch: 250, neg ELBO: -2.5411086082458496 neg ELBO G: 288558.4375
# 2021-02-11T15:13:27.636 DEBUG mmfunctions.anomaly.execute Epoch: 260, neg ELBO: -2.536559820175171 neg ELBO G: 288843.75
# 2021-02-11T15:13:28.161 DEBUG mmfunctions.anomaly.execute Epoch: 270, neg ELBO: -2.5411903858184814 neg ELBO G: 289088.3125
# 2021-02-11T15:13:28.706 DEBUG mmfunctions.anomaly.execute Epoch: 280, neg ELBO: -2.5410096645355225 neg ELBO G: 289302.28125
# 2021-02-11T15:13:29.256 DEBUG mmfunctions.anomaly.execute Epoch: 290, neg ELBO: -2.5455374717712402 neg ELBO G: 289492.4375
# 2021-02-11T15:13:29.788 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# 2021-02-11T15:13:32.398 INFO iotfunctions.dbtables.store_model Model model.IOT_SHADOW_PUMP_DE_GEN5.VIAnomalyScore.rms_z.04714B606390 of size 16642 bytes has been stored in table "BLUADMIN"."KPI_MODEL_STORE".
# CPU times: user 13min 27s, sys: 20.1 s, total: 13min 48s
# Wall time: 2min 44s
#                rms_x          rms_z          rms_y          power  \
# count  762630.000000  762630.000000  762630.000000  762630.000000
# mean        0.079898       0.300077       0.774366       6.199184
# std         0.087452       0.390011       0.431330       8.178557
# min         0.005411       0.010101       0.008728       0.000000
# 25%         0.014603       0.059778       0.955331       0.000000
# 50%         0.067691       0.101045       1.042266       1.753800
# 75%         0.087985       0.178913       1.044446      18.714600
# max         0.576303       1.044346       1.078255      20.277399
#
#                speed
# count  762630.000000
# mean      670.653717
# std       572.746119
# min         0.000000
# 25%         0.000000
# 50%      1060.000000
# 75%      1147.000000
# max      3600.000000

# %%
et.name
# Out:
# 'IOT_SHADOW_PUMP_DE_GEN5'

# %%
df_i.columns
# Out:
# Index(['rms_x', 'rms_z', 'rms_y', 'power', 'speed', 'predicted_rms_x',
#        'pred_dev_rms_x', 'predicted_rms_y', 'pred_dev_rms_y',
#        'predicted_rms_z', 'pred_dev_rms_z'],
#       dtype='object')

# %%
df_i.describe()
# Out:
#                rms_x          rms_z          rms_y          power  \
# count  762630.000000  762630.000000  762630.000000  762630.000000
# mean        0.079898       0.300077       0.774366       6.199184
# std         0.087452       0.390011       0.431330       8.178557
# min         0.005411       0.010101       0.008728       0.000000
# 25%         0.014603       0.059778       0.955331       0.000000
# 50%         0.067691       0.101045       1.042266       1.753800
# 75%         0.087985       0.178913       1.044446      18.714600
# max         0.576303       1.044346       1.078255      20.277399
#
#                speed
# count  762630.000000
# mean      670.653717
# std       572.746119
# min         0.000000
# 25%         0.000000
# 50%      1060.000000
# 75%      1147.000000
# max      3600.000000

# %%
#df_1[['AnomalyZ']].dropna()
# Out:
#                             AnomalyZ
# evt_timestamp
# 2020-10-31-12.38.56.846000  0.192863
# 2020-10-31-18.08.31.521000  0.194593
# 2020-10-31-18.08.51.521000  0.189823
# 2020-10-31-18.14.50.528000  0.200746
# 2020-10-31-18.18.31.928000  0.175144
# ...                              ...
# 2021-01-09-19.23.26.491000  0.192157
# 2021-01-09-19.23.46.491000  0.198031
# 2021-01-09-19.24.06.491000  0.191960
# 2021-01-09-19.24.46.491000  0.191667
# 2021-01-09-19.58.48.014000  0.180750
#
# [370 rows x 1 columns]

# %%
df_i.index.levels[0].values
# Out:
# array(['04714B601096', '04714B603408', '04714B6036B1', '04714B6037F8',
#        '04714B604101', '04714B606390'], dtype=object)

# %%
# no multilevel index for plotting
count = 3

df_1 = df_i.loc[df_i.index.levels[0].values[count]].copy()

# remove speed < 400
df_1[df_1['speed'] < 400] = np.nan

print (df_i.index.levels[0].values[count], df_1.shape)
# Out:
# 04714B6037F8 (219470, 11)

# %%
rmsstr = 'rms_x'
predstr = 'predicted_rms_x'
preddstr = 'pred_dev_rms_x'
anostr = 'AnomalyX'

# X-coordinate
arr1 = np.where(df_1[rmsstr] > df_1[predstr] + df_1[preddstr], df_1[rmsstr], 0) + \
       np.where(df_1[rmsstr] < df_1[predstr] - df_1[preddstr], df_1[rmsstr], 0)
arr1[arr1 == 0] = np.nan
df_1[anostr] = arr1

fig, ax = plt.subplots(1, 1, figsize=(10, 8), squeeze=False)

ax[0,0].scatter(df_1['speed'], df_1[rmsstr])
ax[0,0].scatter(df_1['speed'], df_1[predstr], color='green')
ax[0,0].scatter(df_1['speed'], df_1[predstr] - df_1[preddstr], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['speed'], df_1[predstr] + df_1[preddstr], color='orange', lw=0.1)
ax[0,0].scatter(df_1['speed'], df_1[anostr], color='red', lw=2)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration - X')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i.index.levels[0].values[count])
# Out:
# Text(0.5, 1.0, 'pump 04714B6037F8')

# %%
rmsstr = 'rms_y'
predstr = 'predicted_rms_y'
preddstr = 'pred_dev_rms_y'
anostr = 'AnomalyY'

# Y-coordinate
arr1 = np.where(df_1[rmsstr] > df_1[predstr] + df_1[preddstr], df_1[rmsstr], 0) + \
       np.where(df_1[rmsstr] < df_1[predstr] - df_1[preddstr], df_1[rmsstr], 0)
arr1[arr1 == 0] = np.nan
df_1[anostr] = arr1

fig, ax = plt.subplots(1, 1, figsize=(10, 8), squeeze=False)

ax[0,0].scatter(df_1['speed'], df_1[rmsstr])
ax[0,0].scatter(df_1['speed'], df_1[predstr], color='green')
ax[0,0].scatter(df_1['speed'], df_1[predstr] - df_1[preddstr], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['speed'], df_1[predstr] + df_1[preddstr], color='orange', lw=0.1)
ax[0,0].scatter(df_1['speed'], df_1[anostr], color='red', lw=2)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration - Y')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i.index.levels[0].values[count])
# Out:
# Text(0.5, 1.0, 'pump 04714B6037F8')

# %%
rmsstr = 'rms_z'
predstr = 'predicted_rms_z'
preddstr = 'pred_dev_rms_z'
anostr = 'AnomalyZ'

# Z-coordinate
arr1 = np.where(df_1[rmsstr] > df_1[predstr] + df_1[preddstr], df_1[rmsstr], 0) + \
       np.where(df_1[rmsstr] < df_1[predstr] - df_1[preddstr], df_1[rmsstr], 0)
arr1[arr1 == 0] = np.nan
df_1[anostr] = arr1

fig, ax = plt.subplots(1, 1, figsize=(10, 8), squeeze=False)

ax[0,0].scatter(df_1['speed'], df_1[rmsstr])
ax[0,0].scatter(df_1['speed'], df_1[predstr], color='green')
ax[0,0].scatter(df_1['speed'], df_1[predstr] - df_1[preddstr], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['speed'], df_1[predstr] + df_1[preddstr], color='orange', lw=0.1)
ax[0,0].scatter(df_1['speed'], df_1[anostr], color='red', lw=2)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration - Z')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i.index.levels[0].values[count])
# Out:
# Text(0.5, 1.0, 'pump 04714B6037F8')

# %%
#df_1 = df_i.loc[df_i.index.levels[0].values[0]].copy()

fig, ax = plt.subplots(2, 2, figsize=(20, 9), squeeze=False)

ax[0,0].scatter(df_1['speed'], df_1['rms_x'])
ax[0,0].scatter(df_1['speed'], df_1['predicted_rms_x'], color='green')
ax[0,0].scatter(df_1['speed'], df_1['predicted_rms_x'] - df_1['pred_dev_rms_x'], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['speed'], df_1['predicted_rms_x'] + df_1['pred_dev_rms_x'], color='orange', lw=0.1)
ax[0,0].scatter(df_1['speed'], df_1['AnomalyX'], color='red', lw=0.5)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration - X')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i.index.levels[0].values[count])


ax[0,1].scatter(df_1['speed'], df_1['rms_y'])
ax[0,1].scatter(df_1['speed'], df_1['predicted_rms_y'], color='green')
ax[0,1].scatter(df_1['speed'], df_1['predicted_rms_y'] - df_1['pred_dev_rms_y'], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,1].scatter(df_1['speed'], df_1['predicted_rms_y'] + df_1['pred_dev_rms_y'], color='orange', lw=0.1)
ax[0,1].scatter(df_1['speed'], df_1['AnomalyY'], color='red', lw=0.5)
ax[0,1].set_xlabel('Speed')
ax[0,1].set_ylabel('Vibration - Y')
ax[0,1].legend()
ax[0,1].set_title('pump ' + df_i.index.levels[0].values[count])

ax[1,0].scatter(df_1['speed'], df_1['rms_z'])
ax[1,0].scatter(df_1['speed'], df_1['predicted_rms_z'], color='green')
ax[1,0].scatter(df_1['speed'], df_1['predicted_rms_z'] - df_1['pred_dev_rms_z'], color='orange', lw=0.1, label='limit - p<0.05')
ax[1,0].scatter(df_1['speed'], df_1['predicted_rms_z'] + df_1['pred_dev_rms_z'], color='orange', lw=0.1)
ax[1,0].scatter(df_1['speed'], df_1['AnomalyZ'], color='red', lw=0.5)
ax[1,0].set_xlabel('Speed')
ax[1,0].set_ylabel('Vibration - Z')
ax[1,0].legend()
ax[1,0].set_title('pump ' + df_i.index.levels[0].values[count])


#ax[1,1].scatter(df_1['speed'], df_1['rms_y'])
#ax[1,1].set_xlabel('Speed')
#ax[1,1].set_ylabel('Vibration - Y')
#ax[1,1].legend()
ax[1,1].set_title('Hic sunt leones !')

#plt.fill_between(df_1['Ap'], - df_1['pred_dev_Vx'], df_1['pred_dev_Vx'], alpha=0.2)
# Out:
# Text(0.5, 1.0, 'Hic sunt leones !')

# %%
'''
df_1i = df_1[24000:28000]
cnt = 0
fig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)
ax[cnt,0].scatter(df_1i.index,df_1i['rms_x'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyX'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (X)' + df_i.index.levels[0].values[0])
ax[cnt,0].tick_params(axis = "x", which = "both", bottom = False, top = False)
ax[cnt,0].set_xticklabels([])
'''
# Out:
# '\ndf_1i = df_1[24000:28000]\ncnt = 0\nfig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)\nax[cnt,0].scatter(df_1i.index,df_1i[\'rms_x\'], lw=0.4, color=\'green\', label=\'vibration\')\nax[cnt,0].scatter(df_1i.index, df_1i[\'AnomalyX\'], lw=0.4, color=\'red\', zorder=10, label=\'excessive vibration\')\nax[cnt,0].legend()\nax[cnt,0].set_title(\'pump (X)\' + df_i.index.levels[0].values[0])\nax[cnt,0].tick_params(axis = "x", which = "both", bottom = False, top = False)\nax[cnt,0].set_xticklabels([])\n'

# %%
'''
df_1i = df_1[24000:28000]
cnt = 0
fig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)
ax[cnt,0].scatter(df_1i.index,df_1i['rms_y'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyY'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (Y)' + df_i.index.levels[0].values[0])
ax[cnt,0].tick_params(axis = "x", which = "both", bottom = False, top = False)
ax[cnt,0].set_xticklabels([])
'''
# Out:
# '\ndf_1i = df_1[24000:28000]\ncnt = 0\nfig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)\nax[cnt,0].scatter(df_1i.index,df_1i[\'rms_y\'], lw=0.4, color=\'green\', label=\'vibration\')\nax[cnt,0].scatter(df_1i.index, df_1i[\'AnomalyY\'], lw=0.4, color=\'red\', zorder=10, label=\'excessive vibration\')\nax[cnt,0].legend()\nax[cnt,0].set_title(\'pump (Y)\' + df_i.index.levels[0].values[0])\nax[cnt,0].tick_params(axis = "x", which = "both", bottom = False, top = False)\nax[cnt,0].set_xticklabels([])\n'

# %%
# OOM for ~170000 data points
'''
df_1i = df_1[0:4000]
fig, ax = plt.subplots(4, 1, figsize=(15, 12), squeeze=False)

cnt = 0
ax[0,0].scatter(df_1i.index,df_1i['speed'], lw=0.4, color='orange', zorder=5, label='speed')
cnt += 1
ax[cnt,0].scatter(df_1i.index,df_1i['rms_x'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyX'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (X)' + df_i.index.levels[0].values[0])
cnt += 1
ax[cnt,0].scatter(df_1i.index,df_1i['rms_y'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyY'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (Y)' + df_i.index.levels[0].values[0])
cnt += 1
ax[cnt,0].scatter(df_1i.index,df_1i['rms_z'], lw=0.4, color='green', label='vibration')
ax[cnt,0].scatter(df_1i.index, df_1i['AnomalyZ'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[cnt,0].legend()
ax[cnt,0].set_title('pump (Z)' + df_i.index.levels[0].values[0])
'''
# Out:
# "\ndf_1i = df_1[0:4000]\nfig, ax = plt.subplots(4, 1, figsize=(15, 12), squeeze=False)\n\ncnt = 0\nax[0,0].scatter(df_1i.index,df_1i['speed'], lw=0.4, color='orange', zorder=5, label='speed')\ncnt += 1\nax[cnt,0].scatter(df_1i.index,df_1i['rms_x'], lw=0.4, color='green', label='vibration')\nax[cnt,0].scatter(df_1i.index, df_1i['AnomalyX'], lw=0.4, color='red', zorder=10, label='excessive vibration')\nax[cnt,0].legend()\nax[cnt,0].set_title('pump (X)' + df_i.index.levels[0].values[0])\ncnt += 1\nax[cnt,0].scatter(df_1i.index,df_1i['rms_y'], lw=0.4, color='green', label='vibration')\nax[cnt,0].scatter(df_1i.index, df_1i['AnomalyY'], lw=0.4, color='red', zorder=10, label='excessive vibration')\nax[cnt,0].legend()\nax[cnt,0].set_title('pump (Y)' + df_i.index.levels[0].values[0])\ncnt += 1\nax[cnt,0].scatter(df_1i.index,df_1i['rms_z'], lw=0.4, color='green', label='vibration')\nax[cnt,0].scatter(df_1i.index, df_1i['AnomalyZ'], lw=0.4, color='red', zorder=10, label='excessive vibration')\nax[cnt,0].legend()\nax[cnt,0].set_title('pump (Z)' + df_i.index.levels[0].values[0])\n"

# %%
df_i.loc['04714B601096'].index
# Out:
# Index(['2020-07-19-11.39.28.701000', '2020-07-19-11.39.48.701000',
#        '2020-07-19-11.40.08.701000', '2020-07-19-11.40.28.701000',
#        '2020-07-19-11.40.48.701000', '2020-07-19-11.44.28.948000',
#        '2020-07-19-11.44.48.948000', '2020-07-19-11.45.08.948000',
#        '2020-07-19-11.45.28.948000', '2020-07-19-11.45.48.948000',
#        ...
#        '2021-01-11-11.35.48.595000', '2021-01-11-11.39.28.840000',
#        '2021-01-11-11.39.48.840000', '2021-01-11-11.40.08.840000',
#        '2021-01-11-11.40.28.840000', '2021-01-11-11.40.48.840000',
#        '2021-01-11-14.14.56.144000', '2021-01-11-14.15.16.144000',
#        '2021-01-11-14.15.36.144000', '2021-01-11-14.15.56.144000'],
#       dtype='object', name='evt_timestamp', length=177980)

# %% [markdown]
# #### Does it make sense to have both accel values as features

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 5), squeeze=False)
ax[0,0].scatter(df_i['speed'].values, df_i['power'].values)
ax[0,0].set_xlabel('accel speed')
ax[0,0].set_ylabel('accel power')

#ax[0,1].plot(df_i.loc['04714B601096'].index, df_i['speed'].values, color='green')
#ax[0,1].plot(df_i.loc['04714B601096'].index, df_i['power'].values*100 + 400, color='orange')

#df_i[['As','Ap']].plot(figsize=(20,20))
# Out:
# Text(0, 0.5, 'accel power')

# %%
# hack - do not store model in db2
old_model_store = db.model_store
db.model_store = FileModelStore()

# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsib = BayesRidgeRegressor(['speed'], ['power'])
et = spsib._build_entity_type(columns = [Column('speed',Float())], **jobsettings)
spsib._entity_type = et
df_i = spsib.execute(df=df_i)

db.model_store = old_model_store
df_i.describe()
# Out:
# 2021-02-05T15:14:53.524 INFO iotfunctions.dbtables.__init__ Init FileModelStore
# 2021-02-05T15:14:53.525 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2021-02-05T15:14:53.526 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.3.1
# 2021-02-05T15:14:53.526 DEBUG iotfunctions.util.__init__ Starting trace
# 2021-02-05T15:14:53.527 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_BayesRidgeRegressor_20210205141453
# 2021-02-05T15:14:53.527 DEBUG iotfunctions.util.__init__ auto_save None
# 2021-02-05T15:14:53.528 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2021-02-05T15:14:53.529 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2021-02-05T15:14:53.529 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR
# Functions:
# Granularities:
# No schedules metadata
# 2021-02-05T15:14:53.532 DEBUG iotfunctions.anomaly.execute ['04714B601096'] predicting ['power'] from ['speed'] to appear in ['predicted_power'] with confidence interval ['stddev_power']
# 2021-02-05T15:14:53.536 DEBUG iotfunctions.anomaly.execute check passed
# 2021-02-05T15:14:53.562 INFO iotfunctions.base.get_models_for_training predicting target power
# 2021-02-05T15:14:53.564 INFO iotfunctions.dbtables.retrieve_model Model model.TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR.BayesRidgeRegressor.power.04714B601096 of size 1825 bytes has been retrieved from filesystem
# 2021-02-05T15:14:53.564 INFO iotfunctions.base.get_models_for_training load model {
#  "name": "model.TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR.BayesRidgeRegressor.power.04714B601096",
#  "target": "power",
#  "features": [
#   "speed"
#  ],
#  "estimator_name": "bayesianridge",
#  "eval_metric_name": "r2_score",
#  "eval_metric_train": 1.0,
#  "eval_metric_test": 1.0,
#  "trained_date": "2021-02-04T09:03:27.991368",
#  "expiry_date": null,
#  "col_name": "predicted_power",
#  "col_name_stddev": "stddev_power"
# }
# 2021-02-05T15:14:53.565 INFO iotfunctions.base.get_models_for_training training required: False  results: Existing model has not expired and eval metric is good
# 2021-02-05T15:14:53.565 INFO iotfunctions.dbtables.retrieve_model Model model.TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR.BayesRidgeRegressor.power.04714B601096 of size 1825 bytes has been retrieved from filesystem
# 2021-02-05T15:14:53.576 INFO iotfunctions.metadata.predict_with_std_dev predicted using model model.TEST_ENTITY_FOR_BAYESRIDGEREGRESSOR.BayesRidgeRegressor.power.04714B601096
# 2021-02-05T15:14:53.581 DEBUG iotfunctions.util.log_df_info After adding predictions for target power ; df row count: 177980  ; index: { deviceid , evt_timestamp }  ; columns: { rms_x , rms_z , rms_y , power , speed , predicted_rms_x , pred_dev_rms_x , predicted_rms_y , pred_dev_rms_y , predicted_rms_z , pred_dev_rms_z , predicted_power , stddev_power }
# 2021-02-05T15:14:53.607 DEBUG iotfunctions.anomaly.execute BayesianRidge: Entity 04714B601096 Type of pred, stddev arrays <class 'pandas.core.frame.DataFrame'><class 'numpy.ndarray'>
#                rms_x          rms_z          rms_y          power  \
# count  177980.000000  177980.000000  177980.000000  177980.000000
# mean        0.201499       0.087049       0.964827       2.052877
# std         0.101279       0.028381       0.005473       0.435038
# min         0.018446       0.027219       0.952113       0.115600
# 25%         0.108721       0.065397       0.959472       1.740200
# 50%         0.189055       0.078209       0.965996       1.795200
# 75%         0.278364       0.100557       0.969530       2.325800
# max         0.576303       0.244273       0.979979       6.122200
#
#                speed  predicted_rms_x  pred_dev_rms_x  predicted_rms_y  \
# count  177980.000000    177980.000000   177980.000000    177980.000000
# mean     1079.609838         0.199317        0.243256         0.964607
# std        30.031477         0.050033        0.103079         0.004391
# min       212.000000         0.051936       -0.043635         0.959193
# 25%      1059.000000         0.202365        0.173472         0.960191
# 50%      1062.000000         0.205529        0.305867         0.963184
# 75%      1096.000000         0.218051        0.306096         0.969012
# max      1353.000000         0.274805        1.510480         0.977185
#
#        pred_dev_rms_y  predicted_rms_z  pred_dev_rms_z  predicted_power  \
# count   177980.000000    177980.000000   177980.000000    177980.000000
# mean         0.024917         0.080121        0.096390      1079.609838
# std          0.005371         0.002173        0.027322        30.031477
# min          0.007013        -0.304107       -0.205957       212.000000
# 25%          0.020119         0.080134        0.075043      1059.000000
# 50%          0.022496         0.080134        0.083694      1062.000000
# 75%          0.030674         0.080134        0.112059      1096.000000
# max          0.134411         0.080134        0.160004      1353.000000
#
#        stddev_power
# count  1.779800e+05
# mean   2.494303e-05
# std    6.791502e-07
# min    6.093499e-06
# 25%    2.447661e-05
# 50%    2.454446e-05
# 75%    2.531369e-05
# max    3.114243e-05

# %%
df_2 = df_i[0:10000]
df_2 = df_2[df_2['speed'] > 400]

# %%
plots = 1

fig, ax = plt.subplots(plots, 1, figsize=(20,10), squeeze=False)
cnt = 0
ax[cnt,0].plot(df_2.unstack(level=0).index, df_2['speed'],linewidth=0.5,color='blue',label='speed')
ax[cnt,0].plot(df_2.unstack(level=0).index, df_2['power'],linewidth=0.5,color='green',label='power')
ax[cnt,0].plot(df_2.unstack(level=0).index, df_2['predicted_power'],linewidth=0.5,color='red',label='MaxTemp pred')
ax[cnt,0].fill_between(df_2.unstack(level=0).index, df_2['predicted_power'] - df_2['stddev_power'],
                df_2['predicted_power'] + df_2['stddev_power'], color="pink", alpha=0.3, label="predict stddev")
ax[cnt,0].legend(bbox_to_anchor=(1.1, 1.05))
ax[cnt,0].set_ylabel('power',fontsize=12,weight="bold")
ax[cnt,0].set_xlabel('speed',fontsize=12,weight="bold")
cnt = 1
# Out:
# 2021-02-05T15:16:27.266 DEBUG matplotlib.font_manager._findfont_cached findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=bold:stretch=normal:size=12.0.
# 2021-02-05T15:16:27.266 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'cmex10' (cmex10.ttf) normal normal 400 normal>) = 10.335
# 2021-02-05T15:16:27.267 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal regular normal>) = 10.335
# 2021-02-05T15:16:27.267 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal regular normal>) = 10.335
# 2021-02-05T15:16:27.268 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'STIXSizeOneSym' (STIXSizOneSymReg.ttf) normal normal regular normal>) = 10.335
# 2021-02-05T15:16:27.268 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal regular normal>) = 10.335
# 2021-02-05T15:16:27.269 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal bold normal>) = 1.0
# 2021-02-05T15:16:27.269 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'cmr10' (cmr10.ttf) normal normal 400 normal>) = 10.335
# 2021-02-05T15:16:27.270 DEBUG matplotlib.font_manager._findfont_cached findfont: score(<Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal bold normal>) = 0.0
# 2021-02-05T15:16:27.270 DEBUG matplotlib.font_manager._findfont_cached findfont: Matching :family=sans-serif:style=normal:variant=normal:weight=bold:stretch=normal:size=12.0 to DejaVu Sans ('/home/markus/.local/lib/python3.8/site-packages/matplotlib/mpl-data/fonts/ttf/DejaVuSans-Bold.ttf') with score of 0.000000.

# %%
def load_data_short(filename):
    # load data
    df_input = pd.read_csv(filename, parse_dates=['RCV_TIMESTAMP_UTC'], comment='#')
    #df_input = df_input.asfreq('H')
    df_input = df_input.sort_values(by='RCV_TIMESTAMP_UTC').\
                    rename(columns={'RCV_TIMESTAMP_UTC':'timestamp', 'DEVICEID': 'entity'}).\
                    drop(columns=['DEVICETYPE', 'FORMAT','UPDATED_UTC','LOGICALINTERFACE_ID','DEVICE_ID']).\
                    drop(columns=['RMS_X','RMS_Y','RMS_Z'])
    #df_input = df_input[df_input['VERSION'] != 0].drop(columns=['VERSION'])
       
    return df_input
    
def prep_data_short(df_input):
    entity = df_input['entity'].values[0]
    
    list_ac_vx = []
    cnt = 0
    for idx,row in df_input[['timestamp','VIBRATIONS_XAXIS','ACCEL_SPEED']].iterrows():
        if isinstance(row['timestamp'], str):
            ts = datetime.datetime.strptime(row['timestamp'], '%Y-%m-%d-%H.%M.%S.%f')
        else:
            ts = row['timestamp']
            
        rvibs = row['VIBRATIONS_XAXIS']
        racc = row['ACCEL_SPEED']
        
        if isinstance(racc, str):
            racc = eval(racc)

        if not isinstance(racc, list) and math.isnan(racc):
            continue
            
        if isinstance(rvibs, str):
            list_ac = []
           
            for ac in racc:
                #print(ac)
                list_ac.append(eval(ac))
                list_ac.append(eval(ac))
                list_ac.append(eval(ac))
                #print (list_ac)

            list_vx = []
            for vx in eval(rvibs):
                list_vx.append(vx)
                #print (list_vx)

            #print(list_ac, list_vx)
            cnt2 = 0
            for p in zip(list_ac, list_vx):
                #print(ts + datetime.timedelta(seconds = cnt2 * 10), p[0],p[1])
                list_ac_vx.append([ts + datetime.timedelta(seconds = cnt2 * 10), p[0],p[1]])
                cnt2 += 1
        cnt += 1

    df_clean = pd.DataFrame(list_ac_vx, columns=['timestamp','Ap','Vx'])
    df_clean['Ap'] = df_clean['Ap']/1000
    df_clean['entity'] = entity
    
    return df_clean.set_index(['entity','timestamp'])

# %%
#df_clean2 = prep_data(load_data('./IOT_PUMP_DE_GEN5_202012151526.csv'))
df_clean2 = prep_data_short(load_data_short('./04714B603408.csv'))
#df_clean2.describe()
df_clean2.head(2)
df_clean2.index.levels[0].values[0]
# Out:
# '04714B603408'

# %%
df_clean2.describe()
# Out:
#                  Ap            Vx
# count  1.371300e+06  1.371300e+06
# mean   1.501744e+00 -2.946143e-02
# std    1.482848e+00  1.308858e-01
# min    0.000000e+00 -1.039100e+00
# 25%    0.000000e+00 -4.390000e-02
# 50%    1.281000e+00 -2.730000e-02
# 75%    3.099000e+00 -8.800000e-03
# max    3.780000e+00  1.035200e+00

# %%
plt.figure(figsize=(16, 6))
g = sns.displot(df_clean2[['Ap','Vx']], x='Ap', y='Vx', kind="kde", rug=True)
    
g.set_titles('KDE for' + df_clean2.index.levels[0].values[0])

# %%
df_i2 = df_clean2.copy()

# %%
# %%time
print('Train and evaluate model for ' + df_i2.index.levels[0].values[0])
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsi2 = VIAnomalyScore(['Ap'], ['Vx'])
et = spsi2._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
spsi2._entity_type = et
spsi2.epochs = 300   # 1500 takes ages
df_i2 = spsi.execute(df=df_i2)

EngineLogging.configure_console_logging(logging.INFO)
df_i2.describe()
# Out:
# Train and evaluate model for 04714B603408
# 2020-12-22T13:57:10.081 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2020-12-22T13:57:10.082 DEBUG mmfunctions.anomaly.__init__ init KDE Estimator
# 2020-12-22T13:57:10.083 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.2.1
# 2020-12-22T13:57:10.084 DEBUG iotfunctions.util.__init__ Starting trace
# 2020-12-22T13:57:10.084 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20201222125710
# 2020-12-22T13:57:10.084 DEBUG iotfunctions.util.__init__ auto_save None
# 2020-12-22T13:57:10.085 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2020-12-22T13:57:10.085 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2020-12-22T13:57:10.085 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# Here 1 <class 'pandas.core.frame.DataFrame'>
# 2020-12-22T13:57:10.093 DEBUG mmfunctions.anomaly.execute ['04714B603408']
# ['Ap']
# 2020-12-22T13:57:10.306 INFO iotfunctions.dbtables.retrieve_model Model model.TEST_ENTITY_FOR_VIANOMALYSCORE.VIAnomalyScore.Vx.04714B603408 does not exist in filesystem
# 2020-12-22T13:57:10.306 INFO mmfunctions.anomaly.execute load model None
# 2020-12-22T13:57:11.221 DEBUG mmfunctions.anomaly.execute Epoch: 0, Loss: 0.8914065361022949
# 2020-12-22T13:57:21.196 DEBUG mmfunctions.anomaly.execute Epoch: 10, Loss: 0.6331454515457153
# 2020-12-22T13:57:31.118 DEBUG mmfunctions.anomaly.execute Epoch: 20, Loss: 0.56513911485672
# 2020-12-22T13:57:41.202 DEBUG mmfunctions.anomaly.execute Epoch: 30, Loss: 0.5272055268287659
# 2020-12-22T13:57:51.118 DEBUG mmfunctions.anomaly.execute Epoch: 40, Loss: 0.51528400182724
# 2020-12-22T13:58:01.048 DEBUG mmfunctions.anomaly.execute Epoch: 50, Loss: 0.5176530480384827
# 2020-12-22T13:58:11.025 DEBUG mmfunctions.anomaly.execute Epoch: 60, Loss: 0.5161495208740234
# 2020-12-22T13:58:21.046 DEBUG mmfunctions.anomaly.execute Epoch: 70, Loss: 0.515254020690918
# 2020-12-22T13:58:31.043 DEBUG mmfunctions.anomaly.execute Epoch: 80, Loss: 0.5147814750671387
# 2020-12-22T13:58:41.231 DEBUG mmfunctions.anomaly.execute Epoch: 90, Loss: 0.5146395564079285
# 2020-12-22T13:58:51.802 DEBUG mmfunctions.anomaly.execute Epoch: 100, Loss: 0.515004575252533
# 2020-12-22T13:59:02.172 DEBUG mmfunctions.anomaly.execute Epoch: 110, Loss: 0.5155276656150818
# 2020-12-22T13:59:12.339 DEBUG mmfunctions.anomaly.execute Epoch: 120, Loss: 0.5141093134880066
# 2020-12-22T13:59:22.321 DEBUG mmfunctions.anomaly.execute Epoch: 130, Loss: 0.5144382119178772
# 2020-12-22T13:59:32.385 DEBUG mmfunctions.anomaly.execute Epoch: 140, Loss: 0.5153028964996338
# 2020-12-22T13:59:42.491 DEBUG mmfunctions.anomaly.execute Epoch: 150, Loss: 0.5147557258605957
# 2020-12-22T13:59:52.704 DEBUG mmfunctions.anomaly.execute Epoch: 160, Loss: 0.514911949634552
# 2020-12-22T14:00:02.880 DEBUG mmfunctions.anomaly.execute Epoch: 170, Loss: 0.5151118040084839
# 2020-12-22T14:00:13.050 DEBUG mmfunctions.anomaly.execute Epoch: 180, Loss: 0.5142313241958618
# 2020-12-22T14:00:23.218 DEBUG mmfunctions.anomaly.execute Epoch: 190, Loss: 0.5151821970939636
# 2020-12-22T14:00:33.321 DEBUG mmfunctions.anomaly.execute Epoch: 200, Loss: 0.5146312117576599
# 2020-12-22T14:00:43.626 DEBUG mmfunctions.anomaly.execute Epoch: 210, Loss: 0.5153499245643616
# 2020-12-22T14:00:53.778 DEBUG mmfunctions.anomaly.execute Epoch: 220, Loss: 0.5148592591285706
# 2020-12-22T14:01:04.026 DEBUG mmfunctions.anomaly.execute Epoch: 230, Loss: 0.5150873064994812
# 2020-12-22T14:01:14.208 DEBUG mmfunctions.anomaly.execute Epoch: 240, Loss: 0.5148673057556152
# 2020-12-22T14:01:24.167 DEBUG mmfunctions.anomaly.execute Epoch: 250, Loss: 0.515082836151123
# 2020-12-22T14:01:34.233 DEBUG mmfunctions.anomaly.execute Epoch: 260, Loss: 0.515089213848114
# 2020-12-22T14:01:44.408 DEBUG mmfunctions.anomaly.execute Epoch: 270, Loss: 0.5139238834381104
# 2020-12-22T14:01:54.596 DEBUG mmfunctions.anomaly.execute Epoch: 280, Loss: 0.5150812864303589
# 2020-12-22T14:02:05.458 DEBUG mmfunctions.anomaly.execute Epoch: 290, Loss: 0.5146006345748901
# 2020-12-22T14:02:15.839 DEBUG mmfunctions.anomaly.execute Epoch: 300, Loss: 0.5148071050643921
# 2020-12-22T14:02:25.985 DEBUG mmfunctions.anomaly.execute Epoch: 310, Loss: 0.5151475667953491
# 2020-12-22T14:02:36.358 DEBUG mmfunctions.anomaly.execute Epoch: 320, Loss: 0.5154476761817932
# 2020-12-22T14:02:46.581 DEBUG mmfunctions.anomaly.execute Epoch: 330, Loss: 0.5145741701126099
# 2020-12-22T14:02:56.706 DEBUG mmfunctions.anomaly.execute Epoch: 340, Loss: 0.5140682458877563
# 2020-12-22T14:03:06.818 DEBUG mmfunctions.anomaly.execute Epoch: 350, Loss: 0.5148553252220154
# 2020-12-22T14:03:16.944 DEBUG mmfunctions.anomaly.execute Epoch: 360, Loss: 0.5152938961982727
# 2020-12-22T14:03:26.998 DEBUG mmfunctions.anomaly.execute Epoch: 370, Loss: 0.5144619345664978
# 2020-12-22T14:03:37.211 DEBUG mmfunctions.anomaly.execute Epoch: 380, Loss: 0.5145074725151062
# 2020-12-22T14:03:47.529 DEBUG mmfunctions.anomaly.execute Epoch: 390, Loss: 0.5141514539718628
# 2020-12-22T14:03:57.711 DEBUG mmfunctions.anomaly.execute Epoch: 400, Loss: 0.515694260597229
# 2020-12-22T14:04:07.877 DEBUG mmfunctions.anomaly.execute Epoch: 410, Loss: 0.5152667760848999
# 2020-12-22T14:04:17.942 DEBUG mmfunctions.anomaly.execute Epoch: 420, Loss: 0.514506995677948
# 2020-12-22T14:04:28.160 DEBUG mmfunctions.anomaly.execute Epoch: 430, Loss: 0.5140680074691772
# 2020-12-22T14:04:38.418 DEBUG mmfunctions.anomaly.execute Epoch: 440, Loss: 0.5151513814926147
# 2020-12-22T14:04:48.858 DEBUG mmfunctions.anomaly.execute Epoch: 450, Loss: 0.5153243541717529
# 2020-12-22T14:04:59.093 DEBUG mmfunctions.anomaly.execute Epoch: 460, Loss: 0.5149504542350769
# 2020-12-22T14:05:09.372 DEBUG mmfunctions.anomaly.execute Epoch: 470, Loss: 0.5146647691726685
# 2020-12-22T14:05:19.537 DEBUG mmfunctions.anomaly.execute Epoch: 480, Loss: 0.5142231583595276
# 2020-12-22T14:05:29.721 DEBUG mmfunctions.anomaly.execute Epoch: 490, Loss: 0.5133796334266663
# 2020-12-22T14:05:39.882 DEBUG mmfunctions.anomaly.execute Epoch: 500, Loss: 0.5152966380119324
# 2020-12-22T14:05:50.110 DEBUG mmfunctions.anomaly.execute Epoch: 510, Loss: 0.5144299864768982
# 2020-12-22T14:06:00.274 DEBUG mmfunctions.anomaly.execute Epoch: 520, Loss: 0.5148006677627563
# 2020-12-22T14:06:10.541 DEBUG mmfunctions.anomaly.execute Epoch: 530, Loss: 0.5146817564964294
# 2020-12-22T14:06:20.738 DEBUG mmfunctions.anomaly.execute Epoch: 540, Loss: 0.5140889286994934
# 2020-12-22T14:06:30.766 DEBUG mmfunctions.anomaly.execute Epoch: 550, Loss: 0.5141640901565552
# 2020-12-22T14:06:40.877 DEBUG mmfunctions.anomaly.execute Epoch: 560, Loss: 0.5149827003479004
# 2020-12-22T14:06:51.163 DEBUG mmfunctions.anomaly.execute Epoch: 570, Loss: 0.5139686465263367
# 2020-12-22T14:07:01.329 DEBUG mmfunctions.anomaly.execute Epoch: 580, Loss: 0.5154014229774475
# 2020-12-22T14:07:11.506 DEBUG mmfunctions.anomaly.execute Epoch: 590, Loss: 0.5142351984977722
# 2020-12-22T14:07:21.830 DEBUG mmfunctions.anomaly.execute Epoch: 600, Loss: 0.5153434872627258
# 2020-12-22T14:07:32.068 DEBUG mmfunctions.anomaly.execute Epoch: 610, Loss: 0.5152716040611267
# 2020-12-22T14:07:42.397 DEBUG mmfunctions.anomaly.execute Epoch: 620, Loss: 0.5144082307815552
# 2020-12-22T14:07:52.674 DEBUG mmfunctions.anomaly.execute Epoch: 630, Loss: 0.5143427848815918
# 2020-12-22T14:08:03.039 DEBUG mmfunctions.anomaly.execute Epoch: 640, Loss: 0.5143038034439087
# 2020-12-22T14:08:13.204 DEBUG mmfunctions.anomaly.execute Epoch: 650, Loss: 0.5141136050224304
# 2020-12-22T14:08:23.457 DEBUG mmfunctions.anomaly.execute Epoch: 660, Loss: 0.5130411982536316
# 2020-12-22T14:08:33.750 DEBUG mmfunctions.anomaly.execute Epoch: 670, Loss: 0.5142372250556946
# 2020-12-22T14:08:43.972 DEBUG mmfunctions.anomaly.execute Epoch: 680, Loss: 0.5152056217193604
# 2020-12-22T14:08:54.216 DEBUG mmfunctions.anomaly.execute Epoch: 690, Loss: 0.5141973495483398
# 2020-12-22T14:09:04.555 DEBUG mmfunctions.anomaly.execute Epoch: 700, Loss: 0.5143685340881348
# 2020-12-22T14:09:14.739 DEBUG mmfunctions.anomaly.execute Epoch: 710, Loss: 0.5157939791679382
# 2020-12-22T14:09:25.001 DEBUG mmfunctions.anomaly.execute Epoch: 720, Loss: 0.5140376091003418
# 2020-12-22T14:09:35.230 DEBUG mmfunctions.anomaly.execute Epoch: 730, Loss: 0.5148692727088928
# 2020-12-22T14:09:45.743 DEBUG mmfunctions.anomaly.execute Epoch: 740, Loss: 0.513357400894165
# 2020-12-22T14:09:56.328 DEBUG mmfunctions.anomaly.execute Epoch: 750, Loss: 0.5140331387519836
# 2020-12-22T14:10:06.852 DEBUG mmfunctions.anomaly.execute Epoch: 760, Loss: 0.5143701434135437
# 2020-12-22T14:10:17.249 DEBUG mmfunctions.anomaly.execute Epoch: 770, Loss: 0.5141509175300598
# 2020-12-22T14:10:27.786 DEBUG mmfunctions.anomaly.execute Epoch: 780, Loss: 0.5143022537231445
# 2020-12-22T14:10:38.410 DEBUG mmfunctions.anomaly.execute Epoch: 790, Loss: 0.5142222046852112
# 2020-12-22T14:10:49.238 DEBUG mmfunctions.anomaly.execute Epoch: 800, Loss: 0.5146180987358093
# 2020-12-22T14:11:00.254 DEBUG mmfunctions.anomaly.execute Epoch: 810, Loss: 0.5139776468276978
# 2020-12-22T14:11:11.208 DEBUG mmfunctions.anomaly.execute Epoch: 820, Loss: 0.5138651728630066
# 2020-12-22T14:11:22.086 DEBUG mmfunctions.anomaly.execute Epoch: 830, Loss: 0.5135164260864258
# 2020-12-22T14:11:32.951 DEBUG mmfunctions.anomaly.execute Epoch: 840, Loss: 0.5155550241470337
# 2020-12-22T14:11:44.073 DEBUG mmfunctions.anomaly.execute Epoch: 850, Loss: 0.5142265558242798
# 2020-12-22T14:11:55.120 DEBUG mmfunctions.anomaly.execute Epoch: 860, Loss: 0.5138198137283325
# 2020-12-22T14:12:05.962 DEBUG mmfunctions.anomaly.execute Epoch: 870, Loss: 0.5144504308700562
# 2020-12-22T14:12:16.919 DEBUG mmfunctions.anomaly.execute Epoch: 880, Loss: 0.5146055221557617
# 2020-12-22T14:12:28.016 DEBUG mmfunctions.anomaly.execute Epoch: 890, Loss: 0.5149950981140137
# 2020-12-22T14:12:39.038 DEBUG mmfunctions.anomaly.execute Epoch: 900, Loss: 0.5134389996528625
# 2020-12-22T14:12:50.154 DEBUG mmfunctions.anomaly.execute Epoch: 910, Loss: 0.5146349668502808
# 2020-12-22T14:13:01.462 DEBUG mmfunctions.anomaly.execute Epoch: 920, Loss: 0.5140714049339294
# 2020-12-22T14:13:12.553 DEBUG mmfunctions.anomaly.execute Epoch: 930, Loss: 0.513556957244873
# 2020-12-22T14:13:23.657 DEBUG mmfunctions.anomaly.execute Epoch: 940, Loss: 0.5141644477844238
# 2020-12-22T14:13:34.755 DEBUG mmfunctions.anomaly.execute Epoch: 950, Loss: 0.5147133469581604
# 2020-12-22T14:13:45.849 DEBUG mmfunctions.anomaly.execute Epoch: 960, Loss: 0.5143046975135803
# 2020-12-22T14:13:56.907 DEBUG mmfunctions.anomaly.execute Epoch: 970, Loss: 0.5137965083122253
# 2020-12-22T14:14:07.925 DEBUG mmfunctions.anomaly.execute Epoch: 980, Loss: 0.5133213996887207
# 2020-12-22T14:14:18.996 DEBUG mmfunctions.anomaly.execute Epoch: 990, Loss: 0.5144398808479309
# 2020-12-22T14:14:29.859 DEBUG mmfunctions.anomaly.execute Epoch: 1000, Loss: 0.5143953561782837
# 2020-12-22T14:14:40.803 DEBUG mmfunctions.anomaly.execute Epoch: 1010, Loss: 0.5149785280227661
# 2020-12-22T14:14:51.799 DEBUG mmfunctions.anomaly.execute Epoch: 1020, Loss: 0.5142021775245667
# 2020-12-22T14:15:02.932 DEBUG mmfunctions.anomaly.execute Epoch: 1030, Loss: 0.5147781372070312
# 2020-12-22T14:15:13.969 DEBUG mmfunctions.anomaly.execute Epoch: 1040, Loss: 0.5149414539337158
# 2020-12-22T14:15:24.995 DEBUG mmfunctions.anomaly.execute Epoch: 1050, Loss: 0.5148706436157227
# 2020-12-22T14:15:36.048 DEBUG mmfunctions.anomaly.execute Epoch: 1060, Loss: 0.5148179531097412
# 2020-12-22T14:15:47.303 DEBUG mmfunctions.anomaly.execute Epoch: 1070, Loss: 0.5138766765594482
# 2020-12-22T14:15:58.392 DEBUG mmfunctions.anomaly.execute Epoch: 1080, Loss: 0.5141459107398987
# 2020-12-22T14:16:09.395 DEBUG mmfunctions.anomaly.execute Epoch: 1090, Loss: 0.5145758390426636
# 2020-12-22T14:16:20.458 DEBUG mmfunctions.anomaly.execute Epoch: 1100, Loss: 0.5150577425956726
# 2020-12-22T14:16:31.653 DEBUG mmfunctions.anomaly.execute Epoch: 1110, Loss: 0.5130228400230408
# 2020-12-22T14:16:42.898 DEBUG mmfunctions.anomaly.execute Epoch: 1120, Loss: 0.5149590969085693
# 2020-12-22T14:16:53.885 DEBUG mmfunctions.anomaly.execute Epoch: 1130, Loss: 0.5144556164741516
# 2020-12-22T14:17:04.967 DEBUG mmfunctions.anomaly.execute Epoch: 1140, Loss: 0.5144173502922058
# 2020-12-22T14:17:16.056 DEBUG mmfunctions.anomaly.execute Epoch: 1150, Loss: 0.5134467482566833
# 2020-12-22T14:17:27.178 DEBUG mmfunctions.anomaly.execute Epoch: 1160, Loss: 0.514385998249054
# 2020-12-22T14:17:38.269 DEBUG mmfunctions.anomaly.execute Epoch: 1170, Loss: 0.5140436291694641
# 2020-12-22T14:17:49.507 DEBUG mmfunctions.anomaly.execute Epoch: 1180, Loss: 0.5149255990982056
# 2020-12-22T14:18:00.623 DEBUG mmfunctions.anomaly.execute Epoch: 1190, Loss: 0.5143675804138184
# 2020-12-22T14:18:11.658 DEBUG mmfunctions.anomaly.execute Epoch: 1200, Loss: 0.5145463347434998
# 2020-12-22T14:18:22.687 DEBUG mmfunctions.anomaly.execute Epoch: 1210, Loss: 0.5148018598556519
# 2020-12-22T14:18:33.756 DEBUG mmfunctions.anomaly.execute Epoch: 1220, Loss: 0.51361083984375
# 2020-12-22T14:18:44.918 DEBUG mmfunctions.anomaly.execute Epoch: 1230, Loss: 0.5146350860595703
# 2020-12-22T14:18:55.906 DEBUG mmfunctions.anomaly.execute Epoch: 1240, Loss: 0.5146235227584839
# 2020-12-22T14:19:07.103 DEBUG mmfunctions.anomaly.execute Epoch: 1250, Loss: 0.5154386162757874
# 2020-12-22T14:19:18.151 DEBUG mmfunctions.anomaly.execute Epoch: 1260, Loss: 0.5131248235702515
# 2020-12-22T14:19:29.191 DEBUG mmfunctions.anomaly.execute Epoch: 1270, Loss: 0.5137571692466736
# 2020-12-22T14:19:40.291 DEBUG mmfunctions.anomaly.execute Epoch: 1280, Loss: 0.5144015550613403
# 2020-12-22T14:19:51.426 DEBUG mmfunctions.anomaly.execute Epoch: 1290, Loss: 0.5150455832481384
# 2020-12-22T14:20:02.474 DEBUG mmfunctions.anomaly.execute Epoch: 1300, Loss: 0.5150640606880188
# 2020-12-22T14:20:13.698 DEBUG mmfunctions.anomaly.execute Epoch: 1310, Loss: 0.5138633847236633
# 2020-12-22T14:20:24.754 DEBUG mmfunctions.anomaly.execute Epoch: 1320, Loss: 0.5143010020256042
# 2020-12-22T14:20:35.925 DEBUG mmfunctions.anomaly.execute Epoch: 1330, Loss: 0.5139129757881165
# 2020-12-22T14:20:47.151 DEBUG mmfunctions.anomaly.execute Epoch: 1340, Loss: 0.513812243938446
# 2020-12-22T14:20:58.316 DEBUG mmfunctions.anomaly.execute Epoch: 1350, Loss: 0.5140603184700012
# 2020-12-22T14:21:09.781 DEBUG mmfunctions.anomaly.execute Epoch: 1360, Loss: 0.5139245986938477
# 2020-12-22T14:21:20.931 DEBUG mmfunctions.anomaly.execute Epoch: 1370, Loss: 0.5143417716026306
# 2020-12-22T14:21:32.036 DEBUG mmfunctions.anomaly.execute Epoch: 1380, Loss: 0.5143312811851501
# 2020-12-22T14:21:43.320 DEBUG mmfunctions.anomaly.execute Epoch: 1390, Loss: 0.5150663256645203
# 2020-12-22T14:21:54.519 DEBUG mmfunctions.anomaly.execute Epoch: 1400, Loss: 0.5134438872337341
# 2020-12-22T14:22:05.661 DEBUG mmfunctions.anomaly.execute Epoch: 1410, Loss: 0.5146374106407166
# 2020-12-22T14:22:16.888 DEBUG mmfunctions.anomaly.execute Epoch: 1420, Loss: 0.5138710737228394
# 2020-12-22T14:22:28.274 DEBUG mmfunctions.anomaly.execute Epoch: 1430, Loss: 0.5140697956085205
# 2020-12-22T14:22:39.539 DEBUG mmfunctions.anomaly.execute Epoch: 1440, Loss: 0.5143080353736877
# 2020-12-22T14:22:50.828 DEBUG mmfunctions.anomaly.execute Epoch: 1450, Loss: 0.5147854089736938
# 2020-12-22T14:23:02.188 DEBUG mmfunctions.anomaly.execute Epoch: 1460, Loss: 0.513729989528656
# 2020-12-22T14:23:13.125 DEBUG mmfunctions.anomaly.execute Epoch: 1470, Loss: 0.5134919285774231
# 2020-12-22T14:23:24.424 DEBUG mmfunctions.anomaly.execute Epoch: 1480, Loss: 0.5124624967575073
# 2020-12-22T14:23:35.644 DEBUG mmfunctions.anomaly.execute Epoch: 1490, Loss: 0.5135117769241333
# 2020-12-22T14:23:46.644 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# <ipython-input-17-bb9e9a5bbb29>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   get_ipython().run_cell_magic('time', '', "print('Train and evaluate model for ' + df_i2.index.levels[0].values[0])\n# Now run the anomaly functions as if they were executed in a pipeline\nEngineLogging.configure_console_logging(logging.DEBUG)\njobsettings = { 'db': db, \n               '_db_schema': 'public', 'save_trace_to_file' : True}\n\nspsi2 = VIAnomalyScore(['Ap'], ['Vx'])\net = spsi2._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)\nspsi2._entity_type = et\nspsi2.epochs = 300   # 1500 takes ages\ndf_i2 = spsi.execute(df=df_i2)\n\nEngineLogging.configure_console_logging(logging.INFO)\ndf_i2.describe()\n")
# CPU times: user 1h 59min 6s, sys: 30min 21s, total: 2h 29min 27s
# Wall time: 26min 37s
#                  Ap            Vx  predicted_Vx   pred_dev_Vx
# count  1.371300e+06  1.371300e+06  1.371300e+06  1.371300e+06
# mean   1.501744e+00 -2.946143e-02 -2.734308e-02  4.044737e-01
# std    1.482848e+00  1.308858e-01  1.372179e-03  2.715333e-01
# min    0.000000e+00 -1.039100e+00 -3.356946e-02  1.361498e-01
# 25%    0.000000e+00 -4.390000e-02 -2.845207e-02  1.361498e-01
# 50%    1.281000e+00 -2.730000e-02 -2.845207e-02  2.858738e-01
# 75%    3.099000e+00 -8.800000e-03 -2.569535e-02  6.752676e-01
# max    3.780000e+00  1.035200e+00 -1.292527e-03  8.986392e-01

# %%
entity = df_i2.index.levels[0].values[0]

df_1 = df_i2.loc[entity].copy()


arr1 = np.where(df_1['Vx'] > df_1['predicted_Vx'] + df_1['pred_dev_Vx'], df_1['Vx'], 0) + \
       np.where(df_1['Vx'] < df_1['predicted_Vx'] - df_1['pred_dev_Vx'], df_1['Vx'], 0)
arr1[arr1 == 0] = np.nan
df_1['Anomaly'] = arr1

fig, ax = plt.subplots(1, 2, figsize=(20, 6), squeeze=False)

ax[0,0].scatter(df_1['Ap'], df_1['Vx'])
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'], color='green')
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'] - df_1['pred_dev_Vx'], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'] + df_1['pred_dev_Vx'], color='orange', lw=0.1)
ax[0,0].scatter(df_1['Ap'], df_1['Anomaly'], color='red', lw=2)
ax[0,0].set_xlabel('Speed')
ax[0,0].set_ylabel('Vibration')
ax[0,0].legend()
ax[0,0].set_title('pump ' + entity)

ax[0,1].scatter(df_i2['Ap'], df_i2['Vx'])
ax[0,1].set_xlabel('Speed')
ax[0,1].set_ylabel('Vibration')
ax[0,1].legend()
ax[0,1].set_title('pump ' + entity + ' - plain scatterplot')
# Out:
# 2020-12-22T14:50:14.011 WARNING matplotlib.legend._parse_legend_args No handles with labels found to put in legend.
# Text(0.5, 1.0, 'pump 04714B603408 - plain scatterplot')

# %%
df_1[df_1['Ap'] < 2.0]['Anomaly'] = np.nan
df_1[np.abs(df_1['Vx']) < 0.7]['Anomaly'] = np.nan
# Out:
# <ipython-input-27-11cbb9c58f70>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[df_1['Ap'] < 2.0]['Anomaly'] = np.nan
# <ipython-input-27-11cbb9c58f70>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[np.abs(df_1['Vx']) < 0.7]['Anomaly'] = np.nan

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)
#ax[0,0].plot(df_1['max'] + 2.0, lw=0.4, color='blue', label='smoothed max vib + 1')
ax[0,0].scatter(df_1.index,df_1['Vx'], lw=0.4, color='green', label='vibration')
ax[0,0].scatter(df_1.index,df_1['Ap']/3, lw=0.4, color='orange', zorder=5, label='accel speed')
ax[0,0].scatter(df_1.index, df_1['Anomaly'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i2.index.levels[0].values[0])
# Out:
# Text(0.5, 1.0, 'pump 04714B603408')

# %%
df_clean3 = prep_data_short(load_data_short('./04714B6036B1.csv'))
df_clean3.head(2)
df_clean3.index.levels[0].values[0]
# Out:
# '04714B6036B1'

# %%
plt.figure(figsize=(16, 6))
g = sns.displot(df_clean3[['Ap','Vx']], x='Ap', y='Vx', kind="kde", rug=True)
    
g.set_titles('KDE for' + df_clean3.index.levels[0].values[0])

# %%
df_i3 = df_clean3.copy()

# %%
# %%time
print('Train and evaluate model for ' + df_i3.index.levels[0].values[0])
# Now run the anomaly functions as if they were executed in a pipeline
EngineLogging.configure_console_logging(logging.DEBUG)
jobsettings = { 'db': db, 
               '_db_schema': 'public', 'save_trace_to_file' : True}

spsi3 = VIAnomalyScore(['Ap'], ['Vx'])
et = spsi3._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)
spsi3._entity_type = et
df_i3 = spsi.execute(df=df_i3)

EngineLogging.configure_console_logging(logging.INFO)
df_i3.describe()
# Out:
# Train and evaluate model for 04714B6036B1
# 2020-12-22T15:50:44.327 DEBUG iotfunctions.enginelog.configure_console_logging Console logging has been configured. Level = 10
# 2020-12-22T15:50:44.328 DEBUG mmfunctions.anomaly.__init__ init KDE Estimator
# 2020-12-22T15:50:44.328 DEBUG iotfunctions.metadata.__init__ Initializing new entity type using iotfunctions 8.2.1
# 2020-12-22T15:50:44.329 DEBUG iotfunctions.util.__init__ Starting trace
# 2020-12-22T15:50:44.330 DEBUG iotfunctions.util.__init__ Trace name: auto_trace_test_entity_for_VIAnomalyScore_20201222145044
# 2020-12-22T15:50:44.330 DEBUG iotfunctions.util.__init__ auto_save None
# 2020-12-22T15:50:44.331 DEBUG iotfunctions.util.categorize_args categorizing arguments
# 2020-12-22T15:50:44.331 WARNING iotfunctions.metadata.__init__ Created a logical entity type. It is not connected to a real database table, so it cannot perform any database operations.
# 2020-12-22T15:50:44.332 DEBUG iotfunctions.metadata.__init__ Initialized entity type
# LocalEntityType:TEST_ENTITY_FOR_VIANOMALYSCORE
# Functions:
# Granularities:
# No schedules metadata
# Here 1 <class 'pandas.core.frame.DataFrame'>
# 2020-12-22T15:50:44.338 DEBUG mmfunctions.anomaly.execute ['04714B6036B1']
# ['Ap']
# 2020-12-22T15:50:44.552 INFO iotfunctions.dbtables.retrieve_model Model model.TEST_ENTITY_FOR_VIANOMALYSCORE.VIAnomalyScore.Vx.04714B6036B1 does not exist in filesystem
# 2020-12-22T15:50:44.552 INFO mmfunctions.anomaly.execute load model None
# 2020-12-22T15:50:45.588 DEBUG mmfunctions.anomaly.execute Epoch: 0, Loss: 0.8325163125991821
# 2020-12-22T15:50:56.103 DEBUG mmfunctions.anomaly.execute Epoch: 10, Loss: 0.5652421712875366
# 2020-12-22T15:51:06.955 DEBUG mmfunctions.anomaly.execute Epoch: 20, Loss: 0.5153636932373047
# 2020-12-22T15:51:17.711 DEBUG mmfunctions.anomaly.execute Epoch: 30, Loss: 0.4913690984249115
# 2020-12-22T15:51:28.383 DEBUG mmfunctions.anomaly.execute Epoch: 40, Loss: 0.4863063097000122
# 2020-12-22T15:51:38.963 DEBUG mmfunctions.anomaly.execute Epoch: 50, Loss: 0.4872589111328125
# 2020-12-22T15:51:49.619 DEBUG mmfunctions.anomaly.execute Epoch: 60, Loss: 0.486362099647522
# 2020-12-22T15:51:59.948 DEBUG mmfunctions.anomaly.execute Epoch: 70, Loss: 0.48674455285072327
# 2020-12-22T15:52:10.797 DEBUG mmfunctions.anomaly.execute Epoch: 80, Loss: 0.48609670996665955
# 2020-12-22T15:52:21.633 DEBUG mmfunctions.anomaly.execute Epoch: 90, Loss: 0.48684075474739075
# 2020-12-22T15:52:32.288 DEBUG mmfunctions.anomaly.execute Epoch: 100, Loss: 0.48644647002220154
# 2020-12-22T15:52:43.031 DEBUG mmfunctions.anomaly.execute Epoch: 110, Loss: 0.4854465425014496
# 2020-12-22T15:52:53.978 DEBUG mmfunctions.anomaly.execute Epoch: 120, Loss: 0.48618194460868835
# 2020-12-22T15:53:04.776 DEBUG mmfunctions.anomaly.execute Epoch: 130, Loss: 0.4873572289943695
# 2020-12-22T15:53:15.521 DEBUG mmfunctions.anomaly.execute Epoch: 140, Loss: 0.4859188497066498
# 2020-12-22T15:53:26.247 DEBUG mmfunctions.anomaly.execute Epoch: 150, Loss: 0.48691684007644653
# 2020-12-22T15:53:37.112 DEBUG mmfunctions.anomaly.execute Epoch: 160, Loss: 0.4861513674259186
# 2020-12-22T15:53:48.188 DEBUG mmfunctions.anomaly.execute Epoch: 170, Loss: 0.48652270436286926
# 2020-12-22T15:53:58.871 DEBUG mmfunctions.anomaly.execute Epoch: 180, Loss: 0.4864473342895508
# 2020-12-22T15:54:09.567 DEBUG mmfunctions.anomaly.execute Epoch: 190, Loss: 0.4863928258419037
# 2020-12-22T15:54:20.527 DEBUG mmfunctions.anomaly.execute Epoch: 200, Loss: 0.48636096715927124
# 2020-12-22T15:54:31.252 DEBUG mmfunctions.anomaly.execute Epoch: 210, Loss: 0.48703843355178833
# 2020-12-22T15:54:42.669 DEBUG mmfunctions.anomaly.execute Epoch: 220, Loss: 0.48699185252189636
# 2020-12-22T15:54:53.437 DEBUG mmfunctions.anomaly.execute Epoch: 230, Loss: 0.4859136939048767
# 2020-12-22T15:55:04.288 DEBUG mmfunctions.anomaly.execute Epoch: 240, Loss: 0.4861014187335968
# 2020-12-22T15:55:15.210 DEBUG mmfunctions.anomaly.execute Epoch: 250, Loss: 0.48731422424316406
# 2020-12-22T15:55:26.216 DEBUG mmfunctions.anomaly.execute Epoch: 260, Loss: 0.48592686653137207
# 2020-12-22T15:55:39.288 DEBUG mmfunctions.anomaly.execute Epoch: 270, Loss: 0.48709630966186523
# 2020-12-22T15:55:50.662 DEBUG mmfunctions.anomaly.execute Epoch: 280, Loss: 0.4863559305667877
# 2020-12-22T15:56:01.874 DEBUG mmfunctions.anomaly.execute Epoch: 290, Loss: 0.4861152470111847
# 2020-12-22T15:56:13.266 DEBUG mmfunctions.anomaly.execute Epoch: 300, Loss: 0.4857954978942871
# 2020-12-22T15:56:24.917 DEBUG mmfunctions.anomaly.execute Epoch: 310, Loss: 0.48659488558769226
# 2020-12-22T15:56:38.002 DEBUG mmfunctions.anomaly.execute Epoch: 320, Loss: 0.486554354429245
# 2020-12-22T15:56:50.738 DEBUG mmfunctions.anomaly.execute Epoch: 330, Loss: 0.4864659309387207
# 2020-12-22T15:57:04.072 DEBUG mmfunctions.anomaly.execute Epoch: 340, Loss: 0.48656079173088074
# 2020-12-22T15:57:16.402 DEBUG mmfunctions.anomaly.execute Epoch: 350, Loss: 0.4858933687210083
# 2020-12-22T15:57:28.602 DEBUG mmfunctions.anomaly.execute Epoch: 360, Loss: 0.48608890175819397
# 2020-12-22T15:57:40.958 DEBUG mmfunctions.anomaly.execute Epoch: 370, Loss: 0.4864509105682373
# 2020-12-22T15:57:56.109 DEBUG mmfunctions.anomaly.execute Epoch: 380, Loss: 0.48563650250434875
# 2020-12-22T15:58:11.466 DEBUG mmfunctions.anomaly.execute Epoch: 390, Loss: 0.48714694380760193
# 2020-12-22T15:58:32.321 DEBUG mmfunctions.anomaly.execute Epoch: 400, Loss: 0.487199604511261
# 2020-12-22T15:58:56.036 DEBUG mmfunctions.anomaly.execute Epoch: 410, Loss: 0.4866694509983063
# 2020-12-22T15:59:17.196 DEBUG mmfunctions.anomaly.execute Epoch: 420, Loss: 0.4864768385887146
# 2020-12-22T15:59:36.088 DEBUG mmfunctions.anomaly.execute Epoch: 430, Loss: 0.4860832095146179
# 2020-12-22T15:59:55.002 DEBUG mmfunctions.anomaly.execute Epoch: 440, Loss: 0.4863526523113251
# 2020-12-22T16:00:11.835 DEBUG mmfunctions.anomaly.execute Epoch: 450, Loss: 0.48591163754463196
# 2020-12-22T16:00:29.052 DEBUG mmfunctions.anomaly.execute Epoch: 460, Loss: 0.48736992478370667
# 2020-12-22T16:00:46.637 DEBUG mmfunctions.anomaly.execute Epoch: 470, Loss: 0.486917644739151
# 2020-12-22T16:01:04.056 DEBUG mmfunctions.anomaly.execute Epoch: 480, Loss: 0.48650404810905457
# 2020-12-22T16:01:23.137 DEBUG mmfunctions.anomaly.execute Epoch: 490, Loss: 0.48635298013687134
# 2020-12-22T16:01:40.722 DEBUG mmfunctions.anomaly.execute Epoch: 500, Loss: 0.4861403703689575
# 2020-12-22T16:01:59.116 DEBUG mmfunctions.anomaly.execute Epoch: 510, Loss: 0.48623207211494446
# 2020-12-22T16:02:18.820 DEBUG mmfunctions.anomaly.execute Epoch: 520, Loss: 0.4860113859176636
# 2020-12-22T16:02:36.960 DEBUG mmfunctions.anomaly.execute Epoch: 530, Loss: 0.4870612919330597
# 2020-12-22T16:02:56.152 DEBUG mmfunctions.anomaly.execute Epoch: 540, Loss: 0.4864642918109894
# 2020-12-22T16:03:14.533 DEBUG mmfunctions.anomaly.execute Epoch: 550, Loss: 0.4874727129936218
# 2020-12-22T16:03:34.348 DEBUG mmfunctions.anomaly.execute Epoch: 560, Loss: 0.48634791374206543
# 2020-12-22T16:03:53.736 DEBUG mmfunctions.anomaly.execute Epoch: 570, Loss: 0.48615625500679016
# 2020-12-22T16:04:14.594 DEBUG mmfunctions.anomaly.execute Epoch: 580, Loss: 0.48614296317100525
# 2020-12-22T16:04:36.694 DEBUG mmfunctions.anomaly.execute Epoch: 590, Loss: 0.48542025685310364
# 2020-12-22T16:04:54.580 DEBUG mmfunctions.anomaly.execute Epoch: 600, Loss: 0.4853813946247101
# 2020-12-22T16:05:13.723 DEBUG mmfunctions.anomaly.execute Epoch: 610, Loss: 0.4863088130950928
# 2020-12-22T16:05:34.084 DEBUG mmfunctions.anomaly.execute Epoch: 620, Loss: 0.4867885112762451
# 2020-12-22T16:05:58.037 DEBUG mmfunctions.anomaly.execute Epoch: 630, Loss: 0.4858531951904297
# 2020-12-22T16:06:19.762 DEBUG mmfunctions.anomaly.execute Epoch: 640, Loss: 0.48698464035987854
# 2020-12-22T16:06:37.212 DEBUG mmfunctions.anomaly.execute Epoch: 650, Loss: 0.48672446608543396
# 2020-12-22T16:06:55.175 DEBUG mmfunctions.anomaly.execute Epoch: 660, Loss: 0.4864636957645416
# 2020-12-22T16:07:12.830 DEBUG mmfunctions.anomaly.execute Epoch: 670, Loss: 0.48536059260368347
# 2020-12-22T16:07:33.552 DEBUG mmfunctions.anomaly.execute Epoch: 680, Loss: 0.4857752025127411
# 2020-12-22T16:07:54.241 DEBUG mmfunctions.anomaly.execute Epoch: 690, Loss: 0.48669639229774475
# 2020-12-22T16:08:10.764 DEBUG mmfunctions.anomaly.execute Epoch: 700, Loss: 0.4875572919845581
# 2020-12-22T16:08:27.718 DEBUG mmfunctions.anomaly.execute Epoch: 710, Loss: 0.4861690402030945
# 2020-12-22T16:08:48.223 DEBUG mmfunctions.anomaly.execute Epoch: 720, Loss: 0.4854114055633545
# 2020-12-22T16:09:10.729 DEBUG mmfunctions.anomaly.execute Epoch: 730, Loss: 0.48605582118034363
# 2020-12-22T16:09:31.181 DEBUG mmfunctions.anomaly.execute Epoch: 740, Loss: 0.48728975653648376
# 2020-12-22T16:09:41.966 DEBUG mmfunctions.anomaly.execute Epoch: 750, Loss: 0.4858241081237793
# 2020-12-22T16:09:52.462 DEBUG mmfunctions.anomaly.execute Epoch: 760, Loss: 0.4855801463127136
# 2020-12-22T16:10:02.648 DEBUG mmfunctions.anomaly.execute Epoch: 770, Loss: 0.48650646209716797
# 2020-12-22T16:10:13.460 DEBUG mmfunctions.anomaly.execute Epoch: 780, Loss: 0.4863134026527405
# 2020-12-22T16:10:24.221 DEBUG mmfunctions.anomaly.execute Epoch: 790, Loss: 0.48651033639907837
# 2020-12-22T16:10:34.580 DEBUG mmfunctions.anomaly.execute Epoch: 800, Loss: 0.48592084646224976
# 2020-12-22T16:10:45.270 DEBUG mmfunctions.anomaly.execute Epoch: 810, Loss: 0.4858454465866089
# 2020-12-22T16:10:55.837 DEBUG mmfunctions.anomaly.execute Epoch: 820, Loss: 0.4861123859882355
# 2020-12-22T16:11:07.126 DEBUG mmfunctions.anomaly.execute Epoch: 830, Loss: 0.48574298620224
# 2020-12-22T16:11:17.557 DEBUG mmfunctions.anomaly.execute Epoch: 840, Loss: 0.48601198196411133
# 2020-12-22T16:11:28.256 DEBUG mmfunctions.anomaly.execute Epoch: 850, Loss: 0.48634594678878784
# 2020-12-22T16:11:38.814 DEBUG mmfunctions.anomaly.execute Epoch: 860, Loss: 0.4857790172100067
# 2020-12-22T16:11:49.332 DEBUG mmfunctions.anomaly.execute Epoch: 870, Loss: 0.4871848523616791
# 2020-12-22T16:11:59.930 DEBUG mmfunctions.anomaly.execute Epoch: 880, Loss: 0.4860883057117462
# 2020-12-22T16:12:11.145 DEBUG mmfunctions.anomaly.execute Epoch: 890, Loss: 0.48607900738716125
# 2020-12-22T16:12:21.549 DEBUG mmfunctions.anomaly.execute Epoch: 900, Loss: 0.4859886169433594
# 2020-12-22T16:12:32.143 DEBUG mmfunctions.anomaly.execute Epoch: 910, Loss: 0.48615342378616333
# 2020-12-22T16:12:42.831 DEBUG mmfunctions.anomaly.execute Epoch: 920, Loss: 0.48666912317276
# 2020-12-22T16:12:54.207 DEBUG mmfunctions.anomaly.execute Epoch: 930, Loss: 0.4866842031478882
# 2020-12-22T16:13:05.347 DEBUG mmfunctions.anomaly.execute Epoch: 940, Loss: 0.4850946366786957
# 2020-12-22T16:13:16.280 DEBUG mmfunctions.anomaly.execute Epoch: 950, Loss: 0.48710891604423523
# 2020-12-22T16:13:27.371 DEBUG mmfunctions.anomaly.execute Epoch: 960, Loss: 0.486395925283432
# 2020-12-22T16:13:38.240 DEBUG mmfunctions.anomaly.execute Epoch: 970, Loss: 0.48582524061203003
# 2020-12-22T16:13:49.514 DEBUG mmfunctions.anomaly.execute Epoch: 980, Loss: 0.4864894449710846
# 2020-12-22T16:14:00.490 DEBUG mmfunctions.anomaly.execute Epoch: 990, Loss: 0.48681971430778503
# 2020-12-22T16:14:12.278 DEBUG mmfunctions.anomaly.execute Epoch: 1000, Loss: 0.4864182472229004
# 2020-12-22T16:14:23.575 DEBUG mmfunctions.anomaly.execute Epoch: 1010, Loss: 0.487104594707489
# 2020-12-22T16:14:34.735 DEBUG mmfunctions.anomaly.execute Epoch: 1020, Loss: 0.48670080304145813
# 2020-12-22T16:14:46.180 DEBUG mmfunctions.anomaly.execute Epoch: 1030, Loss: 0.4866601526737213
# 2020-12-22T16:14:58.478 DEBUG mmfunctions.anomaly.execute Epoch: 1040, Loss: 0.48662593960762024
# 2020-12-22T16:15:09.799 DEBUG mmfunctions.anomaly.execute Epoch: 1050, Loss: 0.4856388568878174
# 2020-12-22T16:15:20.386 DEBUG mmfunctions.anomaly.execute Epoch: 1060, Loss: 0.48538678884506226
# 2020-12-22T16:15:30.865 DEBUG mmfunctions.anomaly.execute Epoch: 1070, Loss: 0.48568153381347656
# 2020-12-22T16:15:41.711 DEBUG mmfunctions.anomaly.execute Epoch: 1080, Loss: 0.4858759641647339
# 2020-12-22T16:15:52.250 DEBUG mmfunctions.anomaly.execute Epoch: 1090, Loss: 0.4856809377670288
# 2020-12-22T16:16:03.035 DEBUG mmfunctions.anomaly.execute Epoch: 1100, Loss: 0.48627591133117676
# 2020-12-22T16:16:14.084 DEBUG mmfunctions.anomaly.execute Epoch: 1110, Loss: 0.4862355887889862
# 2020-12-22T16:16:25.733 DEBUG mmfunctions.anomaly.execute Epoch: 1120, Loss: 0.48609238862991333
# 2020-12-22T16:16:36.640 DEBUG mmfunctions.anomaly.execute Epoch: 1130, Loss: 0.4869769811630249
# 2020-12-22T16:16:47.439 DEBUG mmfunctions.anomaly.execute Epoch: 1140, Loss: 0.4861745238304138
# 2020-12-22T16:16:58.072 DEBUG mmfunctions.anomaly.execute Epoch: 1150, Loss: 0.486310750246048
# 2020-12-22T16:17:09.259 DEBUG mmfunctions.anomaly.execute Epoch: 1160, Loss: 0.48594656586647034
# 2020-12-22T16:17:20.027 DEBUG mmfunctions.anomaly.execute Epoch: 1170, Loss: 0.4859270751476288
# 2020-12-22T16:17:30.787 DEBUG mmfunctions.anomaly.execute Epoch: 1180, Loss: 0.48596322536468506
# 2020-12-22T16:17:41.901 DEBUG mmfunctions.anomaly.execute Epoch: 1190, Loss: 0.4862907826900482
# 2020-12-22T16:17:53.092 DEBUG mmfunctions.anomaly.execute Epoch: 1200, Loss: 0.4856567978858948
# 2020-12-22T16:18:05.058 DEBUG mmfunctions.anomaly.execute Epoch: 1210, Loss: 0.4859086275100708
# 2020-12-22T16:18:17.537 DEBUG mmfunctions.anomaly.execute Epoch: 1220, Loss: 0.48617538809776306
# 2020-12-22T16:18:30.283 DEBUG mmfunctions.anomaly.execute Epoch: 1230, Loss: 0.4870046377182007
# 2020-12-22T16:18:42.879 DEBUG mmfunctions.anomaly.execute Epoch: 1240, Loss: 0.48572883009910583
# 2020-12-22T16:18:55.700 DEBUG mmfunctions.anomaly.execute Epoch: 1250, Loss: 0.48631376028060913
# 2020-12-22T16:19:08.318 DEBUG mmfunctions.anomaly.execute Epoch: 1260, Loss: 0.4862262010574341
# 2020-12-22T16:19:21.067 DEBUG mmfunctions.anomaly.execute Epoch: 1270, Loss: 0.4854844808578491
# 2020-12-22T16:19:33.953 DEBUG mmfunctions.anomaly.execute Epoch: 1280, Loss: 0.48578497767448425
# 2020-12-22T16:19:48.351 DEBUG mmfunctions.anomaly.execute Epoch: 1290, Loss: 0.485117107629776
# 2020-12-22T16:20:03.213 DEBUG mmfunctions.anomaly.execute Epoch: 1300, Loss: 0.4853770136833191
# 2020-12-22T16:20:19.919 DEBUG mmfunctions.anomaly.execute Epoch: 1310, Loss: 0.4856608510017395
# 2020-12-22T16:20:38.667 DEBUG mmfunctions.anomaly.execute Epoch: 1320, Loss: 0.48569896817207336
# 2020-12-22T16:20:55.478 DEBUG mmfunctions.anomaly.execute Epoch: 1330, Loss: 0.48554328083992004
# 2020-12-22T16:21:13.278 DEBUG mmfunctions.anomaly.execute Epoch: 1340, Loss: 0.4855981767177582
# 2020-12-22T16:21:30.950 DEBUG mmfunctions.anomaly.execute Epoch: 1350, Loss: 0.48531609773635864
# 2020-12-22T16:21:49.096 DEBUG mmfunctions.anomaly.execute Epoch: 1360, Loss: 0.48670801520347595
# 2020-12-22T16:22:05.546 DEBUG mmfunctions.anomaly.execute Epoch: 1370, Loss: 0.4852875769138336
# 2020-12-22T16:22:22.686 DEBUG mmfunctions.anomaly.execute Epoch: 1380, Loss: 0.4848087430000305
# 2020-12-22T16:22:39.363 DEBUG mmfunctions.anomaly.execute Epoch: 1390, Loss: 0.4856317639350891
# 2020-12-22T16:22:55.841 DEBUG mmfunctions.anomaly.execute Epoch: 1400, Loss: 0.4858027994632721
# 2020-12-22T16:23:12.857 DEBUG mmfunctions.anomaly.execute Epoch: 1410, Loss: 0.4848630726337433
# 2020-12-22T16:23:29.226 DEBUG mmfunctions.anomaly.execute Epoch: 1420, Loss: 0.4854389727115631
# 2020-12-22T16:23:45.377 DEBUG mmfunctions.anomaly.execute Epoch: 1430, Loss: 0.486282616853714
# 2020-12-22T16:24:01.841 DEBUG mmfunctions.anomaly.execute Epoch: 1440, Loss: 0.4853481650352478
# 2020-12-22T16:24:18.709 DEBUG mmfunctions.anomaly.execute Epoch: 1450, Loss: 0.48608991503715515
# 2020-12-22T16:24:35.701 DEBUG mmfunctions.anomaly.execute Epoch: 1460, Loss: 0.4854182004928589
# 2020-12-22T16:24:54.074 DEBUG mmfunctions.anomaly.execute Epoch: 1470, Loss: 0.48608341813087463
# 2020-12-22T16:25:11.277 DEBUG mmfunctions.anomaly.execute Epoch: 1480, Loss: 0.48522114753723145
# 2020-12-22T16:25:27.729 DEBUG mmfunctions.anomaly.execute Epoch: 1490, Loss: 0.4852508306503296
# 2020-12-22T16:25:44.498 DEBUG mmfunctions.anomaly.execute Created VAE VI(
#   (q_mu): Sequential(
#     (0): Linear(in_features=1, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
#   (q_log_var): Sequential(
#     (0): Linear(in_features=1, out_features=50, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=50, out_features=35, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=35, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )
# <ipython-input-32-c9f26aead716>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   get_ipython().run_cell_magic('time', '', "print('Train and evaluate model for ' + df_i3.index.levels[0].values[0])\n# Now run the anomaly functions as if they were executed in a pipeline\nEngineLogging.configure_console_logging(logging.DEBUG)\njobsettings = { 'db': db, \n               '_db_schema': 'public', 'save_trace_to_file' : True}\n\nspsi3 = VIAnomalyScore(['Ap'], ['Vx'])\net = spsi3._build_entity_type(columns = [Column('MinTemp',Float())], **jobsettings)\nspsi3._entity_type = et\ndf_i3 = spsi.execute(df=df_i3)\n\nEngineLogging.configure_console_logging(logging.INFO)\ndf_i3.describe()\n")
# CPU times: user 2h 33min 9s, sys: 41min 20s, total: 3h 14min 30s
# Wall time: 35min 1s
#                  Ap            Vx  predicted_Vx   pred_dev_Vx
# count  1.368975e+06  1.368975e+06  1.368975e+06  1.368975e+06
# mean   1.400429e+00  9.770501e-03  8.359868e-03  3.902670e-01
# std    1.396439e+00  8.449316e-02  2.403382e-03  1.797408e-01
# min    0.000000e+00 -9.580000e-01  6.013222e-03  2.128958e-01
# 25%    0.000000e+00 -1.370000e-02  6.013222e-03  2.128958e-01
# 50%    1.234000e+00  6.800000e-03  7.152006e-03  2.514825e-01
# 75%    3.099000e+00  2.930000e-02  1.133477e-02  5.796511e-01
# max    3.780000e+00  9.834000e-01  1.609729e-02  6.654118e-01

# %%
entity = df_i3.index.levels[0].values[0]

df_1 = df_i3.loc[entity].copy()


arr1 = np.where(df_1['Vx'] > df_1['predicted_Vx'] + df_1['pred_dev_Vx'], df_1['Vx'], 0) + \
       np.where(df_1['Vx'] < df_1['predicted_Vx'] - df_1['pred_dev_Vx'], df_1['Vx'], 0)
arr1[arr1 == 0] = np.nan
df_1['Anomaly'] = arr1

fig, ax = plt.subplots(1, 2, figsize=(20, 6), squeeze=False)

ax[0,0].scatter(df_1['Ap'], df_1['Vx'])
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'], color='green')
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'] - df_1['pred_dev_Vx'], color='orange', lw=0.1, label='limit - p<0.05')
ax[0,0].scatter(df_1['Ap'], df_1['predicted_Vx'] + df_1['pred_dev_Vx'], color='orange', lw=0.1)
ax[0,0].scatter(df_1['Ap'], df_1['Anomaly'], color='red', lw=2)
ax[0,0].set_xlabel('Accel Speed')
ax[0,0].set_ylabel('Vibration')
ax[0,0].legend()
ax[0,0].set_title('pump ' + entity)

ax[0,1].scatter(df_i3['Ap'], df_i3['Vx'])
ax[0,1].set_xlabel('Power')
ax[0,1].set_ylabel('Vibration')
ax[0,1].legend()
ax[0,1].set_title('pump ' + entity + ' - plain scatterplot')
# Out:
# 2020-12-22T16:26:02.429 WARNING matplotlib.legend._parse_legend_args No handles with labels found to put in legend.
# Text(0.5, 1.0, 'pump 04714B6036B1 - plain scatterplot')

# %%
df_1[df_1['Ap'] < 0.5]['Anomaly'] = np.nan
df_1[np.abs(df_1['Vx']) < 0.5]['Anomaly'] = np.nan
# Out:
# <ipython-input-34-dac41d32ec2f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[df_1['Ap'] < 0.5]['Anomaly'] = np.nan
# <ipython-input-34-dac41d32ec2f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1[np.abs(df_1['Vx']) < 0.5]['Anomaly'] = np.nan

# %%
fig, ax = plt.subplots(1, 1, figsize=(15, 6), squeeze=False)
#ax[0,0].plot(df_1['max'] + 2.0, lw=0.4, color='blue', label='smoothed max vib + 1')
ax[0,0].scatter(df_1.index,df_1['Vx'], lw=0.4, color='green', label='vibration')
ax[0,0].scatter(df_1.index,df_1['Ap']/3, lw=0.4, color='orange', zorder=5, label='accel speed')
ax[0,0].scatter(df_1.index, df_1['Anomaly'], lw=0.4, color='red', zorder=10, label='excessive vibration')
ax[0,0].legend()
ax[0,0].set_title('pump ' + df_i3.index.levels[0].values[0])
# Out:
# Text(0.5, 1.0, 'pump 04714B6036B1')

# %% [markdown]
# #### Approximate with Gaussian
#
# major contribution: gaussian along x/y coordinates, start with diagonal covariance matrix:
#
# likelihood:
#
# $e^{\frac{ {(\mu_0 - x)}^2}{\sigma_0} \frac{ {(\mu_1 - y)}^2}{\sigma_1}  }$

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-29b13a3a01e9> in <module>
# ----> 1 import edward
#
# ~/src/mmfunctions/src/edward/edward/__init__.py in <module>
#       3 from __future__ import print_function
#       4
# ----> 5 from edward import criticisms
#       6 from edward import inferences
#       7 from edward import models
#
# ~/src/mmfunctions/src/edward/edward/criticisms/__init__.py in <module>
#       5 from __future__ import print_function
#       6
# ----> 7 from edward.criticisms.evaluate import *
#       8 from edward.criticisms.ppc import *
#       9 from edward.criticisms.ppc_plots import *
#
# ~/src/mmfunctions/src/edward/edward/criticisms/evaluate.py in <module>
#       7 import tensorflow as tf
#       8
# ----> 9 from edward.models import RandomVariable
#      10 from edward.util import check_data, get_session, compute_multinomial_mode, \
#      11     with_binary_averaging
#
# ~/src/mmfunctions/src/edward/edward/models/__init__.py in <module>
#       5 from __future__ import print_function
#       6
# ----> 7 from edward.models.dirichlet_process import *
#       8 from edward.models.empirical import *
#       9 from edward.models.param_mixture import *
#
# ~/src/mmfunctions/src/edward/edward/models/dirichlet_process.py in <module>
#       6
#       7 from edward.models.random_variable import RandomVariable
# ----> 8 from tensorflow.contrib.distributions import Distribution
#       9
#      10 try:
#
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
# theta_0, theta_1 = mu_0/mu_1, theta_2/theta_3 = sigma_0/ sigma_1
def log_likelihood(theta, F, e):
    
    
    return np.sum(theta[0]
        
        np.log(2 * np.pi * (theta[1] ** 2 + theta[2] ** 2))
                         + (theta[0]) ** 2 / (theta[1] ** 2 + theta[2] ** 2))



def log_prior(theta):
    # sigma needs to be positive.
    if theta[1] <= 0:
        return -np.inf
    else:
        return 0

def log_posterior(theta, F, e):
    return log_prior(theta) + log_likelihood(theta, F, e)

# same setup as above:
ndim, nwalkers = 2, 50
nsteps, nburn = 2000, 1000

starting_guesses = np.random.rand(nwalkers, ndim)
starting_guesses[:, 0] *= 2000  # start mu between 0 and 2000
starting_guesses[:, 1] *= 20    # start sigma between 0 and 20

sampler = emcee.EnsembleSampler(nwalkers, ndim, log_posterior, args=[F, e])
sampler.run_mcmc(starting_guesses, nsteps)

sample = sampler.chain  # shape = (nwalkers, nsteps, ndim)
sample = sampler.chain[:, nburn:, :].reshape(-1, 2)
